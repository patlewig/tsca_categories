# %% [markdown]
# #### Using the EPA Categories developed by G Helman which augment the implementation in the OECD Toolbox Version 4.5

# %% [markdown]
# <h1>Extract SMARTS</h1>

# %%
import pandas as pd
import numpy as np
import pymongo
import sys
import os
from datetime import datetime

from rdkit import Chem

import pymongo

# %%
TOP = os.getcwd().replace('notebooks', '')
raw_dir = TOP + 'data/raw/'
interim_dir = TOP + 'data/interim/'
external_dir = TOP + 'data/external/'
figures_dir = TOP + 'reports/figures/'

# %%
with open(raw_dir + 'epa_categories.xml','r') as f:
    xml=f.read()

# %%
xml=xml.replace('\n','')

# %%
#xml

# %%
import xml.etree.ElementTree as ET
e=ET.parse(raw_dir+'epa_categories.xml').getroot()

# %%
e
# Out:
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Scheme' at 0x74514150e810>

# %%
parent_map = {c:p for p in e.iter() for c in p}

# %%
len(parent_map)
# Out:
# 4545

# %%
import operator as op
op_dict={
    'GreaterThan': op.gt,
    'GreaterThanOrEqualTo': op.ge,
    'LessThan': op.lt,
    'LessThanOrEqualTo': op.le
}
prop_dict={
    'log Kow':'logp',
    'Molecular Weight':'mol_weight',
    'Molecular weight':'mol_weight',
    'Water Solubility': 'ws'
}

# %%
def define_smart_match(smart):
    pattern=Chem.MolFromSmarts(smart)
    if not pattern:
        return None
    def smart_match(x):
        mol=x['mol']
        ret=True if mol.GetSubstructMatches(pattern) else False
        return ret
    return smart_match
def define_compare(prop,operand,value):
    def compare(x):
        ret = op_dict[operand](x[prop_dict[prop]],value)
        return ret
    return compare

# %%
class Query:
    
    def __init__(self,xml,qid=None):
        self.xml=xml
        self.id=qid
        self.logic=None
        self.subqueries=[]
        self.category=None

        
    def write_query(self,qtype,tree):
        self.type=qtype
        if qtype=='b:StructureQuery':
            qstring=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch').text
            qstring=re.sub('false','False',qstring)
            qstring=re.sub('true','True',qstring)
            qdict=ast.literal_eval(qstring)
            smart=qdict['queries'][0]['smart']
            self.smart=smart
            if '[Ch3,#1]' in self.smart:
                split=re.search(r'(.*)\[([^\(\)]*),([^\(\)].*)\]$',self.smart)
                split1=split.group(1)
                split2=split.group(1)+'['+split.group(2)+']'
                smart_match1=define_smart_match(split1)
                smart_match2=define_smart_match(split2)
                def smart_match(x):
                    return any([smart_match1(x),smart_match2(x)])
            else:
                smart_match=define_smart_match(smart)
            self.query=smart_match
        elif qtype=='b:ParameterQuery':
            self.operand=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}Operand').text
            self.prop=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ParameterName').text
            self.value=float(self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}Value').text)
            compare=define_compare(self.prop,self.operand,self.value)
            self.query=compare
        elif qtype=='LogicalQuery':
            self.logic=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Logic').text
            elements=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Elements')
            node_ids=[elem.attrib['{http://schemas.microsoft.com/2003/10/Serialization/}Ref']\
                      for elem in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query')\
                      if '{http://schemas.microsoft.com/2003/10/Serialization/}Ref' in elem.attrib]
            if self.logic=='Not':
                node_id=node_ids[0] #Should only be one
                sq=tree[node_id]
                self.subqueries=[sq]
                def func(x):
                    return not(sq.query(x))
                self.query=func
            elif self.logic=='And':
                sqs=[tree[node_id] for node_id in node_ids]
                self.subqueries=sqs
                def func(x):
                    return all([sq.query(x) for sq in self.subqueries])
                self.query=func
            else:
                sqs=[tree[node_id] for node_id in node_ids]
                self.subqueries=sqs
                for orquery in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query'):
                    if '{http://www.w3.org/2001/XMLSchema-instance}type' in orquery.attrib:
                        extra_sq=Query(orquery)
                        extra_sq.write_query('b:StructureQuery',tree)
                        sqs.append(extra_sq)      
                def func(x):
                    return any([sq.query(x) for sq in self.subqueries])
                self.query=func
    
    def print_tree(self,x,tabs=0):
        
        smart_patterns = []
        logic_parameters = []
        
        qinfo=(self.id,self.type)
        if self.type=='b:StructureQuery':
            qinfo=qinfo+(self.smart,)
            smart_patterns.append(self.smart) 
        elif self.type=='b:ParameterQuery':
            qinfo=qinfo+(self.prop,self.value,self.operand)
            logic_parameters.append((self.prop, self.value, self.operand))
        elif self.type=='LogicalQuery':
            qinfo=qinfo+(self.logic,)
            logic_parameters.append(self.logic) 
        try:
            qinfo=qinfo+(self.query(x),)
        except:
            qinfo=qinfo+('does not process',)
        print('\t'*tabs+str(qinfo))
        for sq in self.subqueries:
                sub_smart_patterns, sub_logic_parameters = sq.print_tree(x,tabs+1)
                smart_patterns.extend(sub_smart_patterns)
                logic_parameters.extend(sub_logic_parameters)
        return smart_patterns, logic_parameters

# %%
q = Query(xml)

# %%
all_tests={}
print_tests = {}
bad_smarts=set()
bad_cats=set()
import re
import ast
for elem in e.iter('{http://schemas.microsoft.com/2003/10/Serialization/Arrays}anyType'):
    category=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Caption').text
    queries=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Expression')\
        .find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Queries')\
        .findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query')
    contents=[query.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content') for query in queries]
    #print(query)
    query_tree={}
    for query in contents:
        attributes=query.attrib
        if '{http://schemas.microsoft.com/2003/10/Serialization/}Id' not in attributes:
            continue
        query_id=attributes['{http://schemas.microsoft.com/2003/10/Serialization/}Id']
        #print(query_id)
        query_type=attributes['{http://www.w3.org/2001/XMLSchema-instance}type']
        #print(query_type)
        q=Query(query,query_id)
        q.category=category
        q.write_query(query_type,query_tree)
        q.print_tree(q.query)
        if not q.query or not all([sq.query for sq in q.subqueries]): #Smarts did not compile, sqs needed bc of hidden sqs in or queries
            bad_cats.add(category)
            if q.type=='b:StructureQuery':
                bad_smarts.add(q.smart)
        query_tree[query_id]=q
    all_tests[category]=query_tree[query_id]
    print_tests[category] = [query_id, query_type]#Final one should always be the top level query hopefully
# Out:
# ('24', 'b:StructureQuery', '[#6,#16](=[#8])(Cl)[#6X4,c]', 'does not process')
# ('26', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('29', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('32', 'LogicalQuery', 'And', 'does not process')
# 	('29', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('26', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('24', 'b:StructureQuery', '[#6,#16](=[#8])(Cl)[#6X4,c]', 'does not process')
# ('43', 'b:StructureQuery', '[#6](=[#8])([#7h])[#6](=[#6h2])[Ch3,#1]', 'does not process')
# ('45', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('48', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('51', 'LogicalQuery', 'And', 'does not process')
# 	('48', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('45', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('43', 'b:StructureQuery', '[#6](=[#8])([#7h])[#6](=[#6h2])[Ch3,#1]', 'does not process')
# ('62', 'b:StructureQuery', '[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]', 'does not process')
# ('64', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('67', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('70', 'LogicalQuery', 'And', 'does not process')
# 	('67', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('64', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('62', 'b:StructureQuery', '[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]', 'does not process')
# ('81', 'b:StructureQuery', '[#6h](=[#8])[#6,#1]', 'does not process')
# ('83', 'b:ParameterQuery', 'log Kow', 6.0, 'LessThan', 'does not process')
# ('86', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('89', 'LogicalQuery', 'And', 'does not process')
# 	('86', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('83', 'b:ParameterQuery', 'log Kow', 6.0, 'LessThan', 'does not process')
# 	('81', 'b:StructureQuery', '[#6h](=[#8])[#6,#1]', 'does not process')
# ('100', 'b:StructureQuery', '[#6X4][Nh2v3]', 'does not process')
# ('102', 'b:StructureQuery', '[#6X4][#7hv3][#6X4]', 'does not process')
# ('104', 'b:StructureQuery', '[#6X4][Nv3]([#6X4])[#6X4]', 'does not process')
# ('106', 'b:StructureQuery', '[#6X4][#7+h3]', 'does not process')
# ('108', 'b:StructureQuery', '[#6X4][#7+h2][#6X4]', 'does not process')
# ('110', 'b:StructureQuery', '[#6X4][N+h]([#6X4])[#6X4]', 'does not process')
# ('112', 'b:StructureQuery', '[#7](=[#8])$[[#1],[#6X4]]{1..;xm}', 'does not process')
# ('114', 'LogicalQuery', 'Or', 'does not process')
# 	('112', 'b:StructureQuery', '[#7](=[#8])$[[#1],[#6X4]]{1..;xm}', 'does not process')
# 	('110', 'b:StructureQuery', '[#6X4][N+h]([#6X4])[#6X4]', 'does not process')
# 	('104', 'b:StructureQuery', '[#6X4][Nv3]([#6X4])[#6X4]', 'does not process')
# 	('108', 'b:StructureQuery', '[#6X4][#7+h2][#6X4]', 'does not process')
# 	('106', 'b:StructureQuery', '[#6X4][#7+h3]', 'does not process')
# 	('102', 'b:StructureQuery', '[#6X4][#7hv3][#6X4]', 'does not process')
# 	('100', 'b:StructureQuery', '[#6X4][Nh2v3]', 'does not process')
# 	(None, 'b:StructureQuery', '$[[#1],[#6X4]]{1..;xm}[#7+][#8-]', 'does not process')
# ('118', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('121', 'LogicalQuery', 'And', 'does not process')
# 	('118', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('114', 'LogicalQuery', 'Or', 'does not process')
# 		('112', 'b:StructureQuery', '[#7](=[#8])$[[#1],[#6X4]]{1..;xm}', 'does not process')
# 		('110', 'b:StructureQuery', '[#6X4][N+h]([#6X4])[#6X4]', 'does not process')
# 		('104', 'b:StructureQuery', '[#6X4][Nv3]([#6X4])[#6X4]', 'does not process')
# 		('108', 'b:StructureQuery', '[#6X4][#7+h2][#6X4]', 'does not process')
# 		('106', 'b:StructureQuery', '[#6X4][#7+h3]', 'does not process')
# 		('102', 'b:StructureQuery', '[#6X4][#7hv3][#6X4]', 'does not process')
# 		('100', 'b:StructureQuery', '[#6X4][Nh2v3]', 'does not process')
# 		(None, 'b:StructureQuery', '$[[#1],[#6X4]]{1..;xm}[#7+][#8-]', 'does not process')
# ('132', 'b:StructureQuery', '[Al]', 'does not process')
# ('134', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('137', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThan', 'does not process')
# ('140', 'LogicalQuery', 'And', 'does not process')
# 	('132', 'b:StructureQuery', '[Al]', 'does not process')
# 	('134', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('137', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThan', 'does not process')
# ('151', 'b:StructureQuery', 'c1c([#7h2v3])cccc1', 'does not process')
# ('153', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'LessThan', 'does not process')
# ('156', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('159', 'LogicalQuery', 'And', 'does not process')
# 	('151', 'b:StructureQuery', 'c1c([#7h2v3])cccc1', 'does not process')
# 	('153', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'LessThan', 'does not process')
# 	('156', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('170', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# ('172', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# ('174', 'LogicalQuery', 'Or', 'does not process')
# 	('170', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# 	('172', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# ('176', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('179', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('182', 'LogicalQuery', 'And', 'does not process')
# 	('176', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('179', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('184', 'LogicalQuery', 'And', 'does not process')
# 	('174', 'LogicalQuery', 'Or', 'does not process')
# 		('170', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# 		('172', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# 	('182', 'LogicalQuery', 'And', 'does not process')
# 		('176', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 		('179', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('195', 'b:StructureQuery', 'c12c(cccc1)[#7]=,:[#7][#7v3]2', 'does not process')
# ('197', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('200', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('203', 'LogicalQuery', 'And', 'does not process')
# 	('195', 'b:StructureQuery', 'c12c(cccc1)[#7]=,:[#7][#7v3]2', 'does not process')
# 	('197', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('200', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('214', 'b:StructureQuery', '[c]12[c]([n][n]([n]1)-c1c(cccc1)[#8h])[c][c][c][c]2', 'does not process')
# ('225', 'b:StructureQuery', '[#5]', 'does not process')
# ('227', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('230', 'LogicalQuery', 'And', 'does not process')
# 	('225', 'b:StructureQuery', '[#5]', 'does not process')
# 	('227', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('241', 'b:StructureQuery', '[#7+]([#6])([#6])([#6])[#6]', 'does not process')
# ('252', 'b:StructureQuery', '[Co]', 'does not process')
# ('254', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('257', 'b:ParameterQuery', 'Molecular Weight', 1000.0, 'LessThan', 'does not process')
# ('260', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThanOrEqualTo', 'does not process')
# ('263', 'LogicalQuery', 'And', 'does not process')
# 	('252', 'b:StructureQuery', '[Co]', 'does not process')
# 	('254', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('257', 'b:ParameterQuery', 'Molecular Weight', 1000.0, 'LessThan', 'does not process')
# 	('260', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThanOrEqualTo', 'does not process')
# ('274', 'b:StructureQuery', '[#7]#[#7+]c', 'does not process')
# ('276', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('279', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('282', 'LogicalQuery', 'And', 'does not process')
# 	('274', 'b:StructureQuery', '[#7]#[#7+]c', 'does not process')
# 	('276', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('279', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('293', 'b:StructureQuery', '[#6]1[#8][#6]1', 'does not process')
# ('295', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('298', 'LogicalQuery', 'And', 'does not process')
# 	('293', 'b:StructureQuery', '[#6]1[#8][#6]1', 'does not process')
# 	('295', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('309', 'b:StructureQuery', '[#6]([#6])(=[#8])[#8R0][#6]', 'does not process')
# ('311', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('314', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('317', 'LogicalQuery', 'And', 'does not process')
# 	('309', 'b:StructureQuery', '[#6]([#6])(=[#8])[#8R0][#6]', 'does not process')
# 	('311', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('314', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('328', 'b:StructureQuery', '[#7R0v3][#7R0v3]', 'does not process')
# ('330', 'b:StructureQuery', '[#6]=[#7R0v3][#7R0v3]', 'does not process')
# ('332', 'LogicalQuery', 'Or', 'does not process')
# 	('330', 'b:StructureQuery', '[#6]=[#7R0v3][#7R0v3]', 'does not process')
# 	('328', 'b:StructureQuery', '[#7R0v3][#7R0v3]', 'does not process')
# 	(None, 'b:StructureQuery', '[#6](=[#8])([#7hv3][#7R0v3])[Nh,*]', 'does not process')
# ('336', 'LogicalQuery', 'And', 'does not process')
# 	('332', 'LogicalQuery', 'Or', 'does not process')
# 		('330', 'b:StructureQuery', '[#6]=[#7R0v3][#7R0v3]', 'does not process')
# 		('328', 'b:StructureQuery', '[#7R0v3][#7R0v3]', 'does not process')
# 		(None, 'b:StructureQuery', '[#6](=[#8])([#7hv3][#7R0v3])[Nh,*]', 'does not process')
# ('350', 'b:StructureQuery', '[#6]1([#6h3])([#6h3])[#6][#6][#6][#6]([#6h3])([#6h3])[#7v3]1', 'does not process')
# ('361', 'b:StructureQuery', '[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]', 'does not process')
# ('363', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThanOrEqualTo', 'does not process')
# ('366', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('369', 'LogicalQuery', 'And', 'does not process')
# 	('361', 'b:StructureQuery', '[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]', 'does not process')
# 	('363', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThanOrEqualTo', 'does not process')
# 	('366', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('380', 'b:StructureQuery', '[La,Ce,Pr,Nd,Sm,Eu,Gd,Tb,Dy,Ho,Er,Tm,Yb,Lu]', 'does not process')
# ('382', 'LogicalQuery', 'And', 'does not process')
# 	('380', 'b:StructureQuery', '[La,Ce,Pr,Nd,Sm,Eu,Gd,Tb,Dy,Ho,Er,Tm,Yb,Lu]', 'does not process')
# ('396', 'LogicalQuery', 'Or', 'does not process')
# 	(None, 'b:StructureQuery', '[#6X4][#6](=[#8])[#6X4]', 'does not process')
# 	(None, 'b:StructureQuery', '[#6X4][#8R0][#6X4]', 'does not process')
# 	(None, 'b:StructureQuery', 'c1ccccc1[#6](=[#8])[#6]', 'does not process')
# 	(None, 'b:StructureQuery', 'c1ccccc1.$[[#1],$[[#6X4]]{1..}]{1..;x}', 'does not process')
# 	(None, 'b:StructureQuery', 'c1ccccc1[Cl,Br]', 'does not process')
# 	(None, 'b:StructureQuery', '$[$[[#6X4]]{1..}]{1..;x}[Cl,Br,#8h]', 'does not process')
# ('410', 'LogicalQuery', 'And', 'does not process')
# 	('396', 'LogicalQuery', 'Or', 'does not process')
# 		(None, 'b:StructureQuery', '[#6X4][#6](=[#8])[#6X4]', 'does not process')
# 		(None, 'b:StructureQuery', '[#6X4][#8R0][#6X4]', 'does not process')
# 		(None, 'b:StructureQuery', 'c1ccccc1[#6](=[#8])[#6]', 'does not process')
# 		(None, 'b:StructureQuery', 'c1ccccc1.$[[#1],$[[#6X4]]{1..}]{1..;x}', 'does not process')
# 		(None, 'b:StructureQuery', 'c1ccccc1[Cl,Br]', 'does not process')
# 		(None, 'b:StructureQuery', '$[$[[#6X4]]{1..}]{1..;x}[Cl,Br,#8h]', 'does not process')
# ('420', 'LogicalQuery', 'And', 'does not process')
# 	('410', 'LogicalQuery', 'And', 'does not process')
# 		('396', 'LogicalQuery', 'Or', 'does not process')
# 			(None, 'b:StructureQuery', '[#6X4][#6](=[#8])[#6X4]', 'does not process')
# 			(None, 'b:StructureQuery', '[#6X4][#8R0][#6X4]', 'does not process')
# 			(None, 'b:StructureQuery', 'c1ccccc1[#6](=[#8])[#6]', 'does not process')
# 			(None, 'b:StructureQuery', 'c1ccccc1.$[[#1],$[[#6X4]]{1..}]{1..;x}', 'does not process')
# 			(None, 'b:StructureQuery', 'c1ccccc1[Cl,Br]', 'does not process')
# 			(None, 'b:StructureQuery', '$[$[[#6X4]]{1..}]{1..;x}[Cl,Br,#8h]', 'does not process')
# ('501', 'b:StructureQuery', '[Ni]', 'does not process')
# ('503', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('506', 'LogicalQuery', 'And', 'does not process')
# 	('501', 'b:StructureQuery', '[Ni]', 'does not process')
# 	('503', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('517', 'b:StructureQuery', '[#8]{>-1}$[[#1],[#6X4]]{1..;x}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..5}.[#6X4]{<-1}', 'does not process')
# ('528', 'b:StructureQuery', '[Sn]$[c,[#6X4],[#1]]{1..;xm}', 'does not process')
# ('530', 'b:StructureQuery', '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}', 'does not process')
# ('532', 'LogicalQuery', 'Or', 'does not process')
# 	('528', 'b:StructureQuery', '[Sn]$[c,[#6X4],[#1]]{1..;xm}', 'does not process')
# 	('530', 'b:StructureQuery', '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}', 'does not process')
# ('534', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('537', 'b:ParameterQuery', 'log Kow', 13.6999998092651, 'LessThanOrEqualTo', 'does not process')
# ('540', 'LogicalQuery', 'And', 'does not process')
# 	('534', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('537', 'b:ParameterQuery', 'log Kow', 13.6999998092651, 'LessThanOrEqualTo', 'does not process')
# ('542', 'LogicalQuery', 'And', 'does not process')
# 	('532', 'LogicalQuery', 'Or', 'does not process')
# 		('528', 'b:StructureQuery', '[Sn]$[c,[#6X4],[#1]]{1..;xm}', 'does not process')
# 		('530', 'b:StructureQuery', '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}', 'does not process')
# 	('540', 'LogicalQuery', 'And', 'does not process')
# 		('534', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 		('537', 'b:ParameterQuery', 'log Kow', 13.6999998092651, 'LessThanOrEqualTo', 'does not process')
# ('553', 'b:StructureQuery', '[#6X4][#8][#8][#6X4]', 'does not process')
# ('555', 'b:StructureQuery', '[#6X4][#8][#8h]', 'does not process')
# ('557', 'b:StructureQuery', '[#6](=[#8])[#8][#8][#6]', 'does not process')
# ('559', 'b:StructureQuery', '[#6](=[#8])[#8][#8][#6]=[#8]', 'does not process')
# ('561', 'b:StructureQuery', '[#6](=[#8])[#8][#8h]', 'does not process')
# ('563', 'LogicalQuery', 'Or', 'does not process')
# 	('553', 'b:StructureQuery', '[#6X4][#8][#8][#6X4]', 'does not process')
# 	('555', 'b:StructureQuery', '[#6X4][#8][#8h]', 'does not process')
# 	('557', 'b:StructureQuery', '[#6](=[#8])[#8][#8][#6]', 'does not process')
# 	('559', 'b:StructureQuery', '[#6](=[#8])[#8][#8][#6]=[#8]', 'does not process')
# 	('561', 'b:StructureQuery', '[#6](=[#8])[#8][#8h]', 'does not process')
# ('574', 'b:StructureQuery', 'c1([#6]2(c3ccc([#8])cc3)c3c([#6](=[#8])[#8]2)cccc3)ccc([#8])cc1', 'does not process')
# ('585', 'b:StructureQuery', 'c1ccccc1[#8h]', 'does not process')
# ('587', 'b:StructureQuery', 'c12c(cccc1)cccc2', 'does not process')
# ('589', 'LogicalQuery', 'Not', 'does not process')
# 	('587', 'b:StructureQuery', 'c12c(cccc1)cccc2', 'does not process')
# ('591', 'b:StructureQuery', 'c1(-c2ccccc2)ccccc1', 'does not process')
# ('593', 'LogicalQuery', 'Not', 'does not process')
# 	('591', 'b:StructureQuery', 'c1(-c2ccccc2)ccccc1', 'does not process')
# ('595', 'LogicalQuery', 'And', 'does not process')
# 	('585', 'b:StructureQuery', 'c1ccccc1[#8h]', 'does not process')
# 	('589', 'LogicalQuery', 'Not', 'does not process')
# 		('587', 'b:StructureQuery', 'c12c(cccc1)cccc2', 'does not process')
# 	('593', 'LogicalQuery', 'Not', 'does not process')
# 		('591', 'b:StructureQuery', 'c1(-c2ccccc2)ccccc1', 'does not process')
# ('597', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('600', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'LessThan', 'does not process')
# ('603', 'LogicalQuery', 'And', 'does not process')
# 	('597', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('600', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'LessThan', 'does not process')
# ('605', 'LogicalQuery', 'And', 'does not process')
# 	('595', 'LogicalQuery', 'And', 'does not process')
# 		('585', 'b:StructureQuery', 'c1ccccc1[#8h]', 'does not process')
# 		('589', 'LogicalQuery', 'Not', 'does not process')
# 			('587', 'b:StructureQuery', 'c12c(cccc1)cccc2', 'does not process')
# 		('593', 'LogicalQuery', 'Not', 'does not process')
# 			('591', 'b:StructureQuery', 'c1(-c2ccccc2)ccccc1', 'does not process')
# 	('603', 'LogicalQuery', 'And', 'does not process')
# 		('597', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 		('600', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'LessThan', 'does not process')
# ('616', 'b:StructureQuery', '[#8][#15v5](=[#8])([#8])[#8]', 'does not process')
# ('618', 'b:StructureQuery', '[#6]', 'does not process')
# ('620', 'LogicalQuery', 'Not', 'does not process')
# 	('618', 'b:StructureQuery', '[#6]', 'does not process')
# ('622', 'LogicalQuery', 'And', 'does not process')
# 	('616', 'b:StructureQuery', '[#8][#15v5](=[#8])([#8])[#8]', 'does not process')
# 	('620', 'LogicalQuery', 'Not', 'does not process')
# 		('618', 'b:StructureQuery', '[#6]', 'does not process')
# ('633', 'b:StructureQuery', '[#6][#8][#15v5](=[#8])([#6])[#6]', 'does not process')
# ('635', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('638', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('641', 'LogicalQuery', 'And', 'does not process')
# 	('633', 'b:StructureQuery', '[#6][#8][#15v5](=[#8])([#6])[#6]', 'does not process')
# 	('635', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('638', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('652', 'b:StructureQuery', 'c1([#16](=[#8])(=[#8])[#8])c([#6h]=[#6h]c2c([#16](=[#8])(=[#8])[#8])cc([#7h]c3nc([#6X4])nc([#6X4])n3)cc2)ccc([#7h]c2nc([#6X4])nc([#6X4])n2)c1', 'does not process')
# ('663', 'b:StructureQuery', '[#6][#16hv2]', 'does not process')
# ('665', 'b:ParameterQuery', 'log Kow', 6.5, 'LessThan', 'does not process')
# ('668', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('671', 'LogicalQuery', 'And', 'does not process')
# 	('663', 'b:StructureQuery', '[#6][#16hv2]', 'does not process')
# 	('665', 'b:ParameterQuery', 'log Kow', 6.5, 'LessThan', 'does not process')
# 	('668', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('682', 'b:StructureQuery', '[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}', 'does not process')
# ('684', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('687', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('690', 'LogicalQuery', 'And', 'does not process')
# 	('682', 'b:StructureQuery', '[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}', 'does not process')
# 	('684', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('687', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('701', 'b:StructureQuery', 'c1(ccc(cc1)[#7v3,#8]{>-1})[C](c1ccc(cc1)[#7v3,#8]{>-1})=[C]1[C]=[C][C]([C]=[C]1)=[#7hv3,#8].$[[Ch3]{<-1},[Ch2]{<-1}[Ch3],[#1]{<-1}]{2}', 'does not process')
# ('703', 'b:StructureQuery', '$[[#6](=[#8])[#8h],[#16v6](=[#8])(=[#8])[#8h],F,Cl,Br,I]', 'does not process')
# ('705', 'LogicalQuery', 'Not', 'does not process')
# 	('703', 'b:StructureQuery', '$[[#6](=[#8])[#8h],[#16v6](=[#8])(=[#8])[#8h],F,Cl,Br,I]', 'does not process')
# ('707', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThan', 'does not process')
# ('710', 'LogicalQuery', 'And', 'does not process')
# 	('701', 'b:StructureQuery', 'c1(ccc(cc1)[#7v3,#8]{>-1})[C](c1ccc(cc1)[#7v3,#8]{>-1})=[C]1[C]=[C][C]([C]=[C]1)=[#7hv3,#8].$[[Ch3]{<-1},[Ch2]{<-1}[Ch3],[#1]{<-1}]{2}', 'does not process')
# 	('705', 'LogicalQuery', 'Not', 'does not process')
# 		('703', 'b:StructureQuery', '$[[#6](=[#8])[#8h],[#16v6](=[#8])(=[#8])[#8h],F,Cl,Br,I]', 'does not process')
# 	('707', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThan', 'does not process')
# ('721', 'b:StructureQuery', '[#6][#6](=[#8])[#8][#6h]=[#6h2]', 'does not process')
# ('723', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('726', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('729', 'LogicalQuery', 'And', 'does not process')
# 	('721', 'b:StructureQuery', '[#6][#6](=[#8])[#8][#6h]=[#6h2]', 'does not process')
# 	('723', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('726', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('740', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h]=[#6h]', 'does not process')
# ('742', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h2][#6h2][#8][#16v6](=[#8])(=[#8])[#8]', 'does not process')
# ('744', 'LogicalQuery', 'Or', 'does not process')
# 	('740', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h]=[#6h]', 'does not process')
# 	('742', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h2][#6h2][#8][#16v6](=[#8])(=[#8])[#8]', 'does not process')
# ('746', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('749', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('752', 'LogicalQuery', 'And', 'does not process')
# 	('746', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('749', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('754', 'LogicalQuery', 'And', 'does not process')
# 	('744', 'LogicalQuery', 'Or', 'does not process')
# 		('740', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h]=[#6h]', 'does not process')
# 		('742', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h2][#6h2][#8][#16v6](=[#8])(=[#8])[#8]', 'does not process')
# 	('752', 'LogicalQuery', 'And', 'does not process')
# 		('746', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 		('749', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('765', 'b:StructureQuery', '[Zn]', 'does not process')
# ('767', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#8-].[Zn+2]', 'does not process')
# ('769', 'b:StructureQuery', '[#6](=[#8])[#8-].[Zn+2]', 'does not process')
# ('771', 'LogicalQuery', 'Not', 'does not process')
# 	('769', 'b:StructureQuery', '[#6](=[#8])[#8-].[Zn+2]', 'does not process')
# ('773', 'b:StructureQuery', '[#15](=[#8])([#8])([#8])[#8-].[Zn+2]', 'does not process')
# ('775', 'LogicalQuery', 'Not', 'does not process')
# 	('773', 'b:StructureQuery', '[#15](=[#8])([#8])([#8])[#8-].[Zn+2]', 'does not process')
# ('777', 'LogicalQuery', 'Or', 'does not process')
# 	('765', 'b:StructureQuery', '[Zn]', 'does not process')
# 	('767', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#8-].[Zn+2]', 'does not process')
# ('779', 'LogicalQuery', 'And', 'does not process')
# 	('771', 'LogicalQuery', 'Not', 'does not process')
# 		('769', 'b:StructureQuery', '[#6](=[#8])[#8-].[Zn+2]', 'does not process')
# 	('775', 'LogicalQuery', 'Not', 'does not process')
# 		('773', 'b:StructureQuery', '[#15](=[#8])([#8])([#8])[#8-].[Zn+2]', 'does not process')
# 	('777', 'LogicalQuery', 'Or', 'does not process')
# 		('765', 'b:StructureQuery', '[Zn]', 'does not process')
# 		('767', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#8-].[Zn+2]', 'does not process')
# ('790', 'b:StructureQuery', '[#6](=[#8])([#6])[#8][#6](=[#8])[#6]', 'does not process')
# ('792', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('795', 'LogicalQuery', 'And', 'does not process')
# 	('790', 'b:StructureQuery', '[#6](=[#8])([#6])[#8][#6](=[#8])[#6]', 'does not process')
# 	('792', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('806', 'b:StructureQuery', 'c1(-c2cc(Cl)c([#7]=[#7][#6]([#6]([#6])=[#8])[#6](=[#8])[#7]c3ccccc3)cc2)cc(Cl)c([#7]=[#7][#6]([#6]([#6])=[#8])[#6](=[#8])[#7]c2ccccc2)cc1', 'does not process')
# ('817', 'b:StructureQuery', '[#7]=[#6]=[#8].[#7]=[#6]=[#8]', 'does not process')
# ('819', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('822', 'LogicalQuery', 'And', 'does not process')
# 	('817', 'b:StructureQuery', '[#7]=[#6]=[#8].[#7]=[#6]=[#8]', 'does not process')
# 	('819', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('833', 'b:StructureQuery', '[Si][#8]$[[#6X4]]{1..;x}', 'does not process')
# ('835', 'b:StructureQuery', '[Si](=[#8])([#8h])[#8][#6]', 'does not process')
# ('837', 'LogicalQuery', 'Not', 'does not process')
# 	('835', 'b:StructureQuery', '[Si](=[#8])([#8h])[#8][#6]', 'does not process')
# ('839', 'LogicalQuery', 'And', 'does not process')
# 	('833', 'b:StructureQuery', '[Si][#8]$[[#6X4]]{1..;x}', 'does not process')
# 	('837', 'LogicalQuery', 'Not', 'does not process')
# 		('835', 'b:StructureQuery', '[Si](=[#8])([#8h])[#8][#6]', 'does not process')
# ('841', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('844', 'LogicalQuery', 'And', 'does not process')
# 	('839', 'LogicalQuery', 'And', 'does not process')
# 		('833', 'b:StructureQuery', '[Si][#8]$[[#6X4]]{1..;x}', 'does not process')
# 		('837', 'LogicalQuery', 'Not', 'does not process')
# 			('835', 'b:StructureQuery', '[Si](=[#8])([#8h])[#8][#6]', 'does not process')
# 	('841', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('855', 'b:StructureQuery', 'c1([#6,#7,#8,#16]c2cc{>-1}c{>-1}c{>-1}c2)cc{>-2}c{>-2}c{>-2}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}', 'does not process')
# ('857', 'b:StructureQuery', 'c1([#6,#7,#8,#16]{>-3})cc{>-2}c{>-2}c{>-2}c1.$[c1c([#6]{>-3})cccc{<-3}1,c1c([#7]{>-3})cccc{<-3}1,c1c([#8]{>-3})cccc{<-3}1,c1c([#16]{>-3})cccc{<-3}1]{1..5}.c{<-3}1cc{>-1}c{>-1}c{>-1}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}', 'does not process')
# ('859', 'LogicalQuery', 'Or', 'does not process')
# 	('855', 'b:StructureQuery', 'c1([#6,#7,#8,#16]c2cc{>-1}c{>-1}c{>-1}c2)cc{>-2}c{>-2}c{>-2}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}', 'does not process')
# 	('857', 'b:StructureQuery', 'c1([#6,#7,#8,#16]{>-3})cc{>-2}c{>-2}c{>-2}c1.$[c1c([#6]{>-3})cccc{<-3}1,c1c([#7]{>-3})cccc{<-3}1,c1c([#8]{>-3})cccc{<-3}1,c1c([#16]{>-3})cccc{<-3}1]{1..5}.c{<-3}1cc{>-1}c{>-1}c{>-1}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}', 'does not process')
# ('870', 'b:StructureQuery', 'c{>-1}1c{>-1}([#16](=[#8])(=[#8])[#8])c{>-1}c{>-1}c{>-1}c{>-1}1.$[$[$[[#6h2]]{2..},[#8]]{1..;x}{<-1}]{1}', 'does not process')
# ('872', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# ('874', 'b:StructureQuery', '[#15](=[#8])([#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# ('876', 'b:StructureQuery', '[#8]=[#6]([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# ('878', 'b:StructureQuery', '[Si](=[#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# ('880', 'b:StructureQuery', '[#6X4][#16](=[#8])(=[#8])[#8]', 'does not process')
# ('882', 'b:StructureQuery', '[#8][#6]=[#8]', 'does not process')
# ('884', 'LogicalQuery', 'And', 'does not process')
# 	('880', 'b:StructureQuery', '[#6X4][#16](=[#8])(=[#8])[#8]', 'does not process')
# 	('882', 'b:StructureQuery', '[#8][#6]=[#8]', 'does not process')
# ('886', 'b:StructureQuery', '[#6X4][#16](=[#8])(=[#8])[#8]', 'does not process')
# ('888', 'b:StructureQuery', '[#8]=[#15]([#8])([#8])[#8]', 'does not process')
# ('890', 'LogicalQuery', 'And', 'does not process')
# 	('886', 'b:StructureQuery', '[#6X4][#16](=[#8])(=[#8])[#8]', 'does not process')
# 	('888', 'b:StructureQuery', '[#8]=[#15]([#8])([#8])[#8]', 'does not process')
# ('892', 'b:StructureQuery', '[#8]=[#15]([#8])([#8])[#8][#6X4]', 'does not process')
# ('894', 'b:StructureQuery', '[#8][#6]=[#8]', 'does not process')
# ('896', 'LogicalQuery', 'And', 'does not process')
# 	('892', 'b:StructureQuery', '[#8]=[#15]([#8])([#8])[#8][#6X4]', 'does not process')
# 	('894', 'b:StructureQuery', '[#8][#6]=[#8]', 'does not process')
# ('898', 'LogicalQuery', 'Or', 'does not process')
# 	('870', 'b:StructureQuery', 'c{>-1}1c{>-1}([#16](=[#8])(=[#8])[#8])c{>-1}c{>-1}c{>-1}c{>-1}1.$[$[$[[#6h2]]{2..},[#8]]{1..;x}{<-1}]{1}', 'does not process')
# 	('872', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# 	('874', 'b:StructureQuery', '[#15](=[#8])([#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# 	('876', 'b:StructureQuery', '[#8]=[#6]([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# 	('878', 'b:StructureQuery', '[Si](=[#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}', 'does not process')
# 	('884', 'LogicalQuery', 'And', 'does not process')
# 		('880', 'b:StructureQuery', '[#6X4][#16](=[#8])(=[#8])[#8]', 'does not process')
# 		('882', 'b:StructureQuery', '[#8][#6]=[#8]', 'does not process')
# 	('890', 'LogicalQuery', 'And', 'does not process')
# 		('886', 'b:StructureQuery', '[#6X4][#16](=[#8])(=[#8])[#8]', 'does not process')
# 		('888', 'b:StructureQuery', '[#8]=[#15]([#8])([#8])[#8]', 'does not process')
# 	('896', 'LogicalQuery', 'And', 'does not process')
# 		('892', 'b:StructureQuery', '[#8]=[#15]([#8])([#8])[#8][#6X4]', 'does not process')
# 		('894', 'b:StructureQuery', '[#8][#6]=[#8]', 'does not process')
# ('909', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}', 'does not process')
# ('911', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7hv3][#6h2][#6h2][#7hv3][#6](=[#16])[#16v2]', 'does not process')
# ('913', 'LogicalQuery', 'Or', 'does not process')
# 	('909', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}', 'does not process')
# 	('911', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7hv3][#6h2][#6h2][#7hv3][#6](=[#16])[#16v2]', 'does not process')
# ('915', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# ('918', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('921', 'LogicalQuery', 'And', 'does not process')
# 	('915', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('918', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('923', 'LogicalQuery', 'And', 'does not process')
# 	('913', 'LogicalQuery', 'Or', 'does not process')
# 		('909', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}', 'does not process')
# 		('911', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7hv3][#6h2][#6h2][#7hv3][#6](=[#16])[#16v2]', 'does not process')
# 	('921', 'LogicalQuery', 'And', 'does not process')
# 		('915', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 		('918', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('934', 'b:StructureQuery', 'c1([#7h2v3])c(c2c([ch][ch]1)c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}2)[Oh,#1].$[[#8h]{<-2},[#7h2]{<-2},[#1]{<-2}]{1}.$[[#16]{<-1}(=[#8])(=[#8])[#8h],[#6h2]([#6h2][#16](=[#8])(=[#8])[#8h])[#16]{<-1}(=[#8])=[#8]]{1}', 'does not process')
# ('945', 'b:StructureQuery', 'c1(:,-c2c{>-2}c{>-2}c{>-2}c{>-2}c{>-2}2)c{>-1}c{>-1}c{>-1}c{>-1}c{>-1}1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}', 'does not process')
# ('947', 'b:StructureQuery', 'c1(-c2cc(Cl)c([#7]=[#7][#6])cc2)cc(Cl)c([#7]=[#7][#6])cc1', 'does not process')
# ('949', 'LogicalQuery', 'Not', 'does not process')
# 	('947', 'b:StructureQuery', 'c1(-c2cc(Cl)c([#7]=[#7][#6])cc2)cc(Cl)c([#7]=[#7][#6])cc1', 'does not process')
# ('951', 'LogicalQuery', 'And', 'does not process')
# 	('945', 'b:StructureQuery', 'c1(:,-c2c{>-2}c{>-2}c{>-2}c{>-2}c{>-2}2)c{>-1}c{>-1}c{>-1}c{>-1}c{>-1}1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}', 'does not process')
# 	('949', 'LogicalQuery', 'Not', 'does not process')
# 		('947', 'b:StructureQuery', 'c1(-c2cc(Cl)c([#7]=[#7][#6])cc2)cc(Cl)c([#7]=[#7][#6])cc1', 'does not process')
# ('953', 'b:StructureQuery', '[#6](Cl)(Cl)(Cl)[#6](c1ccc{>-2}cc1)c1ccc{>-1}cc1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}', 'does not process')
# ('955', 'LogicalQuery', 'Or', 'does not process')
# 	('951', 'LogicalQuery', 'And', 'does not process')
# 		('945', 'b:StructureQuery', 'c1(:,-c2c{>-2}c{>-2}c{>-2}c{>-2}c{>-2}2)c{>-1}c{>-1}c{>-1}c{>-1}c{>-1}1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}', 'does not process')
# 		('949', 'LogicalQuery', 'Not', 'does not process')
# 			('947', 'b:StructureQuery', 'c1(-c2cc(Cl)c([#7]=[#7][#6])cc2)cc(Cl)c([#7]=[#7][#6])cc1', 'does not process')
# 	('953', 'b:StructureQuery', '[#6](Cl)(Cl)(Cl)[#6](c1ccc{>-2}cc1)c1ccc{>-1}cc1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}', 'does not process')
# ('957', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('960', 'LogicalQuery', 'And', 'does not process')
# 	('955', 'LogicalQuery', 'Or', 'does not process')
# 		('951', 'LogicalQuery', 'And', 'does not process')
# 			('945', 'b:StructureQuery', 'c1(:,-c2c{>-2}c{>-2}c{>-2}c{>-2}c{>-2}2)c{>-1}c{>-1}c{>-1}c{>-1}c{>-1}1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}', 'does not process')
# 			('949', 'LogicalQuery', 'Not', 'does not process')
# 				('947', 'b:StructureQuery', 'c1(-c2cc(Cl)c([#7]=[#7][#6])cc2)cc(Cl)c([#7]=[#7][#6])cc1', 'does not process')
# 		('953', 'b:StructureQuery', '[#6](Cl)(Cl)(Cl)[#6](c1ccc{>-2}cc1)c1ccc{>-1}cc1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}', 'does not process')
# 	('957', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('971', 'b:StructureQuery', '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}', 'does not process')
# ('973', 'b:StructureQuery', '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}', 'does not process')
# ('975', 'LogicalQuery', 'Not', 'does not process')
# 	('973', 'b:StructureQuery', '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}', 'does not process')
# ('977', 'LogicalQuery', 'And', 'does not process')
# 	('971', 'b:StructureQuery', '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}', 'does not process')
# 	('975', 'LogicalQuery', 'Not', 'does not process')
# 		('973', 'b:StructureQuery', '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}', 'does not process')
# ('979', 'b:ParameterQuery', 'log Kow', 7.0, 'LessThan', 'does not process')
# ('982', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('985', 'LogicalQuery', 'And', 'does not process')
# 	('979', 'b:ParameterQuery', 'log Kow', 7.0, 'LessThan', 'does not process')
# 	('982', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('987', 'LogicalQuery', 'And', 'does not process')
# 	('977', 'LogicalQuery', 'And', 'does not process')
# 		('971', 'b:StructureQuery', '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}', 'does not process')
# 		('975', 'LogicalQuery', 'Not', 'does not process')
# 			('973', 'b:StructureQuery', '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}', 'does not process')
# 	('985', 'LogicalQuery', 'And', 'does not process')
# 		('979', 'b:ParameterQuery', 'log Kow', 7.0, 'LessThan', 'does not process')
# 		('982', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('998', 'b:StructureQuery', '[#6](=[#8])([#8])[#6]1([#6])[#6]2[#6]([#6])([#6]3[#6]([#6]=[#6]([#6]([#6])[#6])[#6][#6]3)=[#6][#6]2)[#6][#6][#6]1', 'does not process')
# ('1000', 'b:StructureQuery', 'c1([#6]=[#6][#6][#8][#6]2[#6]([#8])[#6]([#8])[#6]([#8])[#6]([#6][#8])[#8]2)ccccc1', 'does not process')
# ('1002', 'LogicalQuery', 'Or', 'does not process')
# 	('998', 'b:StructureQuery', '[#6](=[#8])([#8])[#6]1([#6])[#6]2[#6]([#6])([#6]3[#6]([#6]=[#6]([#6]([#6])[#6])[#6][#6]3)=[#6][#6]2)[#6][#6][#6]1', 'does not process')
# 	('1000', 'b:StructureQuery', 'c1([#6]=[#6][#6][#8][#6]2[#6]([#8])[#6]([#8])[#6]([#8])[#6]([#6][#8])[#8]2)ccccc1', 'does not process')
# ('1004', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1007', 'b:ParameterQuery', 'Water Solubility', 0.00100000004749745, 'GreaterThan', 'does not process')
# ('1010', 'LogicalQuery', 'And', 'does not process')
# 	('1004', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('1007', 'b:ParameterQuery', 'Water Solubility', 0.00100000004749745, 'GreaterThan', 'does not process')
# ('1012', 'LogicalQuery', 'And', 'does not process')
# 	('1002', 'LogicalQuery', 'Or', 'does not process')
# 		('998', 'b:StructureQuery', '[#6](=[#8])([#8])[#6]1([#6])[#6]2[#6]([#6])([#6]3[#6]([#6]=[#6]([#6]([#6])[#6])[#6][#6]3)=[#6][#6]2)[#6][#6][#6]1', 'does not process')
# 		('1000', 'b:StructureQuery', 'c1([#6]=[#6][#6][#8][#6]2[#6]([#8])[#6]([#8])[#6]([#8])[#6]([#6][#8])[#8]2)ccccc1', 'does not process')
# 	('1010', 'LogicalQuery', 'And', 'does not process')
# 		('1004', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 		('1007', 'b:ParameterQuery', 'Water Solubility', 0.00100000004749745, 'GreaterThan', 'does not process')
# ('1023', 'b:StructureQuery', '[Zr]', 'does not process')
# ('1025', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1028', 'LogicalQuery', 'And', 'does not process')
# 	('1023', 'b:StructureQuery', '[Zr]', 'does not process')
# 	('1025', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1039', 'b:StructureQuery', '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[s][#6]([#7]=[#7]{>-2})[n]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}', 'does not process')
# ('1041', 'b:StructureQuery', '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[#16][#6](c1ccc(cc1)[#7]=[#7]{>-2})[#7]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}', 'does not process')
# ('1043', 'LogicalQuery', 'Or', 'does not process')
# 	('1039', 'b:StructureQuery', '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[s][#6]([#7]=[#7]{>-2})[n]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}', 'does not process')
# 	('1041', 'b:StructureQuery', '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[#16][#6](c1ccc(cc1)[#7]=[#7]{>-2})[#7]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}', 'does not process')
# ('1054', 'b:StructureQuery', '[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]', 'does not process')
# ('1056', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# ('1059', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('1062', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1065', 'LogicalQuery', 'And', 'does not process')
# 	('1062', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('1059', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1056', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1054', 'b:StructureQuery', '[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]', 'does not process')
# ('1076', 'b:StructureQuery', '[#6h](=[#8])[#6,#1]', 'does not process')
# ('1078', 'b:ParameterQuery', 'log Kow', 6.0, 'GreaterThan', 'does not process')
# ('1081', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThanOrEqualTo', 'does not process')
# ('1084', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1087', 'LogicalQuery', 'And', 'does not process')
# 	('1084', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('1081', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThanOrEqualTo', 'does not process')
# 	('1078', 'b:ParameterQuery', 'log Kow', 6.0, 'GreaterThan', 'does not process')
# 	('1076', 'b:StructureQuery', '[#6h](=[#8])[#6,#1]', 'does not process')
# ('1098', 'b:StructureQuery', 'c1c([#7h2v3])cccc1', 'does not process')
# ('1100', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'GreaterThan', 'does not process')
# ('1103', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('1106', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1109', 'LogicalQuery', 'And', 'does not process')
# 	('1098', 'b:StructureQuery', 'c1c([#7h2v3])cccc1', 'does not process')
# 	('1100', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'GreaterThan', 'does not process')
# 	('1103', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1106', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1120', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# ('1122', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# ('1124', 'LogicalQuery', 'Or', 'does not process')
# 	('1120', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# 	('1122', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# ('1126', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# ('1129', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('1132', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1135', 'LogicalQuery', 'And', 'does not process')
# 	('1126', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1129', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1132', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1137', 'LogicalQuery', 'And', 'does not process')
# 	('1124', 'LogicalQuery', 'Or', 'does not process')
# 		('1120', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# 		('1122', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# 	('1135', 'LogicalQuery', 'And', 'does not process')
# 		('1126', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 		('1129', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 		('1132', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1148', 'b:StructureQuery', 'c12c(cccc1)[#7]=,:[#7][#7v3]2', 'does not process')
# ('1150', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# ('1153', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('1156', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1159', 'LogicalQuery', 'And', 'does not process')
# 	('1148', 'b:StructureQuery', 'c12c(cccc1)[#7]=,:[#7][#7v3]2', 'does not process')
# 	('1150', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1153', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1156', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1170', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}', 'does not process')
# ('1172', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7hv3][#6h2][#6h2][#7hv3][#6](=[#16])[#16v2]', 'does not process')
# ('1174', 'LogicalQuery', 'Or', 'does not process')
# 	('1170', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}', 'does not process')
# 	('1172', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7hv3][#6h2][#6h2][#7hv3][#6](=[#16])[#16v2]', 'does not process')
# ('1176', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# ('1179', 'b:ParameterQuery', 'log Kow', 19.0, 'LessThan', 'does not process')
# ('1182', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1185', 'LogicalQuery', 'And', 'does not process')
# 	('1176', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1179', 'b:ParameterQuery', 'log Kow', 19.0, 'LessThan', 'does not process')
# 	('1182', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1187', 'LogicalQuery', 'And', 'does not process')
# 	('1174', 'LogicalQuery', 'Or', 'does not process')
# 		('1170', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}', 'does not process')
# 		('1172', 'b:StructureQuery', '[#16v2][#6](=[#16])[#7hv3][#6h2][#6h2][#7hv3][#6](=[#16])[#16v2]', 'does not process')
# 	('1185', 'LogicalQuery', 'And', 'does not process')
# 		('1176', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 		('1179', 'b:ParameterQuery', 'log Kow', 19.0, 'LessThan', 'does not process')
# 		('1182', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1198', 'b:StructureQuery', '[#6]([#6])(=[#8])[#8R0][#6]', 'does not process')
# ('1200', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# ('1203', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('1206', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1209', 'LogicalQuery', 'And', 'does not process')
# 	('1198', 'b:StructureQuery', '[#6]([#6])(=[#8])[#8R0][#6]', 'does not process')
# 	('1200', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1203', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1206', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1220', 'b:StructureQuery', '[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]', 'does not process')
# ('1222', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# ('1225', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThanOrEqualTo', 'does not process')
# ('1228', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1231', 'LogicalQuery', 'And', 'does not process')
# 	('1220', 'b:StructureQuery', '[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]', 'does not process')
# 	('1222', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1225', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThanOrEqualTo', 'does not process')
# 	('1228', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1242', 'b:StructureQuery', '[Sn]$[c,[#6X4],[#1]]{1..;xm}', 'does not process')
# ('1244', 'b:StructureQuery', '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}', 'does not process')
# ('1246', 'LogicalQuery', 'Or', 'does not process')
# 	('1242', 'b:StructureQuery', '[Sn]$[c,[#6X4],[#1]]{1..;xm}', 'does not process')
# 	('1244', 'b:StructureQuery', '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}', 'does not process')
# ('1248', 'b:ParameterQuery', 'log Kow', 13.6999998092651, 'GreaterThan', 'does not process')
# ('1251', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1254', 'LogicalQuery', 'And', 'does not process')
# 	('1248', 'b:ParameterQuery', 'log Kow', 13.6999998092651, 'GreaterThan', 'does not process')
# 	('1251', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1256', 'LogicalQuery', 'And', 'does not process')
# 	('1246', 'LogicalQuery', 'Or', 'does not process')
# 		('1242', 'b:StructureQuery', '[Sn]$[c,[#6X4],[#1]]{1..;xm}', 'does not process')
# 		('1244', 'b:StructureQuery', '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}', 'does not process')
# 	('1254', 'LogicalQuery', 'And', 'does not process')
# ...
# ('1375', 'b:StructureQuery', '[#6][#16hv2]', 'does not process')
# ('1377', 'b:ParameterQuery', 'log Kow', 6.5, 'GreaterThanOrEqualTo', 'does not process')
# ('1380', 'b:ParameterQuery', 'log Kow', 9.0, 'LessThan', 'does not process')
# ('1383', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1386', 'LogicalQuery', 'And', 'does not process')
# 	('1375', 'b:StructureQuery', '[#6][#16hv2]', 'does not process')
# 	('1377', 'b:ParameterQuery', 'log Kow', 6.5, 'GreaterThanOrEqualTo', 'does not process')
# 	('1380', 'b:ParameterQuery', 'log Kow', 9.0, 'LessThan', 'does not process')
# 	('1383', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1397', 'b:StructureQuery', '[#6][#6](=[#8])[#8][#6h]=[#6h2]', 'does not process')
# ('1399', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# ('1402', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# ('1405', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1408', 'LogicalQuery', 'And', 'does not process')
# 	('1397', 'b:StructureQuery', '[#6][#6](=[#8])[#8][#6h]=[#6h2]', 'does not process')
# 	('1399', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1402', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1405', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1419', 'b:StructureQuery', '[#7]#[#7+]c', 'does not process')
# ('1421', 'b:ParameterQuery', 'log Kow', 8.0, 'GreaterThanOrEqualTo', 'does not process')
# ('1424', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1427', 'LogicalQuery', 'And', 'does not process')
# 	('1419', 'b:StructureQuery', '[#7]#[#7+]c', 'does not process')
# 	('1421', 'b:ParameterQuery', 'log Kow', 8.0, 'GreaterThanOrEqualTo', 'does not process')
# 	('1424', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1438', 'b:StructureQuery', '[#8]{>-1}$[[#1],$[[#6X4]]{..7}]{1..;x}.$[c,$[[#6X4]]{..7},[#1]]{1..;x}{<-1}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..3}', 'does not process')
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#7](=[#8])$[[#1],[#6X4]]{1..;xm}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#7](=[#8])$[[#1],[#6X4]]{1..;xm}' for input: '[#7](=[#8])$[[#1],[#6X4]]{1..;xm}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: $[[#1],[#6X4]]{1..;xm}[#7+][#8-]
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '$[[#1],[#6X4]]{1..;xm}[#7+][#8-]' for input: '$[[#1],[#6X4]]{1..;xm}[#7+][#8-]'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: c1ccccc1.$[[#1],$[[#6X4]]{1..}]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS 'c1ccccc1.$[[#1],$[[#6X4]]{1..}]{1..;x}' for input: 'c1ccccc1.$[[#1],$[[#6X4]]{1..}]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: $[$[[#6X4]]{1..}]{1..;x}[Cl,Br,#8h]
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '$[$[[#6X4]]{1..}]{1..;x}[Cl,Br,#8h]' for input: '$[$[[#6X4]]{1..}]{1..;x}[Cl,Br,#8h]'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#8]{>-1}$[[#1],[#6X4]]{1..;x}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..5}.[#6X4]{<-1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#8]{>-1}$[[#1],[#6X4]]{1..;x}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..5}.[#6X4]{<-1}' for input: '[#8]{>-1}$[[#1],[#6X4]]{1..;x}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..5}.[#6X4]{<-1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [Sn]$[c,[#6X4],[#1]]{1..;xm}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[Sn]$[c,[#6X4],[#1]]{1..;xm}' for input: '[Sn]$[c,[#6X4],[#1]]{1..;xm}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}' for input: '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}' for input: '[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: c1(ccc(cc1)[#7v3,#8]{>-1})[C](c1ccc(cc1)[#7v3,#8]{>-1})=[C]1[C]=[C][C]([C]=[C]1)=[#7hv3,#8].$[[Ch3]{<-1},[Ch2]{<-1}[Ch3],[#1]{<-1}]{2}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS 'c1(ccc(cc1)[#7v3,#8]{>-1})[C](c1ccc(cc1)[#7v3,#8]{>-1})=[C]1[C]=[C][C]([C]=[C]1)=[#7hv3,#8].$[[Ch3]{<-1},[Ch2]{<-1}[Ch3],[#1]{<-1}]{2}' for input: 'c1(ccc(cc1)[#7v3,#8]{>-1})[C](c1ccc(cc1)[#7v3,#8]{>-1})=[C]1[C]=[C][C]([C]=[C]1)=[#7hv3,#8].$[[Ch3]{<-1},[Ch2]{<-1}[Ch3],[#1]{<-1}]{2}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: $[[#6](=[#8])[#8h],[#16v6](=[#8])(=[#8])[#8h],F,Cl,Br,I]
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '$[[#6](=[#8])[#8h],[#16v6](=[#8])(=[#8])[#8h],F,Cl,Br,I]' for input: '$[[#6](=[#8])[#8h],[#16v6](=[#8])(=[#8])[#8h],F,Cl,Br,I]'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [Si][#8]$[[#6X4]]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[Si][#8]$[[#6X4]]{1..;x}' for input: '[Si][#8]$[[#6X4]]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: c1([#6,#7,#8,#16]c2cc{>-1}c{>-1}c{>-1}c2)cc{>-2}c{>-2}c{>-2}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS 'c1([#6,#7,#8,#16]c2cc{>-1}c{>-1}c{>-1}c2)cc{>-2}c{>-2}c{>-2}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}' for input: 'c1([#6,#7,#8,#16]c2cc{>-1}c{>-1}c{>-1}c2)cc{>-2}c{>-2}c{>-2}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: c1([#6,#7,#8,#16]{>-3})cc{>-2}c{>-2}c{>-2}c1.$[c1c([#6]{>-3})cccc{<-3}1,c1c([#7]{>-3})cccc{<-3}1,c1c([#8]{>-3})cccc{<-3}1,c1c([#16]{>-3})cccc{<-3}1]{1..5}.c{<-3}1cc{>-1}c{>-1}c{>-1}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS 'c1([#6,#7,#8,#16]{>-3})cc{>-2}c{>-2}c{>-2}c1.$[c1c([#6]{>-3})cccc{<-3}1,c1c([#7]{>-3})cccc{<-3}1,c1c([#8]{>-3})cccc{<-3}1,c1c([#16]{>-3})cccc{<-3}1]{1..5}.c{<-3}1cc{>-1}c{>-1}c{>-1}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}' for input: 'c1([#6,#7,#8,#16]{>-3})cc{>-2}c{>-2}c{>-2}c1.$[c1c([#6]{>-3})cccc{<-3}1,c1c([#7]{>-3})cccc{<-3}1,c1c([#8]{>-3})cccc{<-3}1,c1c([#16]{>-3})cccc{<-3}1]{1..5}.c{<-3}1cc{>-1}c{>-1}c{>-1}c1.$[[#7h2]{<-2}]{1}.$[[#7h2]{<-1}]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: c{>-1}1c{>-1}([#16](=[#8])(=[#8])[#8])c{>-1}c{>-1}c{>-1}c{>-1}1.$[$[$[[#6h2]]{2..},[#8]]{1..;x}{<-1}]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS 'c{>-1}1c{>-1}([#16](=[#8])(=[#8])[#8])c{>-1}c{>-1}c{>-1}c{>-1}1.$[$[$[[#6h2]]{2..},[#8]]{1..;x}{<-1}]{1}' for input: 'c{>-1}1c{>-1}([#16](=[#8])(=[#8])[#8])c{>-1}c{>-1}c{>-1}c{>-1}1.$[$[$[[#6h2]]{2..},[#8]]{1..;x}{<-1}]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#8]=[#16](=[#8])([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#8]=[#16](=[#8])([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}' for input: '[#8]=[#16](=[#8])([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#15](=[#8])([#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#15](=[#8])([#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}' for input: '[#15](=[#8])([#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#8]=[#6]([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#8]=[#6]([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}' for input: '[#8]=[#6]([#8])$[$[[#6h2]]{2..},[#8]]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [Si](=[#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[Si](=[#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}' for input: '[Si](=[#8])([#8])[#8]$[$[[#6h2]]{2..},[#8]]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}' for input: '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: c1([#7h2v3])c(c2c([ch][ch]1)c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}2)[Oh,#1].$[[#8h]{<-2},[#7h2]{<-2},[#1]{<-2}]{1}.$[[#16]{<-1}(=[#8])(=[#8])[#8h],[#6h2]([#6h2][#16](=[#8])(=[#8])[#8h])[#16]{<-1}(=[#8])=[#8]]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS 'c1([#7h2v3])c(c2c([ch][ch]1)c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}2)[Oh,#1].$[[#8h]{<-2},[#7h2]{<-2},[#1]{<-2}]{1}.$[[#16]{<-1}(=[#8])(=[#8])[#8h],[#6h2]([#6h2][#16](=[#8])(=[#8])[#8h])[#16]{<-1}(=[#8])=[#8]]{1}' for input: 'c1([#7h2v3])c(c2c([ch][ch]1)c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}c{>-2}{>-1}2)[Oh,#1].$[[#8h]{<-2},[#7h2]{<-2},[#1]{<-2}]{1}.$[[#16]{<-1}(=[#8])(=[#8])[#8h],[#6h2]([#6h2][#16](=[#8])(=[#8])[#8h])[#16]{<-1}(=[#8])=[#8]]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: c1(:,-c2c{>-2}c{>-2}c{>-2}c{>-2}c{>-2}2)c{>-1}c{>-1}c{>-1}c{>-1}c{>-1}1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS 'c1(:,-c2c{>-2}c{>-2}c{>-2}c{>-2}c{>-2}2)c{>-1}c{>-1}c{>-1}c{>-1}c{>-1}1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}' for input: 'c1(:,-c2c{>-2}c{>-2}c{>-2}c{>-2}c{>-2}2)c{>-1}c{>-1}c{>-1}c{>-1}c{>-1}1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#6](Cl)(Cl)(Cl)[#6](c1ccc{>-2}cc1)c1ccc{>-1}cc1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#6](Cl)(Cl)(Cl)[#6](c1ccc{>-2}cc1)c1ccc{>-1}cc1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}' for input: '[#6](Cl)(Cl)(Cl)[#6](c1ccc{>-2}cc1)c1ccc{>-1}cc1.$[Cl{<-2}]{1}.$[Cl{<-1}]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}' for input: '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}' for input: '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[s][#6]([#7]=[#7]{>-2})[n]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[s][#6]([#7]=[#7]{>-2})[n]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}' for input: '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[s][#6]([#7]=[#7]{>-2})[n]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[#16][#6](c1ccc(cc1)[#7]=[#7]{>-2})[#7]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[#16][#6](c1ccc(cc1)[#7]=[#7]{>-2})[#7]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}' for input: '[c~1]{>-1}1c2c([c~1]{>-1}[c~1]{>-1}[c~1]{>-1}1)[#16][#6](c1ccc(cc1)[#7]=[#7]{>-2})[#7]2.$[c1cc([#7h2])ccc{<-2}1,c1cc([#7h2])ccc1[#7h]{<-2}]{1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8]=[#7+]{<-1}[#8-]]{1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}' for input: '[#16v2][#6](=[#16])[#7v3]([#6X4]$[[#6X4]]{1..;x})[#6X4]$[[#6X4]]{1..;x}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [Sn]$[c,[#6X4],[#1]]{1..;xm}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[Sn]$[c,[#6X4],[#1]]{1..;xm}' for input: '[Sn]$[c,[#6X4],[#1]]{1..;xm}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}' for input: '[Sn]($[c,[#6X4],[#1]]{1..;xs})[#8][Sn]$[c,[#6X4],[#1]]{1..;xs}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}' for input: '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{2..3}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}' for input: '[a~1]{>-1}1[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}[a~1]{>-1}1.$[$[[#6]]{..6},$[[#7]]{..1}]{~1}.$[[#8]=[#7+v5]{<-1}[#8-]]{4}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}' for input: '[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[#6]]{3},$[[#7]]{3}]{~1}'
# RDKit ERROR: [18:15:44] SMARTS Parse Error: syntax error while parsing: [#8]{>-1}$[[#1],$[[#6X4]]{..7}]{1..;x}.$[c,$[[#6X4]]{..7},[#1]]{1..;x}{<-1}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..3}
# RDKit ERROR: [18:15:44] SMARTS Parse Error: Failed parsing SMARTS '[#8]{>-1}$[[#1],$[[#6X4]]{..7}]{1..;x}.$[c,$[[#6X4]]{..7},[#1]]{1..;x}{<-1}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..3}' for input: '[#8]{>-1}$[[#1],$[[#6X4]]{..7}]{1..;x}.$[c,$[[#6X4]]{..7},[#1]]{1..;x}{<-1}.$[[#6h2]{<-1}[#6h2][#8]{>-1}]{1..3}'

# %%
#print_tests

# %%
all_tests['Acid Chlorides']

# %%
tests=all_tests.copy()
for category in bad_cats:
    del tests[category]

# %%
tests['Acid Chlorides']

# %%
tests['Acid Chlorides']

# %%
len(tests)
# Out:
# 47

# %%
import json

# Create a dictionary to hold the JSON data
json_data = {}

# Iterate through each category in the tests dictionary
for category, query_instance in tests.items():
    # Call the updated print_tree method to get SMARTS and logic parameters
    smart_patterns, logic_parameters = query_instance.print_tree(query_instance.query)

    # Store the results in the json_data dictionary
    json_data[category] = {
        "SMARTS Patterns": smart_patterns,
        "Logic Parameters": logic_parameters
    }

# Convert the dictionary to a JSON string
json_output = json.dumps(json_data, indent=4)

# Print or save the JSON output
print(json_output)

# Optionally, save it to a file
with open(external_dir+'output_tests47.json', 'w') as json_file:
    json_file.write(json_output)
# Out:
# ('32', 'LogicalQuery', 'And', 'does not process')
# 	('29', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('26', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('24', 'b:StructureQuery', '[#6,#16](=[#8])(Cl)[#6X4,c]', 'does not process')
# ('51', 'LogicalQuery', 'And', 'does not process')
# 	('48', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('45', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('43', 'b:StructureQuery', '[#6](=[#8])([#7h])[#6](=[#6h2])[Ch3,#1]', 'does not process')
# ('70', 'LogicalQuery', 'And', 'does not process')
# 	('67', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('64', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('62', 'b:StructureQuery', '[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]', 'does not process')
# ('89', 'LogicalQuery', 'And', 'does not process')
# 	('86', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('83', 'b:ParameterQuery', 'log Kow', 6.0, 'LessThan', 'does not process')
# 	('81', 'b:StructureQuery', '[#6h](=[#8])[#6,#1]', 'does not process')
# ('140', 'LogicalQuery', 'And', 'does not process')
# 	('132', 'b:StructureQuery', '[Al]', 'does not process')
# 	('134', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('137', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThan', 'does not process')
# ('159', 'LogicalQuery', 'And', 'does not process')
# 	('151', 'b:StructureQuery', 'c1c([#7h2v3])cccc1', 'does not process')
# 	('153', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'LessThan', 'does not process')
# 	('156', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('184', 'LogicalQuery', 'And', 'does not process')
# 	('174', 'LogicalQuery', 'Or', 'does not process')
# 		('170', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# 		('172', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# 	('182', 'LogicalQuery', 'And', 'does not process')
# 		('176', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 		('179', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('203', 'LogicalQuery', 'And', 'does not process')
# 	('195', 'b:StructureQuery', 'c12c(cccc1)[#7]=,:[#7][#7v3]2', 'does not process')
# 	('197', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('200', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('214', 'b:StructureQuery', '[c]12[c]([n][n]([n]1)-c1c(cccc1)[#8h])[c][c][c][c]2', 'does not process')
# ('230', 'LogicalQuery', 'And', 'does not process')
# 	('225', 'b:StructureQuery', '[#5]', 'does not process')
# 	('227', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('241', 'b:StructureQuery', '[#7+]([#6])([#6])([#6])[#6]', 'does not process')
# ('263', 'LogicalQuery', 'And', 'does not process')
# 	('252', 'b:StructureQuery', '[Co]', 'does not process')
# 	('254', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('257', 'b:ParameterQuery', 'Molecular Weight', 1000.0, 'LessThan', 'does not process')
# 	('260', 'b:ParameterQuery', 'Water Solubility', 1.0, 'GreaterThanOrEqualTo', 'does not process')
# ('282', 'LogicalQuery', 'And', 'does not process')
# 	('274', 'b:StructureQuery', '[#7]#[#7+]c', 'does not process')
# 	('276', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('279', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('298', 'LogicalQuery', 'And', 'does not process')
# 	('293', 'b:StructureQuery', '[#6]1[#8][#6]1', 'does not process')
# 	('295', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('317', 'LogicalQuery', 'And', 'does not process')
# 	('309', 'b:StructureQuery', '[#6]([#6])(=[#8])[#8R0][#6]', 'does not process')
# 	('311', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('314', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('336', 'LogicalQuery', 'And', 'does not process')
# 	('332', 'LogicalQuery', 'Or', 'does not process')
# 		('330', 'b:StructureQuery', '[#6]=[#7R0v3][#7R0v3]', 'does not process')
# 		('328', 'b:StructureQuery', '[#7R0v3][#7R0v3]', 'does not process')
# 		(None, 'b:StructureQuery', '[#6](=[#8])([#7hv3][#7R0v3])[Nh,*]', 'does not process')
# ('350', 'b:StructureQuery', '[#6]1([#6h3])([#6h3])[#6][#6][#6][#6]([#6h3])([#6h3])[#7v3]1', 'does not process')
# ('369', 'LogicalQuery', 'And', 'does not process')
# 	('361', 'b:StructureQuery', '[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]', 'does not process')
# 	('363', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThanOrEqualTo', 'does not process')
# 	('366', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('382', 'LogicalQuery', 'And', 'does not process')
# 	('380', 'b:StructureQuery', '[La,Ce,Pr,Nd,Sm,Eu,Gd,Tb,Dy,Ho,Er,Tm,Yb,Lu]', 'does not process')
# ('506', 'LogicalQuery', 'And', 'does not process')
# 	('501', 'b:StructureQuery', '[Ni]', 'does not process')
# 	('503', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('563', 'LogicalQuery', 'Or', 'does not process')
# 	('553', 'b:StructureQuery', '[#6X4][#8][#8][#6X4]', 'does not process')
# 	('555', 'b:StructureQuery', '[#6X4][#8][#8h]', 'does not process')
# 	('557', 'b:StructureQuery', '[#6](=[#8])[#8][#8][#6]', 'does not process')
# 	('559', 'b:StructureQuery', '[#6](=[#8])[#8][#8][#6]=[#8]', 'does not process')
# 	('561', 'b:StructureQuery', '[#6](=[#8])[#8][#8h]', 'does not process')
# ('574', 'b:StructureQuery', 'c1([#6]2(c3ccc([#8])cc3)c3c([#6](=[#8])[#8]2)cccc3)ccc([#8])cc1', 'does not process')
# ('605', 'LogicalQuery', 'And', 'does not process')
# 	('595', 'LogicalQuery', 'And', 'does not process')
# 		('585', 'b:StructureQuery', 'c1ccccc1[#8h]', 'does not process')
# 		('589', 'LogicalQuery', 'Not', 'does not process')
# 			('587', 'b:StructureQuery', 'c12c(cccc1)cccc2', 'does not process')
# 		('593', 'LogicalQuery', 'Not', 'does not process')
# 			('591', 'b:StructureQuery', 'c1(-c2ccccc2)ccccc1', 'does not process')
# 	('603', 'LogicalQuery', 'And', 'does not process')
# 		('597', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 		('600', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'LessThan', 'does not process')
# ('622', 'LogicalQuery', 'And', 'does not process')
# 	('616', 'b:StructureQuery', '[#8][#15v5](=[#8])([#8])[#8]', 'does not process')
# 	('620', 'LogicalQuery', 'Not', 'does not process')
# 		('618', 'b:StructureQuery', '[#6]', 'does not process')
# ('641', 'LogicalQuery', 'And', 'does not process')
# 	('633', 'b:StructureQuery', '[#6][#8][#15v5](=[#8])([#6])[#6]', 'does not process')
# 	('635', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('638', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('652', 'b:StructureQuery', 'c1([#16](=[#8])(=[#8])[#8])c([#6h]=[#6h]c2c([#16](=[#8])(=[#8])[#8])cc([#7h]c3nc([#6X4])nc([#6X4])n3)cc2)ccc([#7h]c2nc([#6X4])nc([#6X4])n2)c1', 'does not process')
# ('671', 'LogicalQuery', 'And', 'does not process')
# 	('663', 'b:StructureQuery', '[#6][#16hv2]', 'does not process')
# 	('665', 'b:ParameterQuery', 'log Kow', 6.5, 'LessThan', 'does not process')
# 	('668', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('729', 'LogicalQuery', 'And', 'does not process')
# 	('721', 'b:StructureQuery', '[#6][#6](=[#8])[#8][#6h]=[#6h2]', 'does not process')
# 	('723', 'b:ParameterQuery', 'log Kow', 5.0, 'LessThan', 'does not process')
# 	('726', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('754', 'LogicalQuery', 'And', 'does not process')
# 	('744', 'LogicalQuery', 'Or', 'does not process')
# 		('740', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h]=[#6h]', 'does not process')
# 		('742', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#6h2][#6h2][#8][#16v6](=[#8])(=[#8])[#8]', 'does not process')
# 	('752', 'LogicalQuery', 'And', 'does not process')
# 		('746', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 		('749', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('779', 'LogicalQuery', 'And', 'does not process')
# 	('771', 'LogicalQuery', 'Not', 'does not process')
# 		('769', 'b:StructureQuery', '[#6](=[#8])[#8-].[Zn+2]', 'does not process')
# 	('775', 'LogicalQuery', 'Not', 'does not process')
# 		('773', 'b:StructureQuery', '[#15](=[#8])([#8])([#8])[#8-].[Zn+2]', 'does not process')
# 	('777', 'LogicalQuery', 'Or', 'does not process')
# 		('765', 'b:StructureQuery', '[Zn]', 'does not process')
# 		('767', 'b:StructureQuery', '[#16v6](=[#8])(=[#8])[#8-].[Zn+2]', 'does not process')
# ('795', 'LogicalQuery', 'And', 'does not process')
# 	('790', 'b:StructureQuery', '[#6](=[#8])([#6])[#8][#6](=[#8])[#6]', 'does not process')
# 	('792', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('806', 'b:StructureQuery', 'c1(-c2cc(Cl)c([#7]=[#7][#6]([#6]([#6])=[#8])[#6](=[#8])[#7]c3ccccc3)cc2)cc(Cl)c([#7]=[#7][#6]([#6]([#6])=[#8])[#6](=[#8])[#7]c2ccccc2)cc1', 'does not process')
# ('822', 'LogicalQuery', 'And', 'does not process')
# 	('817', 'b:StructureQuery', '[#7]=[#6]=[#8].[#7]=[#6]=[#8]', 'does not process')
# 	('819', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1012', 'LogicalQuery', 'And', 'does not process')
# 	('1002', 'LogicalQuery', 'Or', 'does not process')
# 		('998', 'b:StructureQuery', '[#6](=[#8])([#8])[#6]1([#6])[#6]2[#6]([#6])([#6]3[#6]([#6]=[#6]([#6]([#6])[#6])[#6][#6]3)=[#6][#6]2)[#6][#6][#6]1', 'does not process')
# 		('1000', 'b:StructureQuery', 'c1([#6]=[#6][#6][#8][#6]2[#6]([#8])[#6]([#8])[#6]([#8])[#6]([#6][#8])[#8]2)ccccc1', 'does not process')
# 	('1010', 'LogicalQuery', 'And', 'does not process')
# 		('1004', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 		('1007', 'b:ParameterQuery', 'Water Solubility', 0.00100000004749745, 'GreaterThan', 'does not process')
# ('1028', 'LogicalQuery', 'And', 'does not process')
# 	('1023', 'b:StructureQuery', '[Zr]', 'does not process')
# 	('1025', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1065', 'LogicalQuery', 'And', 'does not process')
# 	('1062', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('1059', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1056', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1054', 'b:StructureQuery', '[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]', 'does not process')
# ('1087', 'LogicalQuery', 'And', 'does not process')
# 	('1084', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# 	('1081', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThanOrEqualTo', 'does not process')
# 	('1078', 'b:ParameterQuery', 'log Kow', 6.0, 'GreaterThan', 'does not process')
# 	('1076', 'b:StructureQuery', '[#6h](=[#8])[#6,#1]', 'does not process')
# ('1109', 'LogicalQuery', 'And', 'does not process')
# 	('1098', 'b:StructureQuery', 'c1c([#7h2v3])cccc1', 'does not process')
# 	('1100', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'GreaterThan', 'does not process')
# 	('1103', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1106', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1137', 'LogicalQuery', 'And', 'does not process')
# 	('1124', 'LogicalQuery', 'Or', 'does not process')
# 		('1120', 'b:StructureQuery', '[#7-]=[#7+]=[#7]', 'does not process')
# 		('1122', 'b:StructureQuery', '[#7]=[#7]#[#7]', 'does not process')
# 	('1135', 'LogicalQuery', 'And', 'does not process')
# 		('1126', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 		('1129', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 		('1132', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1159', 'LogicalQuery', 'And', 'does not process')
# 	('1148', 'b:StructureQuery', 'c12c(cccc1)[#7]=,:[#7][#7v3]2', 'does not process')
# 	('1150', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1153', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1156', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1209', 'LogicalQuery', 'And', 'does not process')
# 	('1198', 'b:StructureQuery', '[#6]([#6])(=[#8])[#8R0][#6]', 'does not process')
# 	('1200', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1203', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1206', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1231', 'LogicalQuery', 'And', 'does not process')
# 	('1220', 'b:StructureQuery', '[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]', 'does not process')
# 	('1222', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1225', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThanOrEqualTo', 'does not process')
# 	('1228', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1290', 'LogicalQuery', 'And', 'does not process')
# 	('1277', 'LogicalQuery', 'And', 'does not process')
# 		('1267', 'b:StructureQuery', 'c1ccccc1[#8h]', 'does not process')
# 		('1273', 'LogicalQuery', 'Not', 'does not process')
# 			('1269', 'b:StructureQuery', 'c12c(cccc1)cccc2', 'does not process')
# 		('1275', 'LogicalQuery', 'Not', 'does not process')
# 			('1271', 'b:StructureQuery', 'c1(-c2ccccc2)ccccc1', 'does not process')
# 	('1288', 'LogicalQuery', 'And', 'does not process')
# 		('1279', 'b:ParameterQuery', 'log Kow', 7.38000011444092, 'GreaterThan', 'does not process')
# 		('1282', 'b:ParameterQuery', 'log Kow', 9.0, 'LessThan', 'does not process')
# 		('1285', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1312', 'LogicalQuery', 'And', 'does not process')
# 	('1301', 'b:StructureQuery', '[#6][#8][#15v5](=[#8])([#6])[#6]', 'does not process')
# 	('1303', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1306', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1309', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1386', 'LogicalQuery', 'And', 'does not process')
# 	('1375', 'b:StructureQuery', '[#6][#16hv2]', 'does not process')
# 	('1377', 'b:ParameterQuery', 'log Kow', 6.5, 'GreaterThanOrEqualTo', 'does not process')
# 	('1380', 'b:ParameterQuery', 'log Kow', 9.0, 'LessThan', 'does not process')
# 	('1383', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1408', 'LogicalQuery', 'And', 'does not process')
# 	('1397', 'b:StructureQuery', '[#6][#6](=[#8])[#8][#6h]=[#6h2]', 'does not process')
# 	('1399', 'b:ParameterQuery', 'log Kow', 5.0, 'GreaterThan', 'does not process')
# 	('1402', 'b:ParameterQuery', 'log Kow', 8.0, 'LessThan', 'does not process')
# 	('1405', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# ('1427', 'LogicalQuery', 'And', 'does not process')
# 	('1419', 'b:StructureQuery', '[#7]#[#7+]c', 'does not process')
# 	('1421', 'b:ParameterQuery', 'log Kow', 8.0, 'GreaterThanOrEqualTo', 'does not process')
# 	('1424', 'b:ParameterQuery', 'Molecular weight', 1000.0, 'LessThan', 'does not process')
# {
#     "Acid Chlorides": {
#         "SMARTS Patterns": [
#             "[#6,#16](=[#8])(Cl)[#6X4,c]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Acrylamides": {
#         "SMARTS Patterns": [
#             "[#6](=[#8])([#7h])[#6](=[#6h2])[Ch3,#1]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Acrylates/Methacrylates (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 5.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Aldehydes (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#6h](=[#8])[#6,#1]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 6.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Aluminum Compounds": {
#         "SMARTS Patterns": [
#             "[Al]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "Water Solubility",
#                 1.0,
#                 "GreaterThan"
#             ]
#         ]
#     },
#     "Anilines (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "c1c([#7h2v3])cccc1"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 7.38000011444092,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Azides (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#7-]=[#7+]=[#7]",
#             "[#7]=[#7]#[#7]"
#         ],
#         "Logic Parameters": [
#             "And",
#             "Or",
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Benzotriazoles (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "c12c(cccc1)[#7]=,:[#7][#7v3]2"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Benzotriazole-hindered phenols": {
#         "SMARTS Patterns": [
#             "[c]12[c]([n][n]([n]1)-c1c(cccc1)[#8h])[c][c][c][c]2"
#         ],
#         "Logic Parameters": []
#     },
#     "Boron Compounds": {
#         "SMARTS Patterns": [
#             "[#5]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Cationic (quaternary ammonium) surfactants": {
#         "SMARTS Patterns": [
#             "[#7+]([#6])([#6])([#6])[#6]"
#         ],
#         "Logic Parameters": []
#     },
#     "Cobalt": {
#         "SMARTS Patterns": [
#             "[Co]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular Weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "Water Solubility",
#                 1.0,
#                 "GreaterThanOrEqualTo"
#             ]
#         ]
#     },
#     "Diazoniums (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#7]#[#7+]c"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Epoxides": {
#         "SMARTS Patterns": [
#             "[#6]1[#8][#6]1"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Esters (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#6]([#6])(=[#8])[#8R0][#6]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Hydrazines and Related Compounds": {
#         "SMARTS Patterns": [
#             "[#6]=[#7R0v3][#7R0v3]",
#             "[#7R0v3][#7R0v3]",
#             "[#6](=[#8])([#7hv3][#7R0v3])[Nh,*]"
#         ],
#         "Logic Parameters": [
#             "And",
#             "Or"
#         ]
#     },
#     "Hindered Amines": {
#         "SMARTS Patterns": [
#             "[#6]1([#6h3])([#6h3])[#6][#6][#6][#6]([#6h3])([#6h3])[#7v3]1"
#         ],
#         "Logic Parameters": []
#     },
#     "Imides (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "LessThanOrEqualTo"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Lanthanides or Rare Earth Metals": {
#         "SMARTS Patterns": [
#             "[La,Ce,Pr,Nd,Sm,Eu,Gd,Tb,Dy,Ho,Er,Tm,Yb,Lu]"
#         ],
#         "Logic Parameters": [
#             "And"
#         ]
#     },
#     "Nickel Compounds": {
#         "SMARTS Patterns": [
#             "[Ni]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Peroxides": {
#         "SMARTS Patterns": [
#             "[#6X4][#8][#8][#6X4]",
#             "[#6X4][#8][#8h]",
#             "[#6](=[#8])[#8][#8][#6]",
#             "[#6](=[#8])[#8][#8][#6]=[#8]",
#             "[#6](=[#8])[#8][#8h]"
#         ],
#         "Logic Parameters": [
#             "Or"
#         ]
#     },
#     "Phenolphthaleins": {
#         "SMARTS Patterns": [
#             "c1([#6]2(c3ccc([#8])cc3)c3c([#6](=[#8])[#8]2)cccc3)ccc([#8])cc1"
#         ],
#         "Logic Parameters": []
#     },
#     "Phenols (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "c1ccccc1[#8h]",
#             "c12c(cccc1)cccc2",
#             "c1(-c2ccccc2)ccccc1"
#         ],
#         "Logic Parameters": [
#             "And",
#             "And",
#             "Not",
#             "Not",
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 7.38000011444092,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Phosphates, Inorganic": {
#         "SMARTS Patterns": [
#             "[#8][#15v5](=[#8])([#8])[#8]",
#             "[#6]"
#         ],
#         "Logic Parameters": [
#             "And",
#             "Not"
#         ]
#     },
#     "Phosphinate Esters (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#6][#8][#15v5](=[#8])([#6])[#6]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Stilbene, derivatives of 4,4-bis(triazin-2-ylamino)-": {
#         "SMARTS Patterns": [
#             "c1([#16](=[#8])(=[#8])[#8])c([#6h]=[#6h]c2c([#16](=[#8])(=[#8])[#8])cc([#7h]c3nc([#6X4])nc([#6X4])n3)cc2)ccc([#7h]c2nc([#6X4])nc([#6X4])n2)c1"
#         ],
#         "Logic Parameters": []
#     },
#     "Thiols (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#6][#16hv2]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 6.5,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Vinyl Esters (Acute toxicity)": {
#         "SMARTS Patterns": [
#             "[#6][#6](=[#8])[#8][#6h]=[#6h2]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Vinyl Sulfones": {
#         "SMARTS Patterns": [
#             "[#16v6](=[#8])(=[#8])[#6h]=[#6h]",
#             "[#16v6](=[#8])(=[#8])[#6h2][#6h2][#8][#16v6](=[#8])(=[#8])[#8]"
#         ],
#         "Logic Parameters": [
#             "And",
#             "Or",
#             "And",
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Soluble complexes of Zinc": {
#         "SMARTS Patterns": [
#             "[#6](=[#8])[#8-].[Zn+2]",
#             "[#15](=[#8])([#8])([#8])[#8-].[Zn+2]",
#             "[Zn]",
#             "[#16v6](=[#8])(=[#8])[#8-].[Zn+2]"
#         ],
#         "Logic Parameters": [
#             "And",
#             "Not",
#             "Not",
#             "Or"
#         ]
#     },
#     "Anhydrides, Carboxylic acid": {
#         "SMARTS Patterns": [
#             "[#6](=[#8])([#6])[#8][#6](=[#8])[#6]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Dichlorobenzidine-based Pigments": {
#         "SMARTS Patterns": [
#             "c1(-c2cc(Cl)c([#7]=[#7][#6]([#6]([#6])=[#8])[#6](=[#8])[#7]c3ccccc3)cc2)cc(Cl)c([#7]=[#7][#6]([#6]([#6])=[#8])[#6](=[#8])[#7]c2ccccc2)cc1"
#         ],
#         "Logic Parameters": []
#     },
#     "Diisocyanates": {
#         "SMARTS Patterns": [
#             "[#7]=[#6]=[#8].[#7]=[#6]=[#8]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Rosin": {
#         "SMARTS Patterns": [
#             "[#6](=[#8])([#8])[#6]1([#6])[#6]2[#6]([#6])([#6]3[#6]([#6]=[#6]([#6]([#6])[#6])[#6][#6]3)=[#6][#6]2)[#6][#6][#6]1",
#             "c1([#6]=[#6][#6][#8][#6]2[#6]([#8])[#6]([#8])[#6]([#8])[#6]([#6][#8])[#8]2)ccccc1"
#         ],
#         "Logic Parameters": [
#             "And",
#             "Or",
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "Water Solubility",
#                 0.00100000004749745,
#                 "GreaterThan"
#             ]
#         ]
#     },
#     "Zirconium Compounds": {
#         "SMARTS Patterns": [
#             "[Zr]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Acrylates/Methacrylates (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#6h2]=[#6]([#6](=[#8])[#8])[Ch3,#1]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 5.0,
#                 "GreaterThan"
#             ]
#         ]
#     },
#     "Aldehydes (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#6h](=[#8])[#6,#1]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThanOrEqualTo"
#             ],
#             [
#                 "log Kow",
#                 6.0,
#                 "GreaterThan"
#             ]
#         ]
#     },
#     "Anilines (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "c1c([#7h2v3])cccc1"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 7.38000011444092,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Azides (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#7-]=[#7+]=[#7]",
#             "[#7]=[#7]#[#7]"
#         ],
#         "Logic Parameters": [
#             "And",
#             "Or",
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Benzotriazoles (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "c12c(cccc1)[#7]=,:[#7][#7v3]2"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Esters (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#6]([#6])(=[#8])[#8R0][#6]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Imides (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#6](=[#8])([#6])[#7v3][#6]([#6])=[#8]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThanOrEqualTo"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Phenols (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "c1ccccc1[#8h]",
#             "c12c(cccc1)cccc2",
#             "c1(-c2ccccc2)ccccc1"
#         ],
#         "Logic Parameters": [
#             "And",
#             "And",
#             "Not",
#             "Not",
#             "And",
#             [
#                 "log Kow",
#                 7.38000011444092,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 9.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Phosphinate Esters (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#6][#8][#15v5](=[#8])([#6])[#6]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Thiols (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#6][#16hv2]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 6.5,
#                 "GreaterThanOrEqualTo"
#             ],
#             [
#                 "log Kow",
#                 9.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Vinyl Esters (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#6][#6](=[#8])[#8][#6h]=[#6h2]"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 5.0,
#                 "GreaterThan"
#             ],
#             [
#                 "log Kow",
#                 8.0,
#                 "LessThan"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     },
#     "Diazoniums (Chronic toxicity)": {
#         "SMARTS Patterns": [
#             "[#7]#[#7+]c"
#         ],
#         "Logic Parameters": [
#             "And",
#             [
#                 "log Kow",
#                 8.0,
#                 "GreaterThanOrEqualTo"
#             ],
#             [
#                 "Molecular weight",
#                 1000.0,
#                 "LessThan"
#             ]
#         ]
#     }
# }

# %% [markdown]
# <h1>Fix bad SMARTS</h1>

# %%
len(bad_cats)
# Out:
# 19

# %%
class ChemicalTest:
    def __init__(self, name, smart_patterns, conditions, test_func):
        self.name = name
        self.smart_patterns = smart_patterns  # List of SMARTS patterns
        self.conditions = conditions  # Description of the logic
        self.test_func = test_func  # The actual test function

    def create_test_function(self):
        # Define the test function based on SMARTS patterns and conditions
        def test(x):
            mol = x['mol']
            mw = x['mol_weight']
            smiles = x['smiles']
            
            
            # Add any other required parameters from `x`
            # Evaluate conditions based on the SMARTS patterns
            match_found = any(mol.HasSubstructMatch(sp) for sp in self.smart_patterns)
            # Example condition evaluation (adjust as needed)
            return match_found and eval(self.conditions)
        return test

    def add_to_new_tests(self, new_tests):
        # Create the test function and add it to the new_tests dictionary
        self.test_func = self.create_test_function()
        new_tests[self.name] = self
    
    def get_details(self):
        """Returns the SMARTS patterns, conditions, and test function for this chemical test."""
        return {
            'name': self.name,
            'smart_patterns': [sp for sp in self.smart_patterns],
            'conditions': self.conditions,
            'test_func': self.test_func
        }

# %%
new_tests = {}

# %%
#Epoxides

epoxide=Chem.MolFromSmarts('c1oc1')
aziridine=Chem.MolFromSmarts('c1cn1([CH3,$(CH2CH3)])')
epoxides_test = ChemicalTest(
    name='Epoxides',
    smart_patterns=[epoxide, aziridine],
    conditions='mw < 1000',
    test_func=None
)
# Out:
# RDKit ERROR: [18:21:20] SMARTS Parse Error: syntax error while parsing: c1cn1([CH3,$(CH2CH3)_100])
# RDKit ERROR: [18:21:20] SMARTS Parse Error: Failed parsing SMARTS 'c1cn1([CH3,$(CH2CH3)_100])' for input: 'c1cn1([CH3,$(CH2CH3)])'

# %%
epoxides_test.add_to_new_tests(new_tests)

# %%
#Aliphatic amines
primamine = Chem.MolFromSmarts('[NX3;H2;!$(NC=[O,N,S]);!$(NCN)][CX3]')
secamine = Chem.MolFromSmarts('[NX3;H1;!$(NC=[O,N,S]);!$(NCN)](C)[CX3]')
tertamine = Chem.MolFromSmarts('[N;!$(NC=[O,N,S]);!$(NCN)](C)(C)[CX3]')

# Define the test for Aliphatic Amines
conditions = "'c' not in smiles and mw < 1000 and '1' not in smiles"

# Create an instance of ChemicalTest for Aliphatic Amines
aliphatic_amines_test = ChemicalTest(
    name='Aliphatic Amines',
    smart_patterns=[primamine, secamine, tertamine],
    conditions=conditions,
    test_func=None  # Placeholder for the test function
)

# Add the test to new_tests
aliphatic_amines_test.add_to_new_tests(new_tests)

# %%
#Alkoxysilanes
alkoxy=Chem.MolFromSmarts('[CX4]O[SiX4]')

alkoxysilanes_test = ChemicalTest(
    name='Alkoxysilanes',
    smart_patterns=[alkoxy],
    conditions='mw < 1000',
    test_func=None
)

alkoxysilanes_test.add_to_new_tests(new_tests)

# %%
#Aminobenzothiazole Azo Dyes
azodye=Chem.MolFromSmiles('N=NC1=NC2=C(S1)C=CC=C2')
aminobenzothiazole_azodye_test = ChemicalTest(
    name='Aminobenzothiazole Azo Dyes',
    smart_patterns=[azodye],
    conditions=None,
    test_func=None
)
aminobenzothiazole_azodye_test.add_to_new_tests(new_tests)

# %%
#Benzotriazoles
benzotriazole=Chem.MolFromSmarts('n1c2ccccc2nn1')
benzotriazole2=Chem.MolFromSmarts('N1N=NC2=C1C=CC=C2')
benzotriazole_test = ChemicalTest(
    name='Benzotriazoles',
    smart_patterns=[benzotriazole, benzotriazole2],
    conditions=None,
    test_func=None
)
benzotriazole_test.add_to_new_tests(new_tests)

# %%
#Dianilines
dianiline = Chem.MolFromSmarts('c1cc([NH2])ccc1[CH2,O,N,S]c1ccccc1')
not_dianiline1 = Chem.MolFromSmarts('c1ccccc1[A]~[A]')
not_dianiline2 = Chem.MolFromSmarts('c1ccccc1[A](c)c')

# Conditions for the Dianilines test
conditions = "len(mol.GetSubstructMatches(dianiline)) == 2"

# Create an instance of ChemicalTest for Dianilines
dianilines_test = ChemicalTest(
    name='Dianilines',
    smart_patterns=[dianiline, not_dianiline1, not_dianiline2],
    conditions=f"not mol.HasSubstructMatch(not_dianiline1) and not mol.HasSubstructMatch(not_dianiline2) and {conditions}",
    test_func=None
)

# Add the test to new_tests
dianilines_test.add_to_new_tests(new_tests)

# %%
#Organotins (Acute toxicity)
organotin=Chem.MolFromSmarts('C[Sn]') 

organotins_acute_test = ChemicalTest(
    name='Organotins (Acute toxicity)',
    smart_patterns=[organotin],
    conditions='(mw <1000 and  logp <=13.7)',
    test_func=None
)
organotins_acute_test.add_to_new_tests(new_tests)

# %%
#Organotins (Chronic toxicity)
organotin=Chem.MolFromSmarts('C[Sn]') 

organotins_chronic_test = ChemicalTest(
    name='Organotins (Acute toxicity)',
    smart_patterns=[organotin],
    conditions='(mw <1000 and  logp >=13.7)',
    test_func=None
)
organotins_chronic_test.add_to_new_tests(new_tests)

# %%
#Anionic Surfactants
def create_test():
    sulfate=Chem.MolFromSmarts('COS(=O)(=O)[OH,O-]')
    sulfonate=Chem.MolFromSmarts('CS(=O)(=O)[OH,O-]')
    phosphate=Chem.MolFromSmarts('COP([OH1])([OH1])=O')
    carboxylic=Chem.MolFromSmarts('[CX3;!$(Cc)](=O)[OX2H1]')
    silicic=Chem.MolFromSmarts('[Si][OX2H]')
    def test(x):
        mol=x['mol']
        smiles=x['smiles']
        if set(smiles)-set(['C','c','O','P','S','i','[',']','(',')','=']):
            return False
        m=re.compile('\(.?C.?\)')
        if m.findall(smiles):
            return False
        rgroup_indexes=[i for i,atom in enumerate(smiles) if atom=='C']
        return (mol.HasSubstructMatch(sulfate) or mol.HasSubstructMatch(sulfonate)\
        or mol.HasSubstructMatch(phosphate) or mol.HasSubstructMatch(carboxylic)\
        or mol.HasSubstructMatch(silicic))\
        and sorted(rgroup_indexes)==range(min(rgroup_indexes),max(rgroup_indexes)+1) #Tests for straight alkyl chains
    return test
new_tests['Anionic Surfactants']=create_test()

# %%
def create_test():
    ethylenebisdithiocarbamate=Chem.MolFromSmiles('SC(=S)NCCNC(=S)S')
    dithiocarbamates=[]
    for i in range(1,5):
        for j in range(1,5):
            mol=Chem.MolFromSmiles('C'*i + 'NC(=S)S' + 'C'*j)
            dithiocarbamates.append(mol)
    dithiocarbamates.append(ethylenebisdithiocarbamate)
    def test(x):
        mol=x['mol']
        return x['mol_weight']<1000 and x['logp']<5 and any([mol.HasSubstructMatch(dithiocarbamate) for dithiocarbamate in dithiocarbamates])
    return test
new_tests['Dithiocarbamates (Acute toxicity)']=create_test()


def create_test():
    ethylenebisdithiocarbamate=Chem.MolFromSmiles('SC(=S)NCCNC(=S)S')
    dithiocarbamates=[]
    for i in range(1,5):
        for j in range(1,5):
            mol=Chem.MolFromSmiles('C'*i + 'NC(=S)S' + 'C'*j)
            dithiocarbamates.append(mol)
    dithiocarbamates.append(ethylenebisdithiocarbamate)
    def test(x):
        mol=x['mol']
        return x['mol_weight']<1000 and x['logp']>=5 and x['logp']<19 and any([mol.HasSubstructMatch(dithiocarbamate) for dithiocarbamate in dithiocarbamates])
    return test
new_tests['Dithiocarbamates (Chronic toxicity)']=create_test()

# %%
#Ethylene Glycol Ethers
#Have to enumerate       
def create_test():
    match_mols=[]
    for i in range(1,8):
        for j in range(0,8):
            for k in range(1,4):
                smart='C'*i+'OCC'*k+'O'+'C'*j
                match_mols.append(Chem.MolFromSmiles(smart))
    phenyl_mols=[]
    for i in range(0,7):
        for k in range(1,3):
            for l in range(0,3): #Technically could be any number but this is difficult to implement
                phenyl_smart='c1ccccc1'+'C'*l+'OCC'*k+'O'+'C'*i
                phenyl_mols.append(Chem.MolFromSmiles(phenyl_smart))
    
    def test(x):
        smiles=x['smiles']
        if set(smiles)-set(['C','c','O','1','(',')']):
            return False
        if smiles.count('O')<2:
            return False
        os=[i for i,o in enumerate(smiles) if o=='O']
        between_os=[smiles[(start+1):end] for start,end in zip(os,os[1:])]
        if any([between!='CC' for between in between_os]):
            return False
        m=re.compile('1.*O.*1')
        if m.findall(smiles):
            return False
        carbon1=smiles[0:min(os)]
        carbon2=smiles[(max(os)+1):]
        if carbon1.count('C')>7 or carbon2.count('C')>7:
            return False
        if carbon1.count('c')>6 or carbon2.count('c')>6:
            return False
        if not carbon1 and not carbon2:
            return False
        else:
            return True
    return test
new_tests['Ethylene Glycol Ethers']=create_test()

# %%
#Neutral Organics
#Verhaar scheme, see paper called Classifying Environmental Pollutants
def create_test():
    def test(x):
        mol=x['mol']
        if mol.HasSubstructMatch(Chem.MolFromSmarts('[!C;!c;!N;!O;!F;!Cl;!Br,I]')): #Rule 0.1 and 1.1
            return False
        logp=x['logp']
        if logp>8:
            return False
        mw=x['mol_weight']
        if mw>1000:
            return False
        if not mol.HasSubstructMatch(Chem.MolFromSmarts('[!C;!c]')): #Rule 1.3
            return True
        elif not mol.HasSubstructMatch(Chem.MolFromSmarts('[!C;!c;!Cl;!Br;!F]'))\
        and not mol.HasSubstructMatch(Chem.MolFromSmarts('[Cl,Br,F]C[$(C=C),$(Cc)]')): #Rule 1.4
            return True
        elif not mol.HasSubstructMatch(Chem.MolFromSmarts('[!C;!c;!O;!Cl;!Br;!F]')): #Rule 1.5
            if mol.HasSubstructMatch(Chem.MolFromSmarts('COC'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('COOC'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('C1OC1')): #Rule 1.5.1 and 1.7
                return True
            elif mol.HasSubstructMatch(Chem.MolFromSmarts('[C;!$(C=O)][OH]'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('C=CCO'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('C#CCO'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('cCO')): #Rule 1.5.2, 1.5.3, and 1.7CCCCOCCOCCO
                return True
            elif mol.HasSubstructMatch(Chem.MolFromSmarts('[C;!$(CO)]=O'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('[$(cC),$(C=C)]C=O'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('[Cl,Br]C=O'))\
            and not mol.HasSubstructMatch(Chem.MolFromSmarts('[Cl,Br]CC=O')): #Rule 1.5.4 and 1.7
                return True
            else:
                return False
        elif not mol.HasSubstructMatch(Chem.MolFromSmarts('[!C;!N]'))\
        and mol.HasSubstructMatch(Chem.MolFromSmarts('C[NH,NH0]')): #Rule 1.6
            return True
        else: 
            return False
    return test
new_tests['Neutral Organics']=create_test()

# %%
#Nonionic Surfactants
# nonsurf1=Chem.MolFromSmarts('COCCO')
# nonsurf2=Chem.MolFromSmarts('COCCOC')
# def test(x):
#     mol=x['mol']
#     return mol.HasSubstructMatch(nonsurf1) or mol.HasSubstructMatch(nonsurf2)
import re
def test(x):
    smiles=x['smiles']
    if '(' in smiles:
        return False
    split_smiles=smiles.split('O')
    if len(split_smiles)==1:
        return False
    mol=x['mol']
    if not mol.HasSubstructMatch(Chem.MolFromSmiles('COC')) or mol.HasSubstructMatch(Chem.MolFromSmiles('C=O')):
        return False
    return not any([re.search(r'[^C]',c) for c in split_smiles])
new_tests['Nonionic Surfactants']=test

# %%
#Nonionic Surfactants
import math
def create_test():
    def test(x):
        mol=x['mol']
        atoms=[a for a in x['smiles'].lower() if a.isalpha()]
        if set(atoms)-set(['c','o']):
            return False
        return mol.HasSubstructMatch(Chem.MolFromSmarts('[CH3][CR0][CR0][CR0][CR0][CR0]')) and\
        atoms.count('o')>1 and\
        (math.floor(len(mol.GetSubstructMatches(Chem.MolFromSmarts('O[CH2][CH2]')))/2)+1)==len(mol.GetSubstructMatches(Chem.MolFromSmarts('[O]')))
    return test
new_tests['Nonionic Surfactants']=create_test()

# %%
#Polynitroaromatics (Acute toxicity) 

polynitroaromatic=Chem.MolFromSmarts('ON(=O)[$(c1c(N(O)=O)cccc1),$(c1cc(N(O)=O)ccc1),$(c1ccc(N(O)=O)cc1),$(c1cncc(N(O)=O)c1)]')
conditions = "mw < 1000 and logp <7"

polynitroaromatics_acute_test = ChemicalTest(
    name='Polynitroaromatics (Acute toxicity) ',
    smart_patterns=[polynitroaromatic],
    conditions=f"(mol.HasSubstructMatch(polynitroaromatic)) and {conditions}",    
    test_func=None
)

# Add the test to new_tests
polynitroaromatics_acute_test.add_to_new_tests(new_tests)

# %%
#Polynitroaromatics (Chronic toxicity)

polynitroaromatic=Chem.MolFromSmarts('ON(=O)[$(c1c(N(O)=O)cccc1),$(c1cc(N(O)=O)ccc1),$(c1ccc(N(O)=O)cc1),$(c1cncc(N(O)=O)c1)]')
conditions = "mw < 1000 and logp >=10"

polynitroaromatics_chronic_test = ChemicalTest(
    name='Polynitroaromatics (Chronic toxicity)',
    smart_patterns=[polynitroaromatic],
    conditions=f"(mol.HasSubstructMatch(polynitroaromatic)) and {conditions}",    
    test_func=None
)

# Add the test to new_tests
polynitroaromatics_chronic_test.add_to_new_tests(new_tests)

# %%
# Substituted Triazines (Acute toxicity) 
subtriazine=Chem.MolFromSmarts('[$(n1nnccc1.[!#1]),$(n1ncncc1.[!#1]),$(n1cncnc1.[!#1])]')#
conditions = "mw < 1000 and logp <5"

substituted_triazines_acute_test = ChemicalTest(
    name='Substituted Triazines (Acute toxicity)',
    smart_patterns=[subtriazine],
    conditions=f"(mol.HasSubstructMatch(subtriazine)) and {conditions}",    
    test_func=None
)

# Add the test to new_tests
substituted_triazines_acute_test.add_to_new_tests(new_tests)

# %%
# Substituted Triazines (Chronic toxicity)
subtriazine=Chem.MolFromSmarts('[$(n1nnccc1.[!#1]),$(n1ncncc1.[!#1]),$(n1cncnc1.[!#1])]')#
conditions = "mw < 1000 and logp <=8 and logp>5"

substituted_triazines_chronic_test = ChemicalTest(
    name='Substituted Triazines (Chronic toxicity)',
    smart_patterns=[subtriazine],
    conditions=f"(mol.HasSubstructMatch(subtriazine)) and {conditions}",    
    test_func=None
)

# Add the test to new_tests
substituted_triazines_chronic_test.add_to_new_tests(new_tests)

# %%
def convert_ppb(x): #OPERA results stored as mol/L
    ws=x['ws']
    mol_weight=x['mol_weight']
    return ws*mol_weight*10**6

# %%
#Triarylmethane Pigments/Dyes with Non-solubilizing Groups
def create_test():
    para_permutations='[NH2,O,$([NH1][CH3]),$([NH1][CH2][CH3]),$(N([CH3])[CH3]),$(N([CH3])[CH2][CH3]),$(N([CH2][CH3])[CH2][CH3])]'
    triphenylmethane=Chem.MolFromSmarts('[cH]1[cH]c({})[cH][cH]c1C(c2[cH][cH]c({})[cH][cH]2)=C3[CH]=[CH]C(=[NH,O])[CH]=[CH]3'.format(para_permutations,para_permutations))
    diphenylnaphthylmethane=Chem.MolFromSmarts('[cH]1[cH]c({})[cH][cH]c1C(c2[cH][cH]c({})[cH]3[cH][cH][cH][cH][cH]32)=C3[CH]=[CH]C(=[NH,O])[CH]=[CH]3'.format(para_permutations,para_permutations))
    def test(x):
        mol=x['mol']
        return convert_ppb(x)>1 and (mol.HasSubstructMatch(triphenylmethane) or (mol.HasSubstructMatch(diphenylnaphthylmethane)))
    return test
new_tests['Triarylmethane Pigments/Dyes with Non-solubilizing Groups']=create_test()

# %%
#beta-Naphthylamines, Sulfonated
def create_test():
    smarts=[]
    match_mols=[]
    prefix='[NH2]c1[cH1,$(cO)]'
    suffix='[cH][cH]1'
    for c1 in range(1,4):
        for c2 in range(c1+1,5):
            smarts.append(prefix+'c2'+'[cH]'*(c1-1)+'[cH,$(c[OH]),$(c[NH2])]'+'[cH]'*(c2-c1-1)+'c([$(S(=O)(=O)[OH]),$(S(=O)(=O)[CH2][CH2]S[OH3])])'+'[cH]'*(4-c2)+'c2'+suffix)
            smarts.append(prefix+'c2'+'[cH]'*(c1-1)+'c([$(S(=O)(=O)[OH]),$(S(=O)(=O)[CH2][CH2]S[OH3])])'+'[cH]'*(c2-c1-1)+'[cH1,$(c[OH]),$(c[NH2])]'+'[cH]'*(4-c2)+'c2'+suffix)
    match_mols=[Chem.MolFromSmarts(smart) for smart in smarts]
    def test(x):
        mol=x['mol']
        naph_matches=[True for match in match_mols[:] if mol.HasSubstructMatch(match) and match.HasSubstructMatch(mol)]
        return any(naph_matches)
    return test
new_tests['beta-Naphthylamines, Sulfonated']=create_test()

# %%
#Aldehydes (Acute)

formaldehyde=Chem.MolFromSmarts('[CH2](=O)') #Needs to be special case because buggy way RDKit handles hydrogens
aldehyde=Chem.MolFromSmarts('[CH1](=[O])[C,c]')

conditions = "mw < 1000 and logp <=6"

aldehydes_acute_test = ChemicalTest(
    name='Aldehydes (Acute)',
    smart_patterns=[formaldehyde, aldehyde],
    conditions=f"(mol.HasSubstructMatch(formaldehyde) or mol.HasSubstructMatch(aldehyde)) and {conditions}",    
    test_func=None
)

# Add the test to new_tests
aldehydes_acute_test.add_to_new_tests(new_tests)

# %%
#Aldehydes (Chronic)
formaldehyde=Chem.MolFromSmarts('[CH2](=O)') #Needs to be special case because buggy way RDKit handles hydrogens
aldehyde=Chem.MolFromSmarts('[CH1](=[O])[C,c]')
conditions = "mw < 1000 and logp >6"

aldehydes_chronic_test = ChemicalTest(
    name='Aldehydes (Chronic)',
    smart_patterns=[formaldehyde, aldehyde],
    conditions=f"(mol.HasSubstructMatch(formaldehyde) or mol.HasSubstructMatch(aldehyde)) and {conditions}",      
    test_func=None
)

# Add the test to new_tests
aldehydes_chronic_test.add_to_new_tests(new_tests)

# %%
#Imides (Acute toxicity)

imide=Chem.MolFromSmarts('C(=O)NC(=O)')
not_imide=Chem.MolFromSmarts('c1C(=O)NC(=O)ccccc1')
conditions = "mw < 1000 and logp <=5"

    
imides_acute_test = ChemicalTest(
    name='Imides (Acute toxicity)',
    smart_patterns=[imide, not_imide],
    conditions=f"(mol.HasSubstructMatch(imide) and not mol.HasSubstructMatch(not_imide) and {conditions}",    
    test_func=None
)

# Add the test to new_tests
imides_acute_test.add_to_new_tests(new_tests)

# %%
#Imides (Chronic toxicity)

imide=Chem.MolFromSmarts('C(=O)NC(=O)')
not_imide=Chem.MolFromSmarts('c1C(=O)NC(=O)ccccc1')
conditions = "mw < 1000 and logp > 5 and logp<8"

imides_chronic_test = ChemicalTest(
    name='Imides (Chronic toxicity)',
    smart_patterns=[imide, not_imide],
    conditions=f"(mol.HasSubstructMatch(imide) and not mol.HasSubstructMatch(not_imide) and {conditions}",    
    test_func=None
)

# Add the test to new_tests
imides_chronic_test.add_to_new_tests(new_tests)

# %%
#Hydrazines and related compounds

hydra1 = Chem.MolFromSmarts('[NX3][NX3]')
hydra2 = Chem.MolFromSmarts('[CX3]=[NX2][NX2]')
hydra3 = Chem.MolFromSmarts('[CX3](=O)[NX2][NX3]')
hydra4 = Chem.MolFromSmarts('[NX2][CX3](=O)[NX2][NX3]')

# Conditions for the Hydrazines test
conditions = "mw < 500"

# Create an instance of ChemicalTest for Hydrazines and Related Compounds
hydrazines_test = ChemicalTest(
    name='Hydrazines and Related Compounds',
    smart_patterns=[hydra1, hydra2, hydra3, hydra4],
    conditions=f"(mol.HasSubstructMatch(hydra1) or mol.HasSubstructMatch(hydra2) or mol.HasSubstructMatch(hydra3) or mol.HasSubstructMatch(hydra4)) and {conditions}",
    test_func=None
)

# Add the test to new_tests
hydrazines_test.add_to_new_tests(new_tests)

# %%
#Thiols (Acute toxicity)
thiol=Chem.MolFromSmarts('[C,c][SX2H]')
conditions = "mw < 1000 and logp >=6.5"
thiols_acute_test = ChemicalTest(
    name='Thiols (Acute toxicity)',
    smart_patterns=[thiol],
    conditions=f"(mol.HasSubstructMatch(thiol) and {conditions}",
    test_func=None
)

# Add the test to new_tests
thiols_acute_test.add_to_new_tests(new_tests)

# %%
#Thiols (Chronic toxicity)
thiol=Chem.MolFromSmarts('[C,c][SX2H]')
conditions = "mw < 1000 and logp >=6.5 and logp<9"
thiols_chronic_test = ChemicalTest(
    name='Thiols (Chronic toxicity)',
    smart_patterns=[thiol],
    conditions=f"(mol.HasSubstructMatch(thiol) and {conditions}",
    test_func=None
)

# Add the test to new_tests
thiols_chronic_test.add_to_new_tests(new_tests)

# %%
#Acrylamides

acrylamide1=Chem.MolFromSmarts('[CH2]=[CH1]C(=O)[NH,NH2]')
acrylamide2=Chem.MolFromSmarts('[CH2]=C([CH3])C(=O)[NH,NH2]')
conditions = "mw < 1000 and  logp<8"
acrylamides_test = ChemicalTest(
    name='Acrylamides',
    smart_patterns=[acrylamide1, acrylamide2],
    conditions=f"(mol.HasSubstructMatch(acrylamide1) or mol.HasSubstructMatch(acrylamide2)) and {conditions}",
    test_func=None
)

# Add the test to new_tests
acrylamides_test.add_to_new_tests(new_tests)

# %%
# Acrylates/Methacrylates (Acute toxicity)
acrylate=Chem.MolFromSmarts('[CH2]=[CH]C(=O)O')
methacrylate=Chem.MolFromSmarts('[CH2]=C([CH3])C(=O)O')
conditions = "logp<=5 and mw<1000"
acrylates_methacrylates_acute_test = ChemicalTest(
    name='Acrylates/Methacrylates (Acute toxicity)',
    smart_patterns=[acrylate, methacrylate],
    conditions=f"(mol.HasSubstructMatch(acrylate) or mol.HasSubstructMatch(methacrylate)) and {conditions}",
    test_func=None
)

# Add the test to new_tests
acrylates_methacrylates_acute_test.add_to_new_tests(new_tests)

# %%
# Acrylates/Methacrylates (Chronic toxicity)
acrylate=Chem.MolFromSmarts('[CH2]=[CH]C(=O)O')
methacrylate=Chem.MolFromSmarts('[CH2]=C([CH3])C(=O)O')
conditions = "logp>5 and logp<8 and mw<1000"

acrylates_methacrylates_chronic_test = ChemicalTest(
    name='Acrylates/Methacrylates (Chronic toxicity)',
    smart_patterns=[acrylate, methacrylate],
    conditions=f"(mol.HasSubstructMatch(acrylate) or mol.HasSubstructMatch(methacrylate)) and {conditions}",
    test_func=None
)

# Add the test to new_tests
acrylates_methacrylates_chronic_test.add_to_new_tests(new_tests)

# %%
len(new_tests)
# Out:
# 20

# %%
new_tests
# Out:
# {'Epoxides': <__main__.ChemicalTest at 0x745140fe0e50>,
#  'Aliphatic Amines': <__main__.ChemicalTest at 0x74514138f370>,
#  'Alkoxysilanes': <__main__.ChemicalTest at 0x745140fe0790>,
#  'Aminobenzothiazole Azo Dyes': <__main__.ChemicalTest at 0x745140f2e340>,
#  'Benzotriazoles': <__main__.ChemicalTest at 0x745140f2e190>,
#  'Dianilines': <__main__.ChemicalTest at 0x745140f2e8b0>,
#  'Organotins (Acute toxicity)': <__main__.ChemicalTest at 0x745140fe0eb0>,
#  'Polynitroaromatics (Acute toxicity) ': <__main__.ChemicalTest at 0x745140fe00d0>,
#  'Polynitroaromatics (Chronic toxicity)': <__main__.ChemicalTest at 0x745140fe0a30>,
#  'Substituted Triazines (Acute toxicity)': <__main__.ChemicalTest at 0x745141352160>,
#  'Substituted Triazines (Chronic toxicity)': <__main__.ChemicalTest at 0x7451766e5700>,
#  'Aldehydes (Chronic)': <__main__.ChemicalTest at 0x745140f2e430>,
#  'Imides (Acute toxicity)': <__main__.ChemicalTest at 0x745140f2ed00>,
#  'Imides (Chronic toxicity)': <__main__.ChemicalTest at 0x745140f2e850>,
#  'Hydrazines and Related Compounds': <__main__.ChemicalTest at 0x745140f2e9a0>,
#  'Thiols (Acute toxicity)': <__main__.ChemicalTest at 0x745140f2edc0>,
#  'Thiols (Chronic toxicity)': <__main__.ChemicalTest at 0x745140f2e070>,
#  'Acrylamides': <__main__.ChemicalTest at 0x745140f2ec40>,
#  'Acrylates/Methacrylates (Acute toxicity)': <__main__.ChemicalTest at 0x745140f2e940>,
#  'Acrylates/Methacrylates (Chronic toxicity)': <__main__.ChemicalTest at 0x745140f2ed30>}

# %%
#new_tests.update({k:q.query for k,q in tests.items()})

# %%
len(new_tests)
# Out:
# 20

# %%
example = new_tests['Aliphatic Amines']
out = example.get_details()

# %%
[Chem.MolToSmarts(e) for e in out['smart_patterns'] if e is not None]
# Out:
# ['[N&X3&H2&!$(NC=[O,N,S])&!$(NCN)][C&X3]',
#  '[N&X3&H1&!$(NC=[O,N,S])&!$(NCN)](-,:C)[C&X3]',
#  '[N&!$(NC=[O,N,S])&!$(NCN)](-,:C)(-,:C)[C&X3]']

# %%
[Chem.MolToSmarts(s) for s in out['smart_patterns'] if s not None]
# Out:
#   Cell In [95], line 1
#     [Chem.MolToSmarts(s) for s in out['smart_patterns'] if s not None]
#                                                                  ^
# SyntaxError: invalid syntax

# %%
new_tests['Aliphatic Amines']

# %%
new_tests['Acrylates/Methacrylates (Chronic toxicity)']

# %%
list(new_tests.keys())[:2]
# Out:
# ['Epoxides', 'Aliphatic Amines']

# %%
list(new_tests.values())[:2]
# Out:
# [<__main__.ChemicalTest at 0x7451766e5e20>,
#  <__main__.ChemicalTest at 0x74514134ffa0>]

# %%
for x, y in new_tests.items():
    print(x,y.get_details())
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In [60], line 2
#       1 for x, y in new_tests.items():
# ----> 2     print(x,y.get_details())
#
# Cell In [23], line 32, in ChemicalTest.get_details(self)
#      28 def get_details(self):
#      29     """Returns the SMARTS patterns, conditions, and test function for this chemical test."""
#      30     return {
#      31         'name': self.name,
# ---> 32         'smart_patterns': [Chem.MolToSmarts(sp) for sp in self.smart_patterns],
#      33         'conditions': self.conditions,
#      34         'test_func': self.test_func
#      35     }
#
# Cell In [23], line 32, in <listcomp>(.0)
#      28 def get_details(self):
#      29     """Returns the SMARTS patterns, conditions, and test function for this chemical test."""
#      30     return {
#      31         'name': self.name,
# ---> 32         'smart_patterns': [Chem.MolToSmarts(sp) for sp in self.smart_patterns],
#      33         'conditions': self.conditions,
#      34         'test_func': self.test_func
#      35     }
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolfiles.MolToSmarts(NoneType)
# did not match C++ signature:
#     MolToSmarts(RDKit::ROMol mol, bool isomericSmiles=True)

# %%
sorted(list(new_tests.keys()))[:10]
# Out:
# ['Acid Chlorides',
#  'Acrylamides',
#  'Acrylates/Methacrylates (Acute toxicity)',
#  'Acrylates/Methacrylates (Chronic toxicity)',
#  'Aldehydes (Acute toxicity)',
#  'Aldehydes (Chronic toxicity)',
#  'Aliphatic Amines',
#  'Alkoxysilanes',
#  'Aluminum Compounds',
#  'Aminobenzothiazole Azo Dyes']

# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://removed:27017/')

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'genra_db', 'genra_dev_v5', 'local']

# %%
DB = client.genra_dev_v5

# %%
DB.list_collection_names()
# Out:
# ['toxref_tr_fp',
#  'httr_rj_heparg',
#  'toxcast_assays',
#  'compounds',
#  'chms_fp',
#  'toxval_v9',
#  'toxref_effects',
#  'physprop',
#  'htpp_cr_fp_0',
#  'toxcast_fp',
#  'httr_cr_fp_0',
#  'httr_rj_u2os',
#  'toxcast_fp_1']

# %%
#[e for e in DB2.physprop.find({'dsstox_sid': 'DTXSID8059718'})]

# %%
loael_smiles=DB.compounds.find({},{'_id':0,'dsstox_sid':1,'smiles':1}).limit(10)

# %%
smiles_dict={record['dsstox_sid']:record['smiles'] for record in loael_smiles if record['smiles']}

# %%
smiles_dict
# Out:
# {'DTXSID7020001': 'NC1=NC2=C(C=C1)C1=CC=CC=C1N2',
#  'DTXSID2020004': 'CC=NO',
#  'DTXSID7020005': 'CC(N)=O',
#  'DTXSID2020006': 'CC(=O)NC1=CC=C(O)C=C1',
#  'DTXSID7020007': 'CC(=O)C1=CC=C(C=C1)S(=O)(=O)NC(=O)NC1CCCCC1',
#  'DTXSID2020008': 'CC(C)=NNC1=NC=C(S1)C1=CC=C(O1)[N+]([O-])=O',
#  'DTXSID7020009': 'CC#N',
#  'DTXSID6020010': 'CC(C)=NO',
#  'DTXSID6020012': 'CC(=O)NNC1=CC=C(CO)C=C1',
#  'DTXSID1020013': 'CC(=O)NNC(=O)C1=CC=NC=C1'}

# %%
#[e for e in DB2.physprop.find({},{'_id':0,'dsstox_sid':1,'predicted_props.OPERA_LogP':1}).limit(10)]

# %%
DB.physprop.find_one({})
# Out:
# {'_id': ObjectId('59c92a22a8d0e8591b32a18f'),
#  'predicted_props': {'ACD_FP': [-25.127],
#   'NICEATM_MP': [5.14578],
#   'NICEATM_VP': [12.158],
#   'OPERA_AOH': [2.05998e-12, 2.05995e-12],
#   'OPERA_HL': [3.32082e-05],
#   'EPISUITE_BP': [118.18],
#   'OPERA_WS': [5.8831],
#   'ACD_Prop_Molar_Refractivity': [15.478],
#   'ACD_Prop_Index_Of_Refraction': [1.393],
#   'ACD_Prop_Surface_Tension': [28.315],
#   'OPERA_BCF': [6.17193],
#   'OPERA_RBiodeg': [0.0],
#   'ACD_LogP_v_LogP_Classic': [0.813],
#   'EPISUITE_LOGP': [-0.21],
#   'EPISUITE_WS': [2.99993],
#   'OPERA_BIODEG': [4.59228],
#   'NICEATM_BCF': [2.13379],
#   'OPERA_LogP': [0.267325],
#   'NICEATM_BP': [114.24],
#   'ACD_Prop_Parachor': [149.464],
#   'ACD_Prop_Density': [0.912],
#   'OPERA_VP': [49.9845],
#   'OPERA_BP': [110.309],
#   'ACD_BP': [19.843],
#   'ACD_Prop_Molar_Volume': [64.794],
#   'NICEATM_LogS': [1.18613],
#   'NICEATM_LogP': [0.404076],
#   'EPISUITE_MP': [-73.62],
#   'OPERA_KM': [0.112998],
#   'ACD_Prop_Polarizability': [6.136],
#   'OPERA_MP': [31.3202],
#   'OPERA_KOC': [5.01878],
#   'OPERA_KOA': [1.64895]},
#  'measured_props': {'Volume Exported': [5250000.0],
#   'Domestic Manufacturing Production': [10566000.0],
#   'LogP: Octanol-Water': [-0.13],
#   'Melting Point': [45.0, 45.0],
#   'PubMed_counts': [62.0],
#   'Atmos- Hydroxylation Rate': [2.19998e-12],
#   'Boiling Point': [116.0, 116.0, 115.0],
#   'Volume Used': [0.0],
#   'Imported Volume': [0.0]},
#  'dsstox_sid': 'DTXSID2020004',
#  'dsstox_cid': 'DTXCID404'}

# %%
loael_logp = [e for e in DB.physprop.find({'dsstox_sid': {'$in': list(smiles_dict.keys())}}, {"dsstox_sid":1, "predicted_props.OPERA_LogP" : 1, "_id":0})]

# %%
loael_logp[0]
# Out:
# {'predicted_props': {'OPERA_LogP': [0.267325]}, 'dsstox_sid': 'DTXSID2020004'}

# %%
logp_dict = {record['dsstox_sid']: record.get('predicted_props',{})['OPERA_LogP'][0] for record in loael_logp}

# %%
logp_dict
# Out:
# {'DTXSID2020004': 0.267325,
#  'DTXSID7020005': -1.2057,
#  'DTXSID2020006': 0.875449,
#  'DTXSID7020007': 1.65144,
#  'DTXSID2020008': 1.54363,
#  'DTXSID7020009': -0.316894,
#  'DTXSID6020010': 0.882667,
#  'DTXSID6020012': 0.764281,
#  'DTXSID1020013': -0.577089,
#  'DTXSID7020001': 2.63969}

# %%
loael_ws = [e for e in DB.physprop.find({'dsstox_sid': {'$in': list(smiles_dict.keys())}}, {"dsstox_sid":1, "predicted_props.OPERA_WS" : 1, "_id":0})]

# %%
#loael_ws

# %%
ws_dict = {record['dsstox_sid']: record.get('predicted_props',{})['OPERA_WS'][0] for record in loael_ws}
ws_dict
# Out:
# {'DTXSID2020004': 5.8831,
#  'DTXSID7020005': 19.0029,
#  'DTXSID2020006': 1.11026,
#  'DTXSID7020007': 0.00139472,
#  'DTXSID2020008': 3.31981e-05,
#  'DTXSID7020009': 8.59913,
#  'DTXSID6020010': 1.69356,
#  'DTXSID6020012': 0.686068,
#  'DTXSID1020013': 0.380852,
#  'DTXSID7020001': 0.015397}

# %%
DB.compounds.find_one({})
# Out:
# {'_id': ObjectId('609430c44ce714020b32837e'),
#  'casrn': '26148-68-5',
#  'chemspider_id': 56541.0,
#  'dsstox_cid': 'DTXCID101',
#  'dsstox_sid': 'DTXSID7020001',
#  'gsid': 20001,
#  'inchi_key': 'FJTNLJLPLJDTRM-UHFFFAOYSA-N',
#  'iupac': '9H-Pyrido[2,3-b]indol-2-amine',
#  'mol_weight': 183.214,
#  'name': 'A-alpha-C',
#  'pubchem_cid': 62805.0,
#  'smiles': 'NC1=NC2=C(C=C1)C1=CC=CC=C1N2'}

# %%
loael_weight = [e for e in DB.compounds.find({'dsstox_sid': {'$in': list(smiles_dict.keys())}}, {"dsstox_sid":1, "mol_weight" : 1, "_id":0})]

# %%
loael_weight
# Out:
# [{'dsstox_sid': 'DTXSID1020013', 'mol_weight': 179.179},
#  {'dsstox_sid': 'DTXSID2020004', 'mol_weight': 59.068},
#  {'dsstox_sid': 'DTXSID2020006', 'mol_weight': 151.165},
#  {'dsstox_sid': 'DTXSID2020008', 'mol_weight': 266.28},
#  {'dsstox_sid': 'DTXSID6020010', 'mol_weight': 73.095},
#  {'dsstox_sid': 'DTXSID6020012', 'mol_weight': 180.207},
#  {'dsstox_sid': 'DTXSID7020001', 'mol_weight': 183.214},
#  {'dsstox_sid': 'DTXSID7020005', 'mol_weight': 59.068},
#  {'dsstox_sid': 'DTXSID7020007', 'mol_weight': 324.4},
#  {'dsstox_sid': 'DTXSID7020009', 'mol_weight': 41.053}]

# %%
weight_dict={record['dsstox_sid']:record['mol_weight'] for record in loael_weight}

# %%
weight_dict
# Out:
# {'DTXSID1020013': 179.179,
#  'DTXSID2020004': 59.068,
#  'DTXSID2020006': 151.165,
#  'DTXSID2020008': 266.28,
#  'DTXSID6020010': 73.095,
#  'DTXSID6020012': 180.207,
#  'DTXSID7020001': 183.214,
#  'DTXSID7020005': 59.068,
#  'DTXSID7020007': 324.4,
#  'DTXSID7020009': 41.053}

# %%
sids=set(logp_dict.keys())&set(ws_dict.keys())&set(weight_dict.keys())&set(smiles_dict.keys())

# %%
sids
# Out:
# {'DTXSID1020013',
#  'DTXSID2020004',
#  'DTXSID2020006',
#  'DTXSID2020008',
#  'DTXSID6020010',
#  'DTXSID6020012',
#  'DTXSID7020001',
#  'DTXSID7020005',
#  'DTXSID7020007',
#  'DTXSID7020009'}

# %%
records=[]
for sid in sids:
    records.append({'dsstox_sid':sid,'smiles':smiles_dict[sid],'logp':logp_dict[sid],'ws':ws_dict[sid],'mol_weight':weight_dict[sid],'mol':Chem.MolFromSmiles(smiles_dict[sid])})
records=[record for record in records if record['mol']]

# %%
records[0]
# Out:
# {'dsstox_sid': 'DTXSID2020006',
#  'smiles': 'CC(=O)NC1=CC=C(O)C=C1',
#  'logp': 0.875449,
#  'ws': 1.11026,
#  'mol_weight': 151.165,
#  'mol': <rdkit.Chem.rdchem.Mol at 0x7cf74c146760>}

# %%
import math
for record in records:
    #print(record)
    epa_categories=sorted([category for category,test in new_tests.items() if test(record)])
    if 'Neutral Organics' in epa_categories and len(epa_categories)>1:
        epa_categories.remove('Neutral Organics')
    record['categories']=tuple(epa_categories)

# %%
pd.DataFrame(records)
# Out:
#       dsstox_sid                                       smiles      logp  \
# 0  DTXSID2020006                        CC(=O)NC1=CC=C(O)C=C1  0.875449
# 1  DTXSID7020007  CC(=O)C1=CC=C(C=C1)S(=O)(=O)NC(=O)NC1CCCCC1  1.651440
# 2  DTXSID7020001                 NC1=NC2=C(C=C1)C1=CC=CC=C1N2  2.639690
# 3  DTXSID1020013                     CC(=O)NNC(=O)C1=CC=NC=C1 -0.577089
# 4  DTXSID6020010                                     CC(C)=NO  0.882667
# 5  DTXSID2020004                                        CC=NO  0.267325
# 6  DTXSID7020009                                         CC#N -0.316894
# 7  DTXSID2020008   CC(C)=NNC1=NC=C(S1)C1=CC=C(O1)[N+]([O-])=O  1.543630
# 8  DTXSID7020005                                      CC(N)=O -1.205700
# 9  DTXSID6020012                      CC(=O)NNC1=CC=C(CO)C=C1  0.764281
#
#           ws  mol_weight                                               mol  \
# 0   1.110260     151.165  <rdkit.Chem.rdchem.Mol object at 0x7cf74c146760>
# 1   0.001395     324.400  <rdkit.Chem.rdchem.Mol object at 0x7cf74c146620>
# 2   0.015397     183.214  <rdkit.Chem.rdchem.Mol object at 0x7cf74c148b20>
# 3   0.380852     179.179  <rdkit.Chem.rdchem.Mol object at 0x7cf74c148f80>
# 4   1.693560      73.095  <rdkit.Chem.rdchem.Mol object at 0x7cf74c148ad0>
# 5   5.883100      59.068  <rdkit.Chem.rdchem.Mol object at 0x7cf74c148c10>
# 6   8.599130      41.053  <rdkit.Chem.rdchem.Mol object at 0x7cf74c1428a0>
# 7   0.000033     266.280  <rdkit.Chem.rdchem.Mol object at 0x7cf74c142030>
# 8  19.002900      59.068  <rdkit.Chem.rdchem.Mol object at 0x7cf74c142080>
# 9   0.686068     180.207  <rdkit.Chem.rdchem.Mol object at 0x7cf74c142760>
#
#                             categories
# 0          (Phenols (Acute toxicity),)
# 1                                   ()
# 2                                   ()
# 3  (Hydrazines and Related Compounds,)
# 4                                   ()
# 5                                   ()
# 6                                   ()
# 7  (Hydrazines and Related Compounds,)
# 8                                   ()
# 9  (Hydrazines and Related Compounds,)

# %%
tsca_df = pd.read_excel(interim_dir+'TSCA_OPERA_predictions_080722.xlsx')

# %%
records[0].keys()
# Out:
# dict_keys(['dsstox_sid', 'smiles', 'logp', 'ws', 'mol_weight', 'mol', 'categories'])

# %%
tsca_df2 = tsca_df[tsca_df['errors'].isnull()]

# %%
tsca_df2 = tsca_df2.set_index('dtxsid')

# %%
tsca_df2.columns
# Out:
# Index(['Unnamed: 0', 'PREFERRED_NAME', 'CASRN', 'INCHIKEY', 'IUPAC_NAME',
#        'SMILES', 'INCHI_STRING', 'MOLECULAR_FORMULA', 'AVERAGE_MASS',
#        'MONOISOTOPIC_MASS', 'DATA_SOURCES', 'NUMBER_OF_PUBMED_ARTICLES',
#        'PUBCHEM_DATA_SOURCES', 'CPDAT_COUNT', 'MolWeight', 'nbAtoms',
#        'nbHeavyAtoms', 'nbC', 'nbO', 'nbN', 'nbAromAtom', 'nbRing',
#        'nbHeteroRing', 'Sp3Sp2HybRatio', 'nbRotBd', 'nbHBdAcc', 'ndHBdDon',
#        'nbLipinskiFailures', 'TopoPolSurfAir', 'MolarRefract',
#        'CombDipolPolariz', 'LogP_pred', 'LogP_predRange', 'AD_LogP',
#        'AD_index_LogP', 'Conf_index_LogP', 'MP_pred', 'MP_predRange', 'AD_MP',
#        'AD_index_MP', 'Conf_index_MP', 'BP_pred', 'BP_predRange', 'AD_BP',
#        'AD_index_BP', 'Conf_index_BP', 'LogVP_pred', 'VP_predRange', 'AD_VP',
#        'AD_index_VP', 'Conf_index_VP', 'LogWS_pred', 'WS_predRange', 'AD_WS',
#        'AD_index_WS', 'Conf_index_WS', 'LogHL_pred', 'HL_predRange', 'AD_HL',
#        'AD_index_HL', 'Conf_index_HL', 'RT_pred', 'AD_RT', 'AD_index_RT',
#        'Conf_index_RT', 'RT_predRange', 'LogKOA_pred', 'KOA_predRange',
#        'AD_KOA', 'AD_index_KOA', 'Conf_index_KOA', 'ionization', 'pKa_a_pred',
#        'pKa_a_predRange', 'pKa_b_pred', 'pKa_b_predRange', 'AD_pKa',
#        'AD_index_pKa', 'Conf_index_pKa', 'LogD55_pred', 'LogD55_predRange',
#        'LogD74_pred', 'LogD74_predRange', 'AD_LogD', 'AD_index_LogD',
#        'Conf_index_LogD', 'errors', 'qsar_ready_smiles', 'HLC',
#        'WS_pred_mol/L', 'WS_pred_mg/L', 'test_track', 'physical_form'],
#       dtype='object')

# %%
test_df = tsca_df2[['qsar_ready_smiles','LogP_pred','WS_pred_mol/L','MolWeight']].head()

# %%
test_df = test_df.reset_index()

# %%
test_df
# Out:
#           dtxsid                                  qsar_ready_smiles  \
# 0  DTXSID3060164               C1=CC=CC=C1C(C1C=CC=CC=1)C1C=CC=CC=1
# 1  DTXSID7060837                                              ICCCI
# 2  DTXSID9025879                    OC(=O)C=CC1C=CC(C=CC(O)=O)=CC=1
# 3  DTXSID2026282  O=C(NC1=CC2=C(NC3C4=C(C=CC2=3)C(=O)C2C(=CC=CC=...
# 4  DTXSID4052188                       CC1(C)COC(C)(OC1)C1C=CC=CC=1
#
#    LogP_pred  WS_pred_mol/L   MolWeight
# 0       5.76   4.073803e-07  244.125201
# 1       3.02   7.413102e-04  295.855896
# 2       1.99   9.120108e-03  218.057909
# 3       3.11   2.454709e-08  667.174336
# 4       2.72   1.148154e-03  206.130680

# %%
test_df.columns = ['dsstox_sid', 'smiles', 'logp', 'ws', 'mol_weight']

# %%
test_df['mol'] = [Chem.MolFromSmiles(e) for e in test_df['smiles']]

# %%
test_df
# Out:
#       dsstox_sid                                             smiles  logp  \
# 0  DTXSID3060164               C1=CC=CC=C1C(C1C=CC=CC=1)C1C=CC=CC=1  5.76
# 1  DTXSID7060837                                              ICCCI  3.02
# 2  DTXSID9025879                    OC(=O)C=CC1C=CC(C=CC(O)=O)=CC=1  1.99
# 3  DTXSID2026282  O=C(NC1=CC2=C(NC3C4=C(C=CC2=3)C(=O)C2C(=CC=CC=...  3.11
# 4  DTXSID4052188                       CC1(C)COC(C)(OC1)C1C=CC=CC=1  2.72
#
#              ws  mol_weight                                               mol
# 0  4.073803e-07  244.125201  <rdkit.Chem.rdchem.Mol object at 0x7cf7474a37b0>
# 1  7.413102e-04  295.855896  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b07b0>
# 2  9.120108e-03  218.057909  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b0030>
# 3  2.454709e-08  667.174336  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b0620>
# 4  1.148154e-03  206.130680  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b0990>

# %%
test_dict = test_df.to_dict('records')

# %%
test_dict
# Out:
# [{'dsstox_sid': 'DTXSID3060164',
#   'smiles': 'C1=CC=CC=C1C(C1C=CC=CC=1)C1C=CC=CC=1',
#   'logp': 5.76,
#   'ws': 4.07380277804113e-07,
#   'mol_weight': 244.125200512,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7cf7474a37b0>},
#  {'dsstox_sid': 'DTXSID7060837',
#   'smiles': 'ICCCI',
#   'logp': 3.02,
#   'ws': 0.0007413102413009177,
#   'mol_weight': 295.855896192,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7cf7474b07b0>},
#  {'dsstox_sid': 'DTXSID9025879',
#   'smiles': 'OC(=O)C=CC1C=CC(C=CC(O)=O)=CC=1',
#   'logp': 1.99,
#   'ws': 0.009120108393559097,
#   'mol_weight': 218.0579088,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7cf7474b0030>},
#  {'dsstox_sid': 'DTXSID2026282',
#   'smiles': 'O=C(NC1=CC2=C(NC3C4=C(C=CC2=3)C(=O)C2C(=CC=CC=2C4=O)NC(=O)C2C=CC=CC=2)C2=C1C(=O)C1C=CC=CC=1C2=O)C1C=CC=CC=1',
#   'logp': 3.11,
#   'ws': 2.454708915685029e-08,
#   'mol_weight': 667.174335520001,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7cf7474b0620>},
#  {'dsstox_sid': 'DTXSID4052188',
#   'smiles': 'CC1(C)COC(C)(OC1)C1C=CC=CC=1',
#   'logp': 2.72,
#   'ws': 0.001148153621496883,
#   'mol_weight': 206.130679816,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7cf7474b0990>}]

# %%
for record in test_dict:
    #print(record)
    epa_categories=sorted([category for category,test in new_tests.items() if test(record)])
    if 'Neutral Organics' in epa_categories and len(epa_categories)>1:
        epa_categories.remove('Neutral Organics')
    record['categories']=tuple(epa_categories)

# %%
pd.DataFrame(test_dict)
# Out:
#       dsstox_sid                                             smiles  logp  \
# 0  DTXSID3060164               C1=CC=CC=C1C(C1C=CC=CC=1)C1C=CC=CC=1  5.76
# 1  DTXSID7060837                                              ICCCI  3.02
# 2  DTXSID9025879                    OC(=O)C=CC1C=CC(C=CC(O)=O)=CC=1  1.99
# 3  DTXSID2026282  O=C(NC1=CC2=C(NC3C4=C(C=CC2=3)C(=O)C2C(=CC=CC=...  3.11
# 4  DTXSID4052188                       CC1(C)COC(C)(OC1)C1C=CC=CC=1  2.72
#
#              ws  mol_weight                                               mol  \
# 0  4.073803e-07  244.125201  <rdkit.Chem.rdchem.Mol object at 0x7cf7474a37b0>
# 1  7.413102e-04  295.855896  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b07b0>
# 2  9.120108e-03  218.057909  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b0030>
# 3  2.454709e-08  667.174336  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b0620>
# 4  1.148154e-03  206.130680  <rdkit.Chem.rdchem.Mol object at 0x7cf7474b0990>
#
#             categories
# 0  (Neutral Organics,)
# 1                   ()
# 2                   ()
# 3                   ()
# 4  (Neutral Organics,)

# %%
tsca_df2 = tsca_df2.reset_index()

# %%
epa_cats_df = tsca_df2[['dtxsid','qsar_ready_smiles','LogP_pred','WS_pred_mol/L','MolWeight']]

# %%
epa_cats_df
# Out:
#               dtxsid                                  qsar_ready_smiles  \
# 0      DTXSID3060164               C1=CC=CC=C1C(C1C=CC=CC=1)C1C=CC=CC=1
# 1      DTXSID7060837                                              ICCCI
# 2      DTXSID9025879                    OC(=O)C=CC1C=CC(C=CC(O)=O)=CC=1
# 3      DTXSID2026282  O=C(NC1=CC2=C(NC3C4=C(C=CC2=3)C(=O)C2C(=CC=CC=...
# 4      DTXSID4052188                       CC1(C)COC(C)(OC1)C1C=CC=CC=1
# ...              ...                                                ...
# 13294  DTXSID5064209                          OC(=O)CSC1=NC2=CC=CC=C2S1
# 13295  DTXSID7062873                                       COC(=O)CCCCl
# 13296  DTXSID9040342                                      CCC1COC(=O)O1
# 13297  DTXSID3044889                 CC(C)(C)C1=CC(=O)C(=CC1=O)C(C)(C)C
# 13298  DTXSID3060667                  CC1=CC(=CC(=C1O)C(C)(C)C)C(C)(C)C
#
#        LogP_pred  WS_pred_mol/L   MolWeight
# 0           5.76   4.073803e-07  244.125201
# 1           3.02   7.413102e-04  295.855896
# 2           1.99   9.120108e-03  218.057909
# 3           3.11   2.454709e-08  667.174336
# 4           2.72   1.148154e-03  206.130680
# ...          ...            ...         ...
# 13294       1.54   9.772372e-04  224.991820
# 13295       1.55   2.041738e-01  136.029107
# 13296       0.03   9.772372e-01  116.047344
# 13297       4.26   3.981072e-03  220.146330
# 13298       5.01   1.348963e-05  220.182715
#
# [13299 rows x 5 columns]

# %%
epa_cats_df.columns = ['dsstox_sid', 'smiles', 'logp', 'ws', 'mol_weight']

# %%
epa_cats_df['mol'] = [Chem.MolFromSmiles(e) for e in epa_cats_df['smiles']]
# Out:
# <ipython-input-157-402dac51a3bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   epa_cats_df['mol'] = [Chem.MolFromSmiles(e) for e in epa_cats_df['smiles']]

# %%
epa_cats_df[epa_cats_df['mol'].isnull()]
# Out:
# Empty DataFrame
# Columns: [dsstox_sid, smiles, logp, ws, mol_weight, mol]
# Index: []

# %%
epa_cats_df.dsstox_sid.nunique()
# Out:
# 13299

# %%
epa_cats_df.shape
# Out:
# (13299, 6)

# %%
epa_cats_dict = epa_cats_df.to_dict('records')

# %%
new_tests
# Out:
# {'Aliphatic Amines': <function __main__.create_test.<locals>.test(x)>,
#  'Alkoxysilanes': <function __main__.create_test.<locals>.test(x)>,
#  'Aminobenzothiazole Azo Dyes': <function __main__.create_test.<locals>.test(x)>,
#  'Anionic Surfactants': <function __main__.create_test.<locals>.test(x)>,
#  'Benzotriazoles': <function __main__.create_test.<locals>.test(x)>,
#  'Dianilines': <function __main__.create_test.<locals>.test(x)>,
#  'Dithiocarbamates (Acute toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Dithiocarbamates (Chronic toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Ethylene Glycol Ethers': <function __main__.create_test.<locals>.test(x)>,
#  'Neutral Organics': <function __main__.create_test.<locals>.test(x)>,
#  'Nonionic Surfactants': <function __main__.create_test.<locals>.test(x)>,
#  'Organotins (Acute toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Organotins (Chronic toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Polynitroaromatics (Acute toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Polynitroaromatics (Chronic toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Substituted Triazines (Acute toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Substituted Triazines (Chronic toxicity)': <function __main__.create_test.<locals>.test(x)>,
#  'Triarylmethane Pigments/Dyes with Non-solubilizing Groups': <function __main__.create_test.<locals>.test(x)>,
#  'beta-Naphthylamines, Sulfonated': <function __main__.create_test.<locals>.test(x)>,
#  'Aldehydes (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Aldehydes (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Imides (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Imides (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Hydrazines and Related Compounds': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Thiols (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Thiols (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Acrylamides': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Acrylates/Methacrylates (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Acrylates/Methacrylates (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Epoxides': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Acid Chlorides': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Aluminum Compounds': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Anilines (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Azides (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Benzotriazoles (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Benzotriazole-hindered phenols': <function __main__.define_smart_match.<locals>.smart_match(x)>,
#  'Boron Compounds': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Cationic (quaternary ammonium) surfactants': <function __main__.define_smart_match.<locals>.smart_match(x)>,
#  'Cobalt': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Diazoniums (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Esters (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Hindered Amines': <function __main__.define_smart_match.<locals>.smart_match(x)>,
#  'Lanthanides or Rare Earth Metals': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Nickel Compounds': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Peroxides': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Phenolphthaleins': <function __main__.define_smart_match.<locals>.smart_match(x)>,
#  'Phenols (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Phosphates, Inorganic': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Phosphinate Esters (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Stilbene, derivatives of 4,4-bis(triazin-2-ylamino)-': <function __main__.define_smart_match.<locals>.smart_match(x)>,
#  'Vinyl Esters (Acute toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Vinyl Sulfones': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Soluble complexes of Zinc': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Anhydrides, Carboxylic acid': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Dichlorobenzidine-based Pigments': <function __main__.define_smart_match.<locals>.smart_match(x)>,
#  'Diisocyanates': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Rosin': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Zirconium Compounds': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Anilines (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Azides (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Benzotriazoles (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Esters (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Phenols (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Phosphinate Esters (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Vinyl Esters (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>,
#  'Diazoniums (Chronic toxicity)': <function __main__.Query.write_query.<locals>.func(x)>}

# %%
for record in epa_cats_dict:
    #print(record)
    epa_categories=sorted([category for category,test in new_tests.items() if test(record)])
    if 'Neutral Organics' in epa_categories and len(epa_categories)>1:
        epa_categories.remove('Neutral Organics')
    record['categories']=tuple(epa_categories)

# %%
epa_cats_dict_df = pd.DataFrame(epa_cats_dict)

# %%
epa_cats_dict_df.columns
# Out:
# Index(['dsstox_sid', 'smiles', 'logp', 'ws', 'mol_weight', 'mol',
#        'categories'],
#       dtype='object')

# %%
epa_cats_dict_df['categories'].value_counts()
# Out:
# ()                                                                   5699
# (Neutral Organics,)                                                  2667
# (Esters (Acute toxicity),)                                           1310
# (Phenols (Acute toxicity),)                                           502
# (Anilines (Acute toxicity),)                                          407
#                                                                      ...
# (Aldehydes (Chronic toxicity), Phenols (Acute toxicity))                1
# (Substituted Triazines (Acute toxicity), Thiols (Acute toxicity))       1
# (Aldehydes (Acute toxicity), Nonionic Surfactants)                      1
# (Azides (Chronic toxicity),)                                            1
# (Acrylamides, Cationic (quaternary ammonium) surfactants)               1
# Name: categories, Length: 143, dtype: int64

# %%
epa_dict = {k:v for k,v in zip(epa_cats_dict_df['dsstox_sid'],epa_cats_dict_df['categories'] )}

# %%
epa_dict = {k:v for k,v in epa_dict.items() if len(v) != 0}

# %% [markdown]
# #### Add NCC tag to the main TSCA set

# %%
tsca_df = tsca_df.drop('Unnamed: 0', axis = 1)

# %%
tsca_df['NCC'] = tsca_df['dtxsid'].apply(lambda x : epa_dict[x] if x in epa_dict.keys() else np.nan)

# %%
tsca_df['NCC'].value_counts(dropna = False)
# Out:
# NaN                                                                                                6647
# (Neutral Organics,)                                                                                2667
# (Esters (Acute toxicity),)                                                                         1310
# (Phenols (Acute toxicity),)                                                                         502
# (Anilines (Acute toxicity),)                                                                        407
#                                                                                                    ...
# (Aldehydes (Chronic toxicity), Phenols (Acute toxicity))                                              1
# (Hydrazines and Related Compounds, Polynitroaromatics (Acute toxicity))                               1
# (Substituted Triazines (Acute toxicity), Thiols (Acute toxicity))                                     1
# (Alkoxysilanes, Anilines (Acute toxicity))                                                            1
# (Esters (Chronic toxicity), Phenols (Acute toxicity), Substituted Triazines (Chronic toxicity))       1
# Name: NCC, Length: 143, dtype: int64

# %%
tsca_df.dtxsid.nunique()
# Out:
# 14247

# %%
tsca_df.shape
# Out:
# (14247, 94)

# %% [markdown]
# #### Tag DTXSID by vendor number to give an indicator of procurability

# %%
vendors = pd.read_excel(raw_dir+'TSCA_Active_ChemicalVendors_Summary_0218_2022.xlsx')

# %%
vendors.rename(columns = {'DTXSID': 'dtxsid'}, inplace = True)

# %%
vendors.columns
# Out:
# Index(['dtxsid', 'PREFERRED_NAME', 'CASRN', 'INCHIKEY', 'PUBCHEM_CID',
#        'VENDOR_COUNT', 'IN_SIGMA-ALDRICH'],
#       dtype='object')

# %%
vendors = vendors[vendors['dtxsid'].isin(tsca_df['dtxsid'].tolist())]

# %%
vendors.shape
# Out:
# (14726, 7)

# %%
vendors.dtxsid.nunique()
# Out:
# 13996

# %%
vendors2 = vendors.groupby('dtxsid').agg({'VENDOR_COUNT': 'mean', 'IN_SIGMA-ALDRICH': 'mean'}).reset_index()

# %%
vendors2
# Out:
#                 dtxsid  VENDOR_COUNT  IN_SIGMA-ALDRICH
# 0      DTXSID001007489           0.0               0.0
# 1      DTXSID001014212           NaN               NaN
# 2      DTXSID001014274           0.0               0.0
# 3      DTXSID001014286           NaN               NaN
# 4      DTXSID001014393           5.0               0.0
# ...                ...           ...               ...
# 13991   DTXSID90979094           8.0               0.0
# 13992   DTXSID90988262           0.0               0.0
# 13993   DTXSID90988560           3.0               0.0
# 13994   DTXSID90997177           NaN               NaN
# 13995   DTXSID90999090          28.0               0.5
#
# [13996 rows x 3 columns]

# %%
final_input_df = pd.merge(tsca_df, vendors2[['dtxsid','VENDOR_COUNT', 'IN_SIGMA-ALDRICH']],  on = 'dtxsid', how = 'left')

# %%
final_input_df
# Out:
#               dtxsid                                  PREFERRED_NAME  \
# 0      DTXSID3060164                               Benzhydrylbenzene
# 1      DTXSID7060837                            Propane, 1,3-diiodo-
# 2      DTXSID9025879                3,3'-(p-Phenylene)diacrylic acid
# 3      DTXSID2026282                                C.I. Vat brown 3
# 4      DTXSID4052188            2,5,5-Trimethyl-2-phenyl-1,3-dioxane
# ...              ...                                             ...
# 14242  DTXSID5064209              2-(Carboxymethylthio)benzothiazole
# 14243  DTXSID7062873          Butanoic acid, 4-chloro-, methyl ester
# 14244  DTXSID9040342                      4-Ethyl-1,3-dioxolan-2-one
# 14245  DTXSID3044889  2,5-Di-tert-butylcyclohexa-2,5-diene-1,4-dione
# 14246  DTXSID3060667    Phenol, 2,4-bis(1,1-dimethylethyl)-6-methyl-
#
#             CASRN                     INCHIKEY  \
# 0        519-73-3  AAAQKTZKLRYKHR-UHFFFAOYSA-N
# 1        627-31-6  AAAXMNYUNVCMCJ-UHFFFAOYSA-N
# 2      16323-43-6  AAFXQFIGKBLKMC-UHFFFAOYSA-N
# 3        131-92-0  AAKMSGQPNUGLAZ-UHFFFAOYSA-N
# 4       5406-58-6  AALXTPRRKXUUOM-UHFFFAOYSA-N
# ...           ...                          ...
# 14242   6295-57-4  ZZUQWNYNSKJLPI-UHFFFAOYSA-N
# 14243   3153-37-5  ZZUYIRISBMWFMV-UHFFFAOYSA-N
# 14244   4437-85-8  ZZXUZKXVROWEIF-UHFFFAOYSA-N
# 14245   2460-77-7  ZZYASVWWDLJXIM-UHFFFAOYSA-N
# 14246    616-55-7  ZZZRZBIPCKQDQR-UHFFFAOYSA-N
#
#                                               IUPAC_NAME  \
# 0                        1,1',1''-Methanetriyltribenzene
# 1                                      1,3-Diiodopropane
# 2              3,3'-(1,4-Phenylene)di(prop-2-enoic acid)
# 3      N,N'-(5,10,15,17-Tetraoxo-10,15,16,17-tetrahyd...
# 4                   2,5,5-Trimethyl-2-phenyl-1,3-dioxane
# ...                                                  ...
# 14242       [(1,3-Benzothiazol-2-yl)sulfanyl]acetic acid
# 14243                           Methyl 4-chlorobutanoate
# 14244                         4-Ethyl-1,3-dioxolan-2-one
# 14245     2,5-Di-tert-butylcyclohexa-2,5-diene-1,4-dione
# 14246                   2,4-Di-tert-butyl-6-methylphenol
#
#                                                   SMILES  \
# 0                 C1=CC=C(C=C1)C(C1=CC=CC=C1)C1=CC=CC=C1
# 1                                                  ICCCI
# 2                        OC(=O)C=CC1=CC=C(C=CC(O)=O)C=C1
# 3      O=C(NC1=CC=CC2=C1C(=O)C1=C(C3=C(C=C1)C1=C(N3)C...
# 4                           CC1(C)COC(C)(OC1)C1=CC=CC=C1
# ...                                                  ...
# 14242                          OC(=O)CSC1=NC2=CC=CC=C2S1
# 14243                                       COC(=O)CCCCl
# 14244                                      CCC1COC(=O)O1
# 14245                 CC(C)(C)C1=CC(=O)C(=CC1=O)C(C)(C)C
# 14246                  CC1=CC(=CC(=C1O)C(C)(C)C)C(C)(C)C
#
#                                             INCHI_STRING MOLECULAR_FORMULA  \
# 0      InChI=1S/C19H16/c1-4-10-16(11-5-1)19(17-12-6-2...            C19H16
# 1                      InChI=1S/C3H6I2/c4-2-1-3-5/h1-3H2            C3H6I2
# 2      InChI=1S/C12H10O4/c13-11(14)7-5-9-1-2-10(4-3-9...          C12H10O4
# 3      InChI=1S/C42H23N3O6/c46-37-24-14-7-8-15-25(24)...        C42H23N3O6
# 4      InChI=1S/C13H18O2/c1-12(2)9-14-13(3,15-10-12)1...          C13H18O2
# ...                                                  ...               ...
# 14242  InChI=1S/C9H7NO2S2/c11-8(12)5-13-9-10-6-3-1-2-...         C9H7NO2S2
# 14243      InChI=1S/C5H9ClO2/c1-8-5(7)3-2-4-6/h2-4H2,1H3          C5H9ClO2
# 14244    InChI=1/C5H8O3/c1-2-4-3-7-5(6)8-4/h4H,2-3H2,1H3            C5H8O3
# 14245  InChI=1S/C14H20O2/c1-13(2,3)9-7-12(16)10(8-11(...          C14H20O2
# 14246  InChI=1S/C15H24O/c1-10-8-11(14(2,3)4)9-12(13(1...           C15H24O
#
#        AVERAGE_MASS  MONOISOTOPIC_MASS  ...  errors  \
# 0           244.337         244.125201  ...     NaN
# 1           295.890         295.855890  ...     NaN
# 2           218.208         218.057909  ...     NaN
# 3           665.661         665.158685  ...     NaN
# 4           206.285         206.130680  ...     NaN
# ...             ...                ...  ...     ...
# 14242       225.280         224.991821  ...     NaN
# 14243       136.580         136.029107  ...     NaN
# 14244       116.116         116.047344  ...     NaN
# 14245       220.312         220.146330  ...     NaN
# 14246       220.356         220.182715  ...     NaN
#
#                                        qsar_ready_smiles           HLC  \
# 0                   C1=CC=CC=C1C(C1C=CC=CC=1)C1C=CC=CC=1  2.630268e-06
# 1                                                  ICCCI  2.454709e-03
# 2                        OC(=O)C=CC1C=CC(C=CC(O)=O)=CC=1  6.025596e-10
# 3      O=C(NC1=CC2=C(NC3C4=C(C=CC2=3)C(=O)C2C(=CC=CC=...  2.630268e-09
# 4                           CC1(C)COC(C)(OC1)C1C=CC=CC=1  9.772372e-05
# ...                                                  ...           ...
# 14242                          OC(=O)CSC1=NC2=CC=CC=C2S1  3.388442e-09
# 14243                                       COC(=O)CCCCl  2.818383e-04
# 14244                                      CCC1COC(=O)O1  2.570396e-08
# 14245                 CC(C)(C)C1=CC(=O)C(=CC1=O)C(C)(C)C  5.370318e-04
# 14246                  CC1=CC(=CC(=C1O)C(C)(C)C)C(C)(C)C  8.128305e-06
#
#       WS_pred_mol/L   WS_pred_mg/L  test_track  physical_form  \
# 0      4.073803e-07       0.099452           B          solid
# 1      7.413102e-04     219.321006           B         liquid
# 2      9.120108e-03    1988.711764           B          solid
# 3      2.454709e-08       0.016377           B          solid
# 4      1.148154e-03     236.669687           B          solid
# ...             ...            ...         ...            ...
# 14242  9.772372e-04     219.870381           B          solid
# 14243  2.041738e-01   27773.578977           B         liquid
# 14244  9.772372e-01  113405.784063           B         liquid
# 14245  3.981072e-03     876.418325           B          solid
# 14246  1.348963e-05       2.970183           B          solid
#
#                                NCC  VENDOR_COUNT  IN_SIGMA-ALDRICH
# 0              (Neutral Organics,)          75.0               1.0
# 1                              NaN          72.0               1.0
# 2                              NaN          13.0               0.0
# 3                              NaN          13.5               0.0
# 4              (Neutral Organics,)          11.0               0.0
# ...                            ...           ...               ...
# 14242                          NaN          79.0               1.0
# 14243   (Esters (Acute toxicity),)          71.0               1.0
# 14244          (Neutral Organics,)          49.0               1.0
# 14245                          NaN          61.0               1.0
# 14246  (Phenols (Acute toxicity),)          33.0               1.0
#
# [14247 rows x 96 columns]

# %%
writer = pd.ExcelWriter(interim_dir+'tsca_struct_input_080722.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.

final_input_df.to_excel(writer)

writer.save()
