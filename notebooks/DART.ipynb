# %%
import pandas as pd
import numpy as np

import sys
import os
from datetime import datetime

from rdkit import Chem

# %%
TOP = os.getcwd().replace('notebooks', '')
raw_dir = TOP + 'data/raw/'
interim_dir = TOP + 'data/interim/'
external_dir = TOP + 'data/external/'
figures_dir = TOP + 'reports/figures/'

# %%
with open(raw_dir + 'Copy of Oncologic Primary Classification.plugin.config','r') as f:
    xml=f.read()

# %%
xml=xml.replace('\n','')

# %%
#xml

# %%
import xml.etree.ElementTree as ET
e=ET.parse(raw_dir+'Copy of Oncologic Primary Classification.plugin.config').getroot()

# %%
import re
import ast

# %%
class Query:
    
    def __init__(self,xml,qid=None):
        self.xml=xml
        self.id=qid
        self.logic=None
        self.subqueries=[]
        self.category=None
        
    def write_query(self,qtype,tree):
        self.type=qtype
        if qtype=='b:StructureQuery':
            qstring=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch').text
            qstring=re.sub('false','False',qstring)
            qstring=re.sub('true','True',qstring)
            qdict=ast.literal_eval(qstring)
            smart=qdict['queries'][0]['smart']
            self.smart=smart
            print(self.smart)
            if '[Ch3,#1]' in self.smart:
                split=re.search(r'(.*)\[([^\(\)]*),([^\(\)].*)\]$',self.smart)
                split1=split.group(1)
                split2=split.group(1)+'['+split.group(2)+']'
                smart_match1=define_smart_match(split1)
                smart_match2=define_smart_match(split2)
                def smart_match(x):
                    return any([smart_match1(x),smart_match2(x)])
            else:
                smart_match=define_smart_match(smart)
            self.query=smart_match
        elif qtype=='b:ParameterQuery':
            self.operand=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}Operand').text
            self.prop=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ParameterName').text
            self.value=float(self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}Value').text)
            compare=define_compare(self.prop,self.operand,self.value)
            self.query=compare
        elif qtype=='LogicalQuery':
            self.logic=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Logic').text
            elements=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Elements')
            node_ids=[elem.attrib['{http://schemas.microsoft.com/2003/10/Serialization/}Ref']\
                      for elem in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query')\
                      if '{http://schemas.microsoft.com/2003/10/Serialization/}Ref' in elem.attrib]
            if self.logic=='Not':
                node_id=node_ids[0] #Should only be one
                sq=tree[node_id]
                self.subqueries=[sq]
                def func(x):
                    return not(sq.query(x))
                self.query=func
            elif self.logic=='And':
                sqs=[tree[node_id] for node_id in node_ids]
                self.subqueries=sqs
                def func(x):
                    return all([sq.query(x) for sq in self.subqueries])
                self.query=func
            else:
                sqs=[tree[node_id] for node_id in node_ids]
                self.subqueries=sqs
                for orquery in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query'):
                    if '{http://www.w3.org/2001/XMLSchema-instance}type' in orquery.attrib:
                        extra_sq=Query(orquery)
                        extra_sq.write_query('b:StructureQuery',tree)
                        sqs.append(extra_sq)      
                def func(x):
                    return any([sq.query(x) for sq in self.subqueries])
                self.query=func
    
    def print_tree(self,x,tabs=0):
        qinfo=(self.id,self.type)
        if self.type=='b:StructureQuery':
            qinfo=qinfo+(self.smart,)
        elif self.type=='b:ParameterQuery':
            qinfo=qinfo+(self.prop,self.value,self.operand)
        elif self.type=='LogicalQuery':
            qinfo=qinfo+(self.logic,)
        try:
            qinfo=qinfo+(self.query(x),)
        except:
            qinfo=qinfo+('does not process',)
        print('\t'*tabs+str(qinfo))
        for sq in self.subqueries:
            sq.print_tree(x,tabs+1)

# %%
def define_smart_match(smart):
    pattern=Chem.MolFromSmarts(smart)
    if not pattern:
        return None
    def smart_match(x):
        mol=x['mol']
        ret=True if mol.GetSubstructMatches(pattern) else False
        return ret
    return smart_match
def define_compare(prop,operand,value):
    def compare(x):
        ret = op_dict[operand](x[prop_dict[prop]],value)
        return ret
    return compare

# %%
import operator as op
op_dict={
    'GreaterThan': op.gt,
    'GreaterThanOrEqualTo': op.ge,
    'LessThan': op.lt,
    'LessThanOrEqualTo': op.le
}
prop_dict={
    'log Kow':'logp',
    'Molecular Weight':'mol_weight',
    'Molecular weight':'mol_weight',
    'Water Solubility': 'ws'
}

# %%
q = Query(xml)

# %%
for elem in e.iter('{http://schemas.microsoft.com/2003/10/Serialization/Arrays}anyType'):
    category=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Caption').text
    queries=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Expression')\
        .find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Queries')\
        .findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query')
    contents=[query.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content') for query in queries]
    query_tree={}
    for query in contents:
        attributes=query.attrib
        if '{http://schemas.microsoft.com/2003/10/Serialization/}Id' not in attributes:
            continue
        query_id=attributes['{http://schemas.microsoft.com/2003/10/Serialization/}Id']
        query_type=attributes['{http://www.w3.org/2001/XMLSchema-instance}type']
        q=Query(query,query_id)
        q.category = category
        q.write_query(query_type,query_tree)
# Out:
# [#8]([#6R0]=[#6R0])[#6](=[#8])[#6]=[#6]
# [#8]([#6X4])[#6](=[#8])[#6]=[#6]
# [#6](=[#8])([#6]=[#6])[O]c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 16
#      14 q=Query(query,query_id)
#      15 q.category = category
# ---> 16 q.write_query(query_type,query_tree)
#
# Cell In[70], line 57, in Query.write_query(self, qtype, tree)
#      55     self.query=func
#      56 else:
# ---> 57     sqs=[tree[node_id] for node_id in node_ids]
#      58     self.subqueries=sqs
#      59     for orquery in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query'):
#
# Cell In[70], line 57, in <listcomp>(.0)
#      55     self.query=func
#      56 else:
# ---> 57     sqs=[tree[node_id] for node_id in node_ids]
#      58     self.subqueries=sqs
#      59     for orquery in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query'):
#
# KeyError: '23'

# %%
all_tests={}
print_tests = {}
bad_smarts=set()
bad_cats=set()
for elem in e.iter('{http://schemas.microsoft.com/2003/10/Serialization/Arrays}anyType'):
    category=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Caption').text
    queries=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Expression')\
        .find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Queries')\
        .findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query')
    contents=[query.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content') for query in queries]
    query_tree={}
    for query in contents:
        attributes=query.attrib
        if '{http://schemas.microsoft.com/2003/10/Serialization/}Id' not in attributes:
            continue
        query_id=attributes['{http://schemas.microsoft.com/2003/10/Serialization/}Id']
        query_type=attributes['{http://www.w3.org/2001/XMLSchema-instance}type']
        try:
            q=Query(query,query_id)
            q.category=category
            q.write_query(query_type,query_tree)
            q.print_tree(q.query)
            if not q.query or not all([sq.query for sq in q.subqueries]): #Smarts did not compile, sqs needed bc of hidden sqs in or queries
                bad_cats.add(category)
                if q.type=='b:StructureQuery':
                    bad_smarts.add(q.smart)
        except Exception as error:
            print(error)
        finally:
            query_tree[query_id]=q
        all_tests[category]=query_tree[query_id]
        print_tests[category] = [query_id, query_type]#
# Out:
# [#8]([#6R0]=[#6R0])[#6](=[#8])[#6]=[#6]
# ('23', 'b:StructureQuery', '[#8]([#6R0]=[#6R0])[#6](=[#8])[#6]=[#6]', 'does not process')
# [#8]([#6X4])[#6](=[#8])[#6]=[#6]
# ('25', 'b:StructureQuery', '[#8]([#6X4])[#6](=[#8])[#6]=[#6]', 'does not process')
# [#6](=[#8])([#6]=[#6])[O]c
# ('27', 'b:StructureQuery', '[#6](=[#8])([#6]=[#6])[O]c', 'does not process')
# ('29', 'LogicalQuery', 'Or', 'does not process')
# 	('23', 'b:StructureQuery', '[#8]([#6R0]=[#6R0])[#6](=[#8])[#6]=[#6]', 'does not process')
# 	('25', 'b:StructureQuery', '[#8]([#6X4])[#6](=[#8])[#6]=[#6]', 'does not process')
# 	('27', 'b:StructureQuery', '[#6](=[#8])([#6]=[#6])[O]c', 'does not process')
# [#8]=[C]([#7v3]([[#1],c,CX4])[[#1],c,CX4])[C]=[C]
# ('39', 'b:StructureQuery', '[#8]=[C]([#7v3]([[#1],c,CX4])[[#1],c,CX4])[C]=[C]', 'does not process')
# [#6](=[#6])[C]([Nv3]([CR0]=[CR0])[c,CX4,#1])=[O]
# ('41', 'b:StructureQuery', '[#6](=[#6])[C]([Nv3]([CR0]=[CR0])[c,CX4,#1])=[O]', 'does not process')
# [#7v3]([#6](=[#8])[#6]=[#6])([#6R0]=[#6R0])[#6R0]=[#6R0]
# ('43', 'b:StructureQuery', '[#7v3]([#6](=[#8])[#6]=[#6])([#6R0]=[#6R0])[#6R0]=[#6R0]', 'does not process')
# 'smart'
# ('47', 'LogicalQuery', 'Not', 'does not process')
# 'Query' object has no attribute 'smart'
# ('49', 'LogicalQuery', 'Or', 'does not process')
# 	('39', 'b:StructureQuery', '[#8]=[C]([#7v3]([[#1],c,CX4])[[#1],c,CX4])[C]=[C]', 'does not process')
# 	('41', 'b:StructureQuery', '[#6](=[#6])[C]([Nv3]([CR0]=[CR0])[c,CX4,#1])=[O]', 'does not process')
# ('51', 'LogicalQuery', 'And', 'does not process')
# 	('49', 'LogicalQuery', 'Or', 'does not process')
# 		('39', 'b:StructureQuery', '[#8]=[C]([#7v3]([[#1],c,CX4])[[#1],c,CX4])[C]=[C]', 'does not process')
# 		('41', 'b:StructureQuery', '[#6](=[#6])[C]([Nv3]([CR0]=[CR0])[c,CX4,#1])=[O]', 'does not process')
# 	('47', 'LogicalQuery', 'Not', 'does not process')
# 'Query' object has no attribute 'smart'
# ('53', 'LogicalQuery', 'Or', 'does not process')
# 	('51', 'LogicalQuery', 'And', 'does not process')
# 		('49', 'LogicalQuery', 'Or', 'does not process')
# 			('39', 'b:StructureQuery', '[#8]=[C]([#7v3]([[#1],c,CX4])[[#1],c,CX4])[C]=[C]', 'does not process')
# 			('41', 'b:StructureQuery', '[#6](=[#6])[C]([Nv3]([CR0]=[CR0])[c,CX4,#1])=[O]', 'does not process')
# 		('47', 'LogicalQuery', 'Not', 'does not process')
# 'Query' object has no attribute 'smart'
# [#8]=[#6]{>-1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}
# ('63', 'b:StructureQuery', '[#8]=[#6]{>-1}.$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}', 'does not process')
# [#1][#6v4]=O
# ('73', 'b:StructureQuery', '[#1][#6v4]=O', 'does not process')
# [C][C][O][C]([C][C]([O][C][C])[O][C][C])[O][C][C]
# ('75', 'b:StructureQuery', '[C][C][O][C]([C][C]([O][C][C])[O][C][C])[O][C][C]', 'does not process')
# ('77', 'LogicalQuery', 'Or', 'does not process')
# 	('75', 'b:StructureQuery', '[C][C][O][C]([C][C]([O][C][C])[O][C][C])[O][C][C]', 'does not process')
# 	('73', 'b:StructureQuery', '[#1][#6v4]=O', 'does not process')
# [#7v3]($[$[$[[#6]{>-1}=[#6]{>-2}{>-3}.$[[#1]{<-3},[#8h]{<-3},[#6]{<-3}([#8h])=[#8],[#16]{<-3}([#8h])(=[#8])=[#8],F{<-3},Cl{<-3},Br{<-3},I{<-3},[#6]{<-3}#[#7v3],[#8]{<-3}[#6X4],[#8]{<-3}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6]{<-2}#[#7v3],[#8]{<-2}[#6X4],[#8]{<-2}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6]{<-1}#[#7v3],[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4]]{1},[#6]{>-1}([#6]{>-4}{>-5})=[#6]{>-2}{>-3}.$[[#1]{<-5},[#8h]{<-5},[#6]{<-5}([#8h])=[#8],[#16]{<-5}([#8h])(=[#8])=[#8],F{<-5},Cl{<-5},Br{<-5},I{<-5},[#6]{<-5}#[#7v3],[#8]{<-5}[#6X4],[#8]{<-5}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-4},[#8h]{<-4},[#6]{<-4}([#8h])=[#8],[#16]{<-4}([#8h])(=[#8])=[#8],F{<-4},Cl{<-4},Br{<-4},I{<-4},[#6]{<-4}#[#7v3],[#8]{<-4}[#6X4],[#8]{<-4}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-3},[#8h]{<-3},[#6]{<-3}([#8h])=[#8],[#16]{<-3}([#8h])(=[#8])=[#8],F{<-3},Cl{<-3},Br{<-3},I{<-3},[#6]{<-3}#[#7v3],[#8]{<-3}[#6X4],[#8]{<-3}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6]{<-2}#[#7v3],[#8]{<-2}[#6X4],[#8]{<-2}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6]{<-1}#[#7v3],[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4]]{1}]{1..;x}],$[$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1},[#6R0X4]{>-1}{>-2}.$[[#7v3]#[#6]{<-2},[#8]{<-2}[#6](=[#8])[#6X4],[#8]{<-2}[#6X4]]{1}.$[[#7v3]#[#6]{<-1},[#8]{<-1}[#6](=[#8])[#6X4],[#8]{<-1}[#6X4]]{1},[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#7v3]#[#6]{<-1},[#8]{<-1}[#6](=[#8])[#6X4],[#8]{<-1}[#6X4]]{1}]{1..;x}],$[$[[#6]1[#6][#6][#6][#6][#6]1,[#6]{>-1}1[#6][#6][#6][#6][#6]1.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6]{<-1}#[#7v3],[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4]]{1},[#6R0X4],[#6R0X3]]{1..;x}],$[$[c1ccccc1,[#6h2]c1ccccc1,[#6h2][#6h2]c1ccccc1,c{>-1}1ccccc1.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6]{<-1}#[#7v3],[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4]]{
[#6](=[#8])[#6X4]]{1}.$[[#1]{<-3},[#8h]{<-3},[#6]{<-3}([#8h])=[#8],[#16]{<-3}([#8h])(=[#8])=[#8],F{<-3},Cl{<-3},Br{<-3},I{<-3},[#6]{<-3}#[#7v3],[#8]{<-3}[#6X4],[#8]{<-3}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6]{<-2}#[#7v3],[#8]{<-2}[#6X4],[#8]{<-2}[#6](=[#8])[#6X4]]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6]{<-1}#[#7v3],[# ...
# [#8]([#16](=[#8])(=[#8])$[[CX4],[#1]]{1..;x})$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])$[[CX4],[#1]]{1..;x}
# ('101', 'b:StructureQuery', '[#8]([#16](=[#8])(=[#8])$[[CX4],[#1]]{1..;x})$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])$[[CX4],[#1]]{1..;x}', 'does not process')
# [#8]([#16](=[#8])(=[#8])$[c1ccccc1]{1..;x})$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])$[c1ccccc1]{1..;x}
# ('103', 'b:StructureQuery', '[#8]([#16](=[#8])(=[#8])$[c1ccccc1]{1..;x})$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])$[c1ccccc1]{1..;x}', 'does not process')
# [#8]([#16](=[#8])(=[#8])c1[ch][ch]c([#6h3])[ch][ch]1)$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])c1[ch][ch]c([#6h3])[ch][ch]1
# ('105', 'b:StructureQuery', '[#8]([#16](=[#8])(=[#8])c1[ch][ch]c([#6h3])[ch][ch]1)$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])c1[ch][ch]c([#6h3])[ch][ch]1', 'does not process')
# [#6][#16](=[#8])(=[#8])[#8][#6][#6]#[#6][#6][#8][#16]([#6])(=[#8])=[#8]
# ('107', 'b:StructureQuery', '[#6][#16](=[#8])(=[#8])[#8][#6][#6]#[#6][#6][#8][#16]([#6])(=[#8])=[#8]', 'does not process')
# ('109', 'LogicalQuery', 'Or', 'does not process')
# 	('101', 'b:StructureQuery', '[#8]([#16](=[#8])(=[#8])$[[CX4],[#1]]{1..;x})$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])$[[CX4],[#1]]{1..;x}', 'does not process')
# 	('103', 'b:StructureQuery', '[#8]([#16](=[#8])(=[#8])$[c1ccccc1]{1..;x})$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])$[c1ccccc1]{1..;x}', 'does not process')
# 	('105', 'b:StructureQuery', '[#8]([#16](=[#8])(=[#8])c1[ch][ch]c([#6h3])[ch][ch]1)$[[#6R0X4]{>-1}{>-2}.$[[#1]{<-2},[#8h]{<-2},[#6]{<-2}([#8h])=[#8],[#16]{<-2}([#8h])(=[#8])=[#8],F{<-2},Cl{<-2},Br{<-2},I{<-2},[#6X4]{<-2}]{1}.$[[#1]{<-1},[#8h]{<-1},[#6]{<-1}([#8h])=[#8],[#16]{<-1}([#8h])(=[#8])=[#8],F{<-1},Cl{<-1},Br{<-1},I{<-1},[#6X4]{<-1}]{1}]{1..;x}[#8][#16](=[#8])(=[#8])c1[ch][ch]c([#6h3])[ch][ch]1', 'does not process')
# 	('107', 'b:StructureQuery', '[#6][#16](=[#8])(=[#8])[#8][#6][#6]#[#6][#6][#8][#16]([#6])(=[#8])=[#8]', 'does not process')
# [#8]=[#16](=[#8])([#8]$[[CR0X4],[#6R0]=[#6R0],[#1]]{1..;x})[#8]$[[#6R0X4],[#6R0]=[#6R0],[#1]]{1..;x}
# ('119', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[[CR0X4],[#6R0]=[#6R0],[#1]]{1..;x})[#8]$[[#6R0X4],[#6R0]=[#6R0],[#1]]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])([#8]{>-1})[#8]$[[CR0X4],[CR0X3]=[CR0X3],[#1]]{1..;x}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}
# ('121', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-1})[#8]$[[CR0X4],[CR0X3]=[CR0X3],[#1]]{1..;x}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}', 'does not process')
# [#8]=[#16](=[#8])([#8]$[[CR0X4],[CR0X3]=[CR0X3],[#1]]{1..;x})[#8]$[c1ccccc1]{1..;x}
# ('123', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[[CR0X4],[CR0X3]=[CR0X3],[#1]]{1..;x})[#8]$[c1ccccc1]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])([#8]{>-2})[#8]{>-1}.$[[ch]1[ch][ch]c([#6h2]{<-2})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-2})[ch][ch]1]{1}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}
# ('125', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-2})[#8]{>-1}.$[[ch]1[ch][ch]c([#6h2]{<-2})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-2})[ch][ch]1]{1}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}', 'does not process')
# [#8]=[#16](=[#8])([#8]{>-1})[#8]$[c1ccccc1]{1..;x}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}
# ('127', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-1})[#8]$[c1ccccc1]{1..;x}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}', 'does not process')
# [#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})[#8]$[c1ccccc1]{1..;x}
# ('129', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})[#8]$[c1ccccc1]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])([#8]$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x})$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}
# ('131', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x})$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])([#8]{>-1})c1[ch][ch]c([ch][ch]1)[#6h3].$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}
# ('133', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-1})c1[ch][ch]c([ch][ch]1)[#6h3].$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# [#8]=[#16]{>-1}(=[#8])[#8]$[c1ccccc1]{1..;x}.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}
# ('135', 'b:StructureQuery', '[#8]=[#16]{>-1}(=[#8])[#8]$[c1ccccc1]{1..;x}.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8]{>-1}.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}
# ('137', 'b:StructureQuery', '[#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8]{>-1}.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# [#8]=[#16]{>-1}(=[#8])[#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}
# ('139', 'b:StructureQuery', '[#8]=[#16]{>-1}(=[#8])[#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])([#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)O$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}
# ('141', 'b:StructureQuery', '[#8]=[#16](=[#8])([#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)O$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8]$[c1ccccc1]{1..;x}
# ('143', 'b:StructureQuery', '[#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8]$[c1ccccc1]{1..;x}', 'does not process')
# [#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})c1[ch][ch]c([#6h3])[ch][ch]1
# ('145', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})c1[ch][ch]c([#6h3])[ch][ch]1', 'does not process')
# [#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})[#6h2][#6h2]c1[ch][ch][ch][ch][ch]1
# ('147', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})[#6h2][#6h2]c1[ch][ch][ch][ch][ch]1', 'does not process')
# [#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1
# ('149', 'b:StructureQuery', '[#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1', 'does not process')
# [#8]=[#16](=[#8])([#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)c1[ch][ch]c([#6h3])[ch][ch]1
# ('151', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)c1[ch][ch]c([#6h3])[ch][ch]1', 'does not process')
# [#8]=[#16](=[#8])([#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)[#6h2][#6h2]c1[ch][ch][ch][ch][ch]1
# ('153', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)[#6h2][#6h2]c1[ch][ch][ch][ch][ch]1', 'does not process')
# ('155', 'LogicalQuery', 'Or', 'does not process')
# 	('119', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[[CR0X4],[#6R0]=[#6R0],[#1]]{1..;x})[#8]$[[#6R0X4],[#6R0]=[#6R0],[#1]]{1..;x}', 'does not process')
# 	('121', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-1})[#8]$[[CR0X4],[CR0X3]=[CR0X3],[#1]]{1..;x}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}', 'does not process')
# 	('123', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[[CR0X4],[CR0X3]=[CR0X3],[#1]]{1..;x})[#8]$[c1ccccc1]{1..;x}', 'does not process')
# 	('125', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-2})[#8]{>-1}.$[[ch]1[ch][ch]c([#6h2]{<-2})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-2})[ch][ch]1]{1}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}', 'does not process')
# 	('127', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-1})[#8]$[c1ccccc1]{1..;x}.$[[ch]1[ch][ch]c([#6h2]{<-1})[ch][ch]1,[ch]1[ch][ch]c([#6h2][#6h2]{<-1})[ch][ch]1]{1}', 'does not process')
# 	('129', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})[#8]$[c1ccccc1]{1..;x}', 'does not process')
# 	('131', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x})$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# 	('133', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]{>-1})c1[ch][ch]c([ch][ch]1)[#6h3].$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# 	('135', 'b:StructureQuery', '[#8]=[#16]{>-1}(=[#8])[#8]$[c1ccccc1]{1..;x}.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# 	('137', 'b:StructureQuery', '[#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8]{>-1}.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# 	('139', 'b:StructureQuery', '[#8]=[#16]{>-1}(=[#8])[#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1.$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# 	('141', 'b:StructureQuery', '[#8]=[#16](=[#8])([#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)O$[[CR0X4],[CR0X3]=[CR0X3]]{1..;x}', 'does not process')
# 	('143', 'b:StructureQuery', '[#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8]$[c1ccccc1]{1..;x}', 'does not process')
# 	('145', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})c1[ch][ch]c([#6h3])[ch][ch]1', 'does not process')
# 	('147', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8]$[c1ccccc1]{1..;x})[#6h2][#6h2]c1[ch][ch][ch][ch][ch]1', 'does not process')
# 	('149', 'b:StructureQuery', '[#8]=[#16](=[#8])($[c1ccccc1]{1..;x})[#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1', 'does not process')
# 	('151', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)c1[ch][ch]c([#6h3])[ch][ch]1', 'does not process')
# 	('153', 'b:StructureQuery', '[#8]=[#16](=[#8])([#8][#6h2][#6h2]c1[ch][ch][ch][ch][ch]1)[#6h2][#6h2]c1[ch][ch][ch][ch][ch]1', 'does not process')
# $[[Nv3]{<-1}=[#8],[#7+]{<-1}(=[#8])[#8-],[#7hv3]{<-1}[CR0X4],[Nhv3]{<-1}c,[#7v3]{<-1}(c)c,[#7v3]{<-1}(c)[CR0X4],[#7v3]{<-1}([CR0X4])[CR0X4],[Nh2v3]{<-1},[#7v3]{<-1}=[#6R0]]{1}.[a]{>-1}
# ('165', 'b:StructureQuery', '$[[Nv3]{<-1}=[#8],[#7+]{<-1}(=[#8])[#8-],[#7hv3]{<-1}[CR0X4],[Nhv3]{<-1}c,[#7v3]{<-1}(c)c,[#7v3]{<-1}(c)[CR0X4],[#7v3]{<-1}([CR0X4])[CR0X4],[Nh2v3]{<-1},[#7v3]{<-1}=[#6R0]]{1}.[a]{>-1}', 'does not process')
# [#6]1[#6](=[#8])[#8][#6](=[#8])[#6]1
# ('175', 'b:StructureQuery', '[#6]1[#6](=[#8])[#8][#6](=[#8])[#6]1', 'does not process')
# [#6]1(=[#8])[C]=[C][#6](=[#8])[O]1
# ('177', 'b:StructureQuery', '[#6]1(=[#8])[C]=[C][#6](=[#8])[O]1', 'does not process')
# [#6]1([#8][#6](=[#8])[C][C][C]1)=[#8]
# ('179', 'b:StructureQuery', '[#6]1([#8][#6](=[#8])[C][C][C]1)=[#8]', 'does not process')
# c12[#6](=[#8])[#8][#6](=[#8])c1cccc2
# ('181', 'b:StructureQuery', 'c12[#6](=[#8])[#8][#6](=[#8])c1cccc2', 'does not process')
# $[$[[#6h2X4]]{7..20}]{1..;x}1[Ch2][#6](=[#8])[O][#6](=[#8])[Ch2]1
# ('183', 'b:StructureQuery', '$[$[[#6h2X4]]{7..20}]{1..;x}1[Ch2][#6](=[#8])[O][#6](=[#8])[Ch2]1', 'does not process')
# ('185', 'LogicalQuery', 'Or', 'does not process')
# 	('175', 'b:StructureQuery', '[#6]1[#6](=[#8])[#8][#6](=[#8])[#6]1', 'does not process')
# 	('177', 'b:StructureQuery', '[#6]1(=[#8])[C]=[C][#6](=[#8])[O]1', 'does not process')
# 	('179', 'b:StructureQuery', '[#6]1([#8][#6](=[#8])[C][C][C]1)=[#8]', 'does not process')
# 	('181', 'b:StructureQuery', 'c12[#6](=[#8])[#8][#6](=[#8])c1cccc2', 'does not process')
# 	('183', 'b:StructureQuery', '$[$[[#6h2X4]]{7..20}]{1..;x}1[Ch2][#6](=[#8])[O][#6](=[#8])[Ch2]1', 'does not process')
# c1ccc([#7v3]=[#7v3]c2ccccc2)cc1
# ('195', 'b:StructureQuery', 'c1ccc([#7v3]=[#7v3]c2ccccc2)cc1', 'does not process')
# c1([#7+]#[#7])[a~1][a~1][a~1][a~1][a~1]1.$[$[[n]]{..5},[c]]{~1}
# ('205', 'b:StructureQuery', 'c1([#7+]#[#7])[a~1][a~1][a~1][a~1][a~1]1.$[$[[n]]{..5},[c]]{~1}', 'does not process')
# [Nv3](=[C][CX4])[OH]
# ('215', 'b:StructureQuery', '[Nv3](=[C][CX4])[OH]', 'does not process')
# [CX4][Nv3]=[O]
# ('217', 'b:StructureQuery', '[CX4][Nv3]=[O]', 'does not process')
# [#6][#7]1[#6]([#7])=[#6]([#7]=[#8])[#6](=[#8])[#7]([#6])[#6]1=[#8]
# ('219', 'b:StructureQuery', '[#6][#7]1[#6]([#7])=[#6]([#7]=[#8])[#6](=[#8])[#7]([#6])[#6]1=[#8]', 'does not process')
# [#6](c)=[Nv3][Oh]
# ('221', 'b:StructureQuery', '[#6](c)=[Nv3][Oh]', 'does not process')
# [#7v3](=[#8])c
# ('223', 'b:StructureQuery', '[#7v3](=[#8])c', 'does not process')
# ('225', 'LogicalQuery', 'Or', 'does not process')
# 	('215', 'b:StructureQuery', '[Nv3](=[C][CX4])[OH]', 'does not process')
# 	('217', 'b:StructureQuery', '[CX4][Nv3]=[O]', 'does not process')
6]]{1..;x}],$[$[[#8v2],[#6X4],[#6]=[#6]]{1..;x}]])[#6]{>-2}($[[#1],[#8h],[#6]#[#7v3],[#6h]=[#8],[#6](=[#8])[#8h],[#16](=[#8])([#8h])=[#8],F,Cl,Br,I,[#6](=[#8])[#7v3]$[[#6R0X4],[#6R0]=[#6R0],[#1]]{1..;xm},[#6](=[#8])[#7h2v3],[#6](=[#8])[#7hv3]$[[#6R0X4],[#6R0]=[#6R0],[#1]]{1..;x},$[$[[#6X4],[#6](F)=[#8],[#6](Cl)=[#8],[#6](Br)=[#8],[#6](I)=[#8],[#6]=[#6]]{1..;x}],$[$[[#6X4],[#8h],[#6]=[#6]]{1..;x}],$[$[[#8v2],[#6X4],[#6]=[#6]]{1..;x}]])=[#6]{>-1}2$[[#1],[#8h],[#6]#[#7v3],[#6h]=[#8],[#6](=[#8])[#8h],[#16](=[#8])([#8h])=[#8],F,Cl,Br,I,[#6](=[#8])[#7v3]$[[#6R0X4],[#6R0]=[#6R0],[#1]]{1..;xm},[#6](=[#8])[#7h2v3],[#6](=[#8])[#7hv3]$[[#6R0X4],[#6R0]=[#6R0],[#1]]{1..;x},$[$[[#6X4],[#6](F)=[#8],[#6](Cl)=[#8],[#6](Br)=[#8],[#6](I)=[#8],[#6]=[#6]]{1..;x}],$[$[[#6X4],[#8h],[#6]=[#6]]{1..;x}],$[$[[#8v2],[#6X4],[#6]=[#6]]{1..;x}]]', 'does not process')
# ...
# [10:02:01] SMARTS Parse Error: syntax error while parsing: $[$[n1ccccc1]{1},$[c1ccccc1]{6}]{1..;x}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '$[$[n1ccccc1]{1},$[c1ccccc1]{6}]{1..;x}' for input: '$[$[n1ccccc1]{1},$[c1ccccc1]{6}]{1..;x}'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: $[$[[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[n]]{..1},[c]]{~1}]{..4},$[[a]1[a][a][a][n]1]{1}]{1..;x}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '$[$[[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[n]]{..1},[c]]{~1}]{..4},$[[a]1[a][a][a][n]1]{1}]{1..;x}' for input: '$[$[[a~1]1[a~1][a~1][a~1][a~1][a~1]1.$[$[[n]]{..1},[c]]{~1}]{..4},$[[a]1[a][a][a][n]1]{1}]{1..;x}'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: $[$[[n]1[c][c][c][c]1]{1},$[[a~2]1[n,c][a~2][a~2][a~2][a~2]1.$[[c],[n]]{~2}]{4}]{1..;x}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '$[$[[n]1[c][c][c][c]1]{1},$[[a~2]1[n,c][a~2][a~2][a~2][a~2]1.$[[c],[n]]{~2}]{4}]{1..;x}' for input: '$[$[[n]1[c][c][c][c]1]{1},$[[a~2]1[n,c][a~2][a~2][a~2][a~2]1.$[[c],[n]]{~2}]{4}]{1..;x}'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: [Si]{>-1}{>-2}{>-3}{>-4}($[[#1],F,Cl,Br,I,[#7h2],[#8h],$[$[[#8][#6R0X4],[#6R0X4]]{1..;x}],c1[ch][ch][ch][ch][ch]1,[#6h2]c1[ch][ch][ch][ch][ch]1,[#6h2][#6h2]c1[ch][ch][ch][ch][ch]
#8]{<-2}[#6X4],[#8]{<-2}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-2}1,[#6]{<-2}#[#7],[#6]{<-2}(=[#8])[#8][#6X4]]{1}.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},[#1],[#6]=[#8]]{1..;x}[#7R0v3][Nv3]=[O]' for input: '$[[#6X4],[#6X4]{>-1}{>-2}.$[[#1]{<-2},F{<-2},Cl{<-2},Br{<-2},I{<-2},[#8h]{<-2},[#6]{<-2}(=[#8])[#8h],[#16]{<-2}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-2},[#8]{<-2}[#6X4],[#8]{<-2}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-2}1,[#6]{<-2}#[#7],[#6]{<-2}(=[#8])[#8][#6X4]]{1}.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1}... truncated[10:02:01] SMARTS Parse Error: syntax error while parsing: $[c1ccccc1,c{>-1}1ccccc1.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},c1(ccccc1)[Ch2],c1(ccccc1)[Ch2][ch2]]{1..;xm}[#7R0v3][Nv3]=[O]
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '$[c1ccccc1,c{>-1}1ccccc1.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},c1(ccccc1)[Ch2],c1(ccccc1)[Ch2][ch2]]{1..;xm}[#7R0v3][Nv3]=[O]' for input: '$[c1ccccc1,c{>-1}1ccccc1.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},c1(ccccc1)[Ch2],c1(ccccc1)[Ch2][ch2]]{1..;xm}[#7R0v3][Nv3]=[O]'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: [Nv3](=[O])[#7R0v3]$[$[[#6]1[#6][#6][#6][#6][#6]1]{1}]{1..;xm}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '[Nv3](=[O])[#7R0v3]$[$[[#6]1[#6][#6][#6][#6][#6]1]{1}]{1..;xm}' for input: '[Nv3](=[O])[#7R0v3]$[$[[#6]1[#6][#6][#6][#6][#6]1]{1}]{1..;xm}'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: $[[CX4],[#6X4]{>-1}{>-2}.$[[#1]{<-2},F{<-2},Cl{<-2},Br{<-2},I{<-2},[#8h]{<-2},[#6]{<-2}(=[#8])[#8h],[#16]{<-2}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-2},[#8]{<-2}[#6X4],[#8]{<-2}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-2}1,[#6]{<-2}#[#7],[#6]{<-2}(=[#8])[#8][#6X4]]{1}.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},[#1],[#6]=[O]]{1..;x}[#7R0v3]([Nv3]=[O])$[c1ccccc1,c{>-1}1ccccc1.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},c1(ccccc1)[Ch2],c1(ccccc1)[Ch2][Ch2]]{1..;x}... truncated[10:02:01] SMARTS Parse Error: Failed parsing SMARTS '$[[CX4],[#6X4]{>-1}{>-2}.$[[#1]{<-2},F{<-2},Cl{<-2},Br{<-2},I{<-2},[#8h]{<-2},[#6]{<-2}(=[#8])[#8h],[#16]{<-2}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-2},[#8]{<-2}[#6X4],[#8]{<-2}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-2}1,[#6]{<-2}#[#7],[#6]{<-2}(=[#8])[#8][#6X4]]{1}.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X
#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},c1(ccccc1)[Ch2],c1(ccccc1)[Ch2][Ch2]]{1..;x}[#7R0v3]($[$[[#6]1[#6][#6][#6][#6][#6]1]{1}]{1..;x})[Nv3]=[O]
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '$[c1ccccc1,c{>-1}1ccccc1.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},c1(ccccc1)[Ch2],c1(ccccc1)[Ch2][Ch2]]{1..;x}[#7R0v3]($[$[[#6]1[#6][#6][#6][#6][#6]1]{1}]{1..;x})[Nv3]=[O]' for input: '$[c1ccccc1,c{>-1}1ccccc1.$[[#1]{<-1},F{<-1},Cl{<-1},Br{<-1},I{<-1},[#8h]{<-1},[#6]{<-1}(=[#8])[#8h],[#16]{<-1}(=[#8])([#8h])=[#8],[#16](=[#8])(=[#8])([#8h])[#8]{<-1},[#8]{<-1}[#6X4],[#8]{<-1}[#6](=[#8])[#6X4],c1cc([#16](=[#8])(=[#8])[#8])ccc{<-1}1,[#6]{<-1}#[#7],[#6]{<-1}(=[#8])[#8][#6X4]]{1},c1(ccccc1)[Ch2],c1(ccccc1)[Ch2][Ch2]]{1..;x}[#7R0v3]($[$[[#6]1[#6][#6][#6][#6][#6]1]{1}]{1..;x})[Nv3]=[O]'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: [#6](=[#6])[Sv6]{>-1}(=[#8])=[#8].$[[CX4]{<-1},[#1]{<-1},c{<-1}]{1}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '[#6](=[#6])[Sv6]{>-1}(=[#8])=[#8].$[[CX4]{<-1},[#1]{<-1},c{<-1}]{1}' for input: '[#6](=[#6])[Sv6]{>-1}(=[#8])=[#8].$[[CX4]{<-1},[#1]{<-1},c{<-1}]{1}'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: [#6]{>-1}[#16]{>-2}(=[#8])=[#8].$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}.$[[CX4]{<-2},[#1]{<-2},c{<-2}]{1}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '[#6]{>-1}[#16]{>-2}(=[#8])=[#8].$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}.$[[CX4]{<-2},[#1]{<-2},c{<-2}]{1}' for input: '[#6]{>-1}[#16]{>-2}(=[#8])=[#8].$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}.$[[CX4]{<-2},[#1]{<-2},c{<-2}]{1}'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: [#6]([#6]{>-2})[Sv2]{>-1}.$[F{<-2},Cl{<-2},Br{<-2},I{<-2}]{1}.$[[CX4]{<-1},[#1]{<-1},c{<-1}]{1}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '[#6]([#6]{>-2})[Sv2]{>-1}.$[F{<-2},Cl{<-2},Br{<-2},I{<-2}]{1}.$[[CX4]{<-1},[#1]{<-1},c{<-1}]{1}' for input: '[#6]([#6]{>-2})[Sv2]{>-1}.$[F{<-2},Cl{<-2},Br{<-2},I{<-2}]{1}.$[[CX4]{<-1},[#1]{<-1},c{<-1}]{1}'
# [10:02:01] SMARTS Parse Error: syntax error while parsing: [#16v2]([#6][#6]{>-1})[#6R0]=[#6R0].$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}
# [10:02:01] SMARTS Parse Error: Failed parsing SMARTS '[#16v2]([#6][#6]{>-1})[#6R0]=[#6R0].$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}' for input: '[#16v2]([#6][#6]{>-1})[#6R0]=[#6R0].$[F{<-1},Cl{<-1},Br{<-1},I{<-1}]{1}'

# %%
bad_cats
# Out:
# {'Acrylamide Reactive Functional Groups',
#  'Acyl and Benzoyl Type Compounds',
#  'Aliphatic Azo and Azoxy Type Compounds',
#  'Alkanesulfonoxy Ester Type Compounds',
#  'Alkyl Sulfate Type Compounds',
#  'Alpha- and beta-Haloether Reactive Functional Groups',
#  'Alpha-Haloalkylamine Reactive Functional Groups',
#  'Alpha-Halothioether Reactive Functional Groups',
#  'Anhydride Type Compounds',
#  'Aromatic Amine Type Compounds',
#  'Aryldiazonium Salts',
#  'Carbamyl Halide Type Compounds',
#  'Coumarine and Furocoumarin Type Compounds',
#  'Dicarbonyl Type Compounds',
#  'Epoxide Reactive Functional Groups',
#  'Ethyleneimine (Aziridine) Reactive Functional Groups',
#  'Halogenated Aromatic Hydrocarbon Type Compounds',
#  'Halogenated Cycloalkane Type Compounds',
#  'Halogenated Linear Aliphatic Hydrocarbone Type Compounds',
#  'Halogenated Nitroaromatic Type Compounds',
#  'Hydrazo Type Compounds',
#  'Lactone Type Reactive Functional Groups',
#  'Nitrogen Mustards Reactive Functional Groups',
#  'Nitrosamide Type Compounds',
#  'Nitrosamine Type Compounds',
#  'Organophosphorus Type Compounds',
#  'Phosgene Type Compounds',
#  'Polycyclic Aromatic Hydrocarbons - Heterocyclic',
#  'Reactive Ketone Reactive Functional Groups',
#  'Reactive Sulfone Reactive Functional Groups',
#  'Silicone and Siloxane Type Compounds',
#  'Sulfur Mustard Reactive Functional Groups',
#  'Sultone Reactive Functional Groups',
#  'Thiocarbamate Type Compounds',
#  'Thiocarbonyl Type Compounds',
#  'Triazene Type Compounds',
#  'Urea Type Compounds',
#  'ortho-Haloganated Heterocyclic Type Compounds'}

# %%
print(all_tests['Acrylate Reactive Functional Groups'])
# Out:
# <__main__.Query object at 0x7a4cf961c3a0>

# %%
import operator as op
op_dict={
    'GreaterThan': op.gt,
    'GreaterThanOrEqualTo': op.ge,
    'LessThan': op.lt,
    'LessThanOrEqualTo': op.le
}

# %%
def define_smart_match(smart):
    pattern=Chem.MolFromSmarts(smart)
    if not pattern:
        return None
    def smart_match(x):
        mol=x['mol']
        ret=True if mol.GetSubstructMatches(pattern) else False
        return ret
    return smart_match

# %%
#print(ET.tostring(e, encoding='utf8').decode('utf8'))

# %%
#[(elem.tag, elem.attrib) for elem in e.iter()]

# %%
"http://schemas.microsoft.com/2003/10/Serialization/Arrays"/><ExternalLabels

# %%
xml.find("http://schemas.microsoft.com/2003/10/Serialization/Arrays")
# Out:
# 10138

# %%
alert_dict = {}
for elem in e.iter('{http://schemas.microsoft.com/2003/10/Serialization/Arrays}string'):
    id_value = elem.attrib['{http://schemas.microsoft.com/2003/10/Serialization/}Id']
    alert_dict[id_value] = elem.text

# %%
len(alert_dict)
# Out:
# 728

# %%
import json

# %%
 smarts = []
for elem in e.iter('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch'):
        x = json.loads(elem.text)
        try:
            print(x['queries'][0]['predefined'])
        except:
            smarts.append(x['queries'][0]['smart'])
# Out:
# Organic
# Inorganic

# %%
for k, v in alert_dict.items():
    if 'Phenyl' in v:
        print(k)
# Out:
# 98
# 99
# 173
# 174

# %%
len(alert_dict)
# Out:
# 728

# %%
def remove_duplicates(input_dict):
    unique_dict = {}
    seen_values = set()

    for key, value in input_dict.items():
        if value not in seen_values:
            unique_dict[key] = value
            seen_values.add(value)

    return unique_dict

# %%
alert_dict = remove_duplicates(alert_dict)

# %%
smarts
# Out:
# ['[As,Cd,Cr,Hg,V,Al,Co,Ga,Li,Mg,Ni,Sn,Pb]',
#  '$[[#1],[#6X4]]{..;x}[#8][#6]([#6])=[#8]',
#  '$[[#6]{>-2},[#1]{>-2},[#7]{>-2}]{1}.[#6]{>-1}{<-2}=[#6h2].$[[#6]{<-1},[#1]{<-1},[#7]{<-1}]{1}',
#  '$[[#1]{>-1},[#6X4]{>-1},[#7R0v3]{>-1}]{1}.[#6h]{<-1}=[#8]',
#  '[#7][#6]([#7])=[#8]',
#  '$[[#8]{>=1},[#16v2]{>=1}]{1}.[#6]{<=1}([#7])[#7]',
#  '$[[#8]{>-1},[#7]{>-1}]{1}.[#6]{<-1}([#8])=[#8]',
#  '$[[#8]{>=2},[#7]{>=2}]{1}.[#6]{<=2}([#7])[#7,#8][#7]{>=1}.$[[#8]{<=1},[#6]{<=1}]{1}',
#  '[#6][#6]([#7v3])=[#8]',
#  '$[[#8h]{>-1},[#6h3][#8]{>-1}]{1}.c{<-1}1ccc2[#6]3[#6][#6][#6]4[#6][#6][#6][#6]4[#6]3[#6][#6]c2c1',
#  '[#6h3][#6]12[#6][#6][#6](=[#8])[#6]=[#6]1[#6][#6][#6]1[#6]2[#6][#6][#6]2[#6][#6][#6][#6]12',
#  '[#6h3][#6]12[#6]=[#6][#6](=[#8])[#6]=[#6]1[#6][#6][#6]1[#6]2[#6][#6][#6]2[#6][#6][#6][#6]12',
#  '[#6h3][#6]12[#6]=[#6][#6](=[#8])[#6]=[#6]1[#6]=[#6][#6]1[#6]2[#6][#6][#6]2[#6][#6][#6][#6]12',
#  '[#6h3][#6]12[#6][#6][#6](=[#8])[#6]=[#6]1[#6]=[#6][#6]1[#6]2[#6][#6][#6]2[#6][#6][#6][#6]12',
#  '[#8]=[#6]1[#6][#6][#6]2=[#6]3[#6][#6][#6]4[#6][#6][#6][#6]4[#6]3[#6][#6][#6]2=[#6]1',
#  '[#8]=[#6]1[#6][#6][#6]2=[#6]3[#6]=[#6][#6]4[#6][#6][#6][#6]4[#6]3[#6][#6][#6]2=[#6]1',
#  '[#8]=[#6]1[#6][#6][#6]2[#6]3[#6][#6][#6]4[#6][#6][#6][#6]4=[#6]3[#6][#6][#6]2=[#6]1',
#  '[#8]=[#6]1[#6][#6][#6]2[#6]3[#6][#6][#6]4[#6][#6][#6][#6]4[#6]3[#6][#6][#6]2=[#6]1',
#  '[#6][#6]12[#6][c]3[c][n][o][c]3[#6]=[#6]1[#6][#6][#6]1[#6]2[#6][#6][#6]2[#6][#6][#6][#6]12',
#  'c',
#  '[#8,#7,#16]1[a~1][a~1][a~1][a~1]1.$[[#7v3],[#6]]{~1}']

# %%
#xml2=ET.parse(raw_dir+'Category 1_New_Inorganics and derivatives_organophosphorus,organosiloxane compounds_2.xml').getroot()

xml_tree = ET.parse(raw_dir+'Category 1_New_Inorganics and derivatives_organophosphorus,organosiloxane compounds_2.xml')
xml_root = xml_tree.getroot()

# %%
for x in xml_root.finda('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch', "b:StructureQuery"):
    print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 for x in xml_root.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch', "b:StructureQuery"):
#       2     print(x)
#
# File ~/anaconda3/envs/py39/lib/python3.9/xml/etree/ElementPath.py:388, in find(elem, path, namespaces)
#     387 def find(elem, path, namespaces=None):
# --> 388     return next(iterfind(elem, path, namespaces), None)
#
# File ~/anaconda3/envs/py39/lib/python3.9/xml/etree/ElementPath.py:350, in iterfind(elem, path, namespaces)
#     348 cache_key = (path,)
#     349 if namespaces:
# --> 350     cache_key += tuple(sorted(namespaces.items()))
#     352 try:
#     353     selector = _cache[cache_key]
#
# AttributeError: 'str' object has no attribute 'items'

# %%
category_1 = []
for x in xml_root.iter('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch'):
    a = json.loads(x.text)['queries'][0]['smart']
    category_1.append(a)

# %%
category_1[13]
# Out:
# '[Si]{<-1}1([Ch3])[#8]$[$[O[Siv4]([Ch3])[Ch3]]{..1}]{..;x}[Siv4]([#8]$[$[[Siv4]([Ch3])([Ch3])[#8]]{1..2}]{..;x}1)([Ch3])c1[c]{<-2}[c]{<-2}[c]{<-2}[c]{<-2}[c]{<-2}1.$[[ch]1c{>-1}[ch][ch][ch][ch]1,[Ch3]{>-1}]{1}.$[[Ch3]{>-2},[Ch2]{>-2}[Ch3],[Ch2]{>-2}[Ch2][Ch3],[Ch3][Ch]{>-2}[Ch3]]{1}'

# %%
for x in xml_root.iter('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch'):
    a = x.attrib
    print(a['{http://schemas.microsoft.com/2003/10/Serialization/}Id'])
# Out:
# 17
# 19
# 21
# 23
# 25
# 29
# 192
# 194
# 207
# 209
# 254
# 256
# 309
# 311
# 313
# 315
# 317
# 319

# %%
alert_dicts = {}
for elem in xml_root.iter('http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries'):
    print(elem.tag)

# %%
alert_dicts
# Out:
# {'37': 'Male reproductive toxicity',
#  '38': 'Spectrum of developmental toxicity endpoints observed include structural malformations',
#  '39': 'n/a',
#  '40': 'False',
#  '45': 'No relevant studies identified',
#  '46': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '47': 'n/a',
#  '48': 'False',
#  '53': 'No relevant studies identified',
#  '54': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '55': 'n/a',
#  '56': 'False',
#  '61': 'No relevant studies identified',
#  '62': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '63': 'n/a',
#  '64': 'False',
#  '69': 'No relevant studies identified',
#  '70': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '71': 'n/a',
#  '72': 'False',
#  '77': 'No relevant studies identified',
#  '78': 'Spectrum of developmental toxicity endpoints observed include structural malformations',
#  '79': 'n/a',
#  '80': 'False',
#  '85': 'Male reproductive toxicity',
#  '86': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '87': 'n/a',
#  '88': 'False',
#  '93': 'Male reproductive toxicity',
#  '94': 'Spectrum of developmental toxicity endpoints observed include structural malformations',
#  '95': 'n/a',
#  '96': 'False',
#  '101': 'No relevant studies identified',
#  '102': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '103': 'n/a',
#  '104': 'False',
#  '109': 'No relevant studies identified',
#  '110': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '111': 'n/a',
#  '112': 'False',
#  '117': 'No relevant studies identified',
#  '118': 'Spectrum of developmental toxicity endpoints observed include structural malformations',
#  '119': 'n/a',
#  '120': 'False',
#  '125': 'Changes in reproductive function or fertility in both sexes',
#  '126': 'Spectrum of developmental toxicity endpoints observed include structural malformations',
#  '127': 'n/a',
#  '128': 'False',
#  '133': 'No relevant studies identified',
#  '134': 'No relevant studies identified',
#  '135': 'Not active',
#  '136': 'True',
#  '141': 'No relevant studies identified',
#  '142': 'No relevant studies identified',
#  '143': 'Not active',
#  '144': 'True',
#  '149': 'Changes in reproductive function or fertility in both sexes',
#  '150': 'Spectrum of developmental toxicity endpoints observed include structural malformations',
#  '151': 'Active',
#  '152': 'True',
#  '157': 'No relevant studies identified',
#  '158': 'No relevant studies identified',
#  '159': 'Not active',
#  '160': 'True',
#  '165': 'No relevant studies identified',
#  '166': 'No relevant studies identified',
#  '167': 'Not active',
#  '168': 'True',
#  '173': 'No relevant studies identified',
#  '174': 'No relevant studies identified',
#  '175': 'Not active',
#  '176': 'True',
#  '219': 'Changes in reproductive function or fertility in both sexes',
#  '220': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '221': 'n/a',
#  '222': 'False',
#  '227': 'Changes in reproductive function or fertility in both sexes',
#  '228': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '229': 'n/a',
#  '230': 'False',
#  '235': 'Changes in reproductive function or fertility in both sexes',
#  '236': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '237': 'n/a',
#  '238': 'False',
#  '266': 'Changes in reproductive function/fertility only occurred at doses where there was significant toxicity on other organ systems',
#  '267': 'Spectrum of developmental toxicity endpoints observed include structural malformations',
#  '268': 'n/a',
#  '269': 'False',
#  '274': 'Changes in reproductive function or fertility in both sexes',
#  '275': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '276': 'n/a',
#  '277': 'False',
#  '282': 'Changes in reproductive function or fertility in both sexes',
#  '283': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '284': 'n/a',
#  '285': 'False',
#  '290': 'Changes in reproductive function or fertility in both sexes',
#  '291': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '292': 'n/a',
#  '293': 'False',
#  '329': 'Changes in reproductive function or fertility in both sexes',
#  '330': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '331': 'n/a',
#  '332': 'False',
#  '337': 'Changes in reproductive function or fertility in both sexes',
#  '338': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '339': 'n/a',
#  '340': 'False',
#  '345': 'Changes in reproductive function or fertility in both sexes',
#  '346': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '347': 'n/a',
#  '348': 'False',
#  '353': 'Changes in reproductive function or fertility in both sexes',
#  '354': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '355': 'n/a',
#  '356': 'False',
#  '361': 'Changes in reproductive function or fertility in both sexes',
#  '362': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '363': 'n/a',
#  '364': 'False',
#  '369': 'Changes in reproductive function or fertility in both sexes',
#  '370': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '371': 'n/a',
#  '372': 'False',
#  '377': 'Changes in reproductive function or fertility in both sexes',
#  '378': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '379': 'n/a',
#  '380': 'False',
#  '385': 'Changes in reproductive function or fertility in both sexes',
#  '386': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '387': 'n/a',
#  '388': 'False',
#  '393': 'Changes in reproductive function or fertility in both sexes',
#  '394': 'For adverse effects on the fetus during pregnancy or those occurring during the perinatal period',
#  '395': 'n/a',
#  '396': 'False'}

# %%
class Query:
    
    def __init__(self,xml,qid=None):
        self.xml=xml
        self.id=qid
        self.logic=None
        self.subqueries=[]
        self.category=None
        
    def write_query(self,qtype,tree):
        self.type=qtype
        if qtype=='b:StructureQuery':
            qstring=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch').text
            qstring=re.sub('false','False',qstring)
            qstring=re.sub('true','True',qstring)
            qdict=json.loadsl(qstring)
            smart=qdict['queries'][0]['smart']
            self.smart=smart
            if '[Ch3,#1]' in self.smart:
                split=re.search(r'(.*)\[([^\(\)]*),([^\(\)].*)\]$',self.smart)
                split1=split.group(1)
                split2=split.group(1)+'['+split.group(2)+']'
                smart_match1=define_smart_match(split1)
                smart_match2=define_smart_match(split2)
                def smart_match(x):
                    return any([smart_match1(x),smart_match2(x)])
            else:
                smart_match=define_smart_match(smart)
            self.query=smart_match
            
    def print_tree(self,x,tabs=0):
        qinfo=(self.id,self.type)
        if self.type=='b:StructureQuery':
            qinfo=qinfo+(self.smart)
        try:
            qinfo=qinfo+(self.query(x),)
        except:
            qinfo=qinfo+('does not process',)
        print('\t'*tabs+str(qinfo))
        for sq in self.subqueries:
            sq.print_tree(x,tabs+1)

# %%
q = Query(xml = xml2)

# %%
q.write_query('b:StructureQuery', xml2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 q.write_query('b:StructureQuery', xml2)
#
# Cell In[149], line 13, in Query.write_query(self, qtype, tree)
#      11 self.type=qtype
#      12 if qtype=='b:StructureQuery':
# ---> 13     qstring=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch').text
#      14     qstring=re.sub('false','False',qstring)
#      15     qstring=re.sub('true','True',qstring)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
chemical_elements
# Out:
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Scheme' at 0x7f14e5aed0e0>

# %%
for el in chemical_elements.iter():
    print(el)
# Out:
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Scheme' at 0x7f14e5aed0e0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}CounterProfile' at 0x7f14e5aed450>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Credits' at 0x7f14e5aed6d0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Adopted' at 0x7f14e5aed5e0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Author' at 0x7f14e5aed720>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Changelog' at 0x7f14e5aed770>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Description' at 0x7f14e5aed810>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Disclaimer' at 0x7f14e5aed860>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Donator' at 0x7f14e5aeda90>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}LastModifiedDate' at 0x7f14e5aedd60>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Url' at 0x7f14e5aedf40>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}CustomCaptions' at 0x7f14e5aedea0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}ExternalColors' at 0x7f14e5aedef0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}ExternalLabels' at 0x7f14e5aedb80>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Filename' at 0x7f14e5aedbd0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Guid' at 0x7f14e5aedc20>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}HashModifier' at 0x7f14e5aedc70>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Name' at 0x7f14e5aedcc0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Nature' at 0x7f14e5aed900>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Nested' at 0x7f14e5aed950>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}OrderedLabelGroups' at 0x7f14e5aed9f0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}PluginConfigHeader' at 0x7f14e5aeda40>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Toolbox.General.Metadata}ModuleGuid' at 0x7f14e5aed8b0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Toolbox.General.Metadata}ModuleName' at 0x7f14e5aed540>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}ReadOnly' at 0x7f14e5aedd10>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Reference' at 0x7f14e5aedae0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Root' at 0x7f14e5aed2c0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Caption' at 0x7f14e5aed310>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Elements' at 0x7f14e5aed360>
# <Element '{http://schemas.microsoft.com/2003/10/Serialization/Arrays}anyType' at 0x7f14e5aed400>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Caption' at 0x7f14e5aed4a0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}CustomLabels' at 0x7f14e5aed220>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Expression' at 0x7f14e5aed3b0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Queries' at 0x7f14e5aed180>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e82dd540>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e82dd8b0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e82dd6d0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e82dd9f0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch' at 0x7f14e5aefae0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5aefc70>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e5aefd10>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e5aefe00>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e5aefcc0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch' at 0x7f14e5aef9a0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5aef860>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e5aef630>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e5aef680>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e5aefb80>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch' at 0x7f14e5aefa90>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5aef040>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e5aef180>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e5aef540>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e5aecef0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch' at 0x7f14e5aece50>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5aecf90>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e5aecf40>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e5aecd60>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e5aecdb0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch' at 0x7f14e5aec040>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5aec090>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e5ae8540>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e5ae8040>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e5ae81d0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch' at 0x7f14e5ae80e0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5ae8180>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e5ae8400>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e5ae8310>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e5ae8b80>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Elements' at 0x7f14e5ae8770>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5ae8a90>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e5ae8ef0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e
>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e59ec310>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}MetaInfoTable' at 0x7f14e59ec360>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}PacketProcessMode' at 0x7f14e59ec3b0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}ReferenceKey' at 0x7f14e59ec400>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}TrainingSet' at 0x7f14e59ec4a0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Chemicals' at 0x7f14e59ec4f0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Description' at 0x7f14e59ec540>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Parameters' at 0x7f14e59ec590>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}YesLabel' at 0x7f14e59ec5e0>
# <Element '{http://schemas.microsoft.com/2003/10/Serialization/Arrays}anyType' at 0x7f14e59ec630>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Caption' at 0x7f14e59ec680>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}CustomLabels' at 0x7f14e59ec6d0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Expression' at 0x7f14e59ec720>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Queries' at 0x7f14e59ec770>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query' at 0x7f14e59ec7c0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e59ec810>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content' at 0x7f14e59ec8b0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Definitions}Id' at 0x7f14e59ec950>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}Options' at 0x7f14e59ec9f0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}RequiredProfiles' at 0x7f14e59eca90>
# <Element '{http://schemas.microsoft.com/2003/10/Serialization/Arrays}string' at 0x7f14e59ecb30>
# <Element '{http://schemas.microsoft.com/2003/10/Serialization/Arrays}string' at 0x7f14e59ecc20>
# <Element '{http://schemas.microsoft.com/2003/10/Serialization/Arrays}string' at 0x7f14e59ecd10>
# <Element '{http://schemas.microsoft.com/2003/10/Serialization/Arrays}string' at 0x7f14e59ece00>
# <Element '{http://schemas.microsoft.com/2003/10/Serialization/Arrays}string' at 0x7f14e59ecef0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}RequiresAll' at 0x7f14e59f0090>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}Strict' at 0x7f14e59f0130>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}TargetProfilingScheme' at 0x7f14e59f01d0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}_autoIncrement' at 0x7f14e59f0270>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}_finalQuery' at 0x7f14e59f02c0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e59f0310>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}MetaInfoTable' at 0x7f14e59f0360>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}PacketProcessMode' at 0x7f14e59f03b0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}ReferenceKey' at 0x7f14e59f0400>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}TrainingSet' at 0x7f14e59f0450>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Chemicals' at 0x7f14e59f04a0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Description' at 0x7f14e59f04f0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Parameters' at 0x7f14e59f0540>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}YesLabel' at 0x7f14e59f0590>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Id' at 0x7f14e59f05e0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}SavedWithEngine' at 0x7f14e59f0630>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Version' at 0x7f14e59f0680>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}WorksWithMixtures' at 0x7f14e59f06d0>
# <Element '{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}_autoIncrement' at 0x7f14e59f0720>

# %%
class Query:
    
    def __init__(self,xml,qid=None):
        self.xml=xml
        self.id=qid
        self.logic=None
        self.subqueries=[]
        self.category=None
        
    def write_query(self,qtype,tree):
        self.type=qtype
        if qtype=='a:StructureQuery':
            qstring=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch').text
            qstring=re.sub('false','False',qstring)
            qstring=re.sub('true','True',qstring)
            qdict=ast.literal_eval(qstring)
            smart=qdict['queries'][0]['smart']
            self.smart=smart
            return smart

# %%
class Query:
    
    def __init__(self,xml,qid=None):
        self.xml=xml
        self.id=qid
        self.logic=None
        self.subqueries=[]
        self.category=None
        
    def write_query(self,qtype,tree):
        self.type=qtype
        if qtype=='a:StructureQuery':
            qstring=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Queries}ComplexSearch').text
            qstring=re.sub('false','False',qstring)
            qstring=re.sub('true','True',qstring)
            qdict=ast.literal_eval(qstring)
            smart=qdict['queries'][0]['smart']
            self.smart=smart
            if '[Ch3,#1]' in self.smart:
                split=re.search(r'(.*)\[([^\(\)]*),([^\(\)].*)\]$',self.smart)
                split1=split.group(1)
                split2=split.group(1)+'['+split.group(2)+']'
                smart_match1=define_smart_match(split1)
                smart_match2=define_smart_match(split2)
                def smart_match(x):
                    return any([smart_match1(x),smart_match2(x)])
            else:
                smart_match=define_smart_match(smart)
            self.query=smart_match
        elif qtype=='LogicalQuery':
            self.logic=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Logic').text
            elements=self.xml.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Elements')
            node_ids=[elem.attrib['{http://schemas.microsoft.com/2003/10/Serialization/}Ref']\
                      for elem in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query')\
                      if '{http://schemas.microsoft.com/2003/10/Serialization/}Ref' in elem.attrib]
            if self.logic=='Not':
                node_id=node_ids[0] #Should only be one
                sq=tree[node_id]
                self.subqueries=[sq]
                def func(x):
                    return not(sq.query(x))
                self.query=func
            elif self.logic=='And':
                sqs=[tree[node_id] for node_id in node_ids]
                self.subqueries=sqs
                def func(x):
                    return all([sq.query(x) for sq in self.subqueries])
                self.query=func
            else:
                sqs=[tree[node_id] for node_id in node_ids]
                self.subqueries=sqs
                for orquery in elements.findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query'):
                    if '{http://www.w3.org/2001/XMLSchema-instance}type' in orquery.attrib:
                        extra_sq=Query(orquery)
                        extra_sq.write_query('b:StructureQuery',tree)
                        sqs.append(extra_sq)      
                def func(x):
                    return any([sq.query(x) for sq in self.subqueries])
                self.query=func
    
    def print_tree(self,x,tabs=0):
        qinfo=(self.id,self.type)
        if self.type=='b:StructureQuery':
            qinfo=qinfo+(self.smart,)
        elif self.type=='LogicalQuery':
            qinfo=qinfo+(self.logic,)
        try:
            qinfo=qinfo+(self.query(x),)
        except:
            qinfo=qinfo+('does not process',)
        print('\t'*tabs+str(qinfo))
        for sq in self.subqueries:
            sq.print_tree(x,tabs+1)

# %%
q = Query(xml)

# %%
for elem in e.iter('http://schemas.microsoft.com/2003/10/Serialization/Arrays'):
    print(elem)

# %%
all_tests={}
print_tests = {}
bad_smarts=set()
bad_cats=set()
import re
import ast
for elem in e.iter('{http://schemas.microsoft.com/2003/10/Serialization/Arrays}anyType'):
    category=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Caption').text
    queries=elem.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Expression')\
        .find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Queries')\
        .findall('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Query')
    contents=[query.find('{http://schemas.datacontract.org/2004/07/LMC.Profiling.Engine}Content') for query in queries]
    #print(query)
    query_tree={}
    for query in contents:
        attributes=query.attrib
        if '{http://schemas.microsoft.com/2003/10/Serialization/}Id' not in attributes:
            continue
        query_id=attributes['{http://schemas.microsoft.com/2003/10/Serialization/}Id']
        query_type=attributes['{http://www.w3.org/2001/XMLSchema-instance}type']
        q=Query(query,query_id)
        q.category=category
        q.write_query(query_type,query_tree)
        q.print_tree(q.query)
        if not q.query or not all([sq.query for sq in q.subqueries]): #Smarts did not compile, sqs needed bc of hidden sqs in or queries
            bad_cats.add(category)
            if q.type=='b:StructureQuery':
                bad_smarts.add(q.smart)
        query_tree[query_id]=q
    all_tests[category]=query_tree[query_id]
    print_tests[category] = [query_id, query_type]#Final one should always be the top level query hopefully
